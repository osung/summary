# %%
import re
import requests
from bs4 import BeautifulSoup
import ssl

# %%
# SSL 인증서 검증 비활성화
requests.packages.urllib3.disable_warnings(requests.packages.urllib3.exceptions.InsecureRequestWarning)

# %%
keyword='태연'
url="https://search.naver.com/search.naver?where=image&sm=tab_jum&query="+keyword

# %%
url
# Out:
# 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query=태연'

# %%
html = requests.get(url, verify=False)
soup = BeautifulSoup(html.content,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#  <html lang="ko"><head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="태연 : 네이버 이미지검색" property="og:title"> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'태연'의 네이버 이미지검색 결과입니다." property="og:description"/> <meta content="'태연'의 네이버 이미지검색 결과입니다." lang="ko" name="description"/> <title>태연 : 네이버 이미지검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_240314.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_240502.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_240502.css" rel="stylesheet" type="text/css"/><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; </script><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); function nx_add_event_handler (event, func) { $Fn(func).attach(document, event) ; } function bt(id, after) { document.getElementById(id).src = after; } function document_write (s) { document.write(s) ; } </script><script> var nx_au_cookie_domain = ".search.naver.com" ; var g_site = "" ; function nx_defer_eval (id) { var codeElement = document.getElementById(id), code = codeElement.innerHTML; eval(code.replace(/\/\*/, '').replace(/\*\//, '')); } function trim_crlf (q) { var crlf = /[\r|\n]/ ; q = q.replace(crlf, "") ; return q ; } function include_script (type, defer, src, charset) { var script = document.createElement("script") ; script.type = type, script.defer = defer ; script.src = src ; if (charset) script.charset = charset ; else script.charset = 'utf-8' ; document.getElementsByTagName('head')[0].appendChild(script) ; return script ; } function include_style (src, charset) { var h = document.getElementsByTagName("head")[0] ; var l = document.createElement('link') ; l.type = 'text/css' ; l.rel = 'stylesheet' ; if (charset) l.charset = charset ; else l.charset = 'utf-8' ; l.media = 'screen' ; l.href = src ; h.appendChild(l) ; } function rank_val (rank, name, sign, number, ad_onair) { this.rank = rank ; this.name = name ; this.sign = sign ; this.number = number ; this.ad_onair = ad_onair ; } function rr_hotquery_val (titleImg, totalLink, ad_onair) { this.titleImg = titleImg ; this.totalLink = totalLink ; this.ad_onair = ad_onair ; } function rr_append () { for (var i=0; i<rr_list.length; i++) if (rr_list[i].qname==hotqry_Name && rr_list[i].dir==hotqry_Dir) return 0 ; var o = { order:hotqry_Order, contid:hotqry_ContID, qname:hotqry_Name, dir:hotqry_Dir, toprank:hotqry_TopRank, rankdown:hotqry_RankDown, clicklog:hotqry_ClickLog, toprank_idx:toprank_idx, lowrank_idx:lowrank_idx, topranklist:toprank, lowranklist:lowrank_idx>=0?lowrank:null } ; rr_list = rr_list.concat(o) ; return 1 ; } var msg_hidden_idle=null; function msg (id) { if(msg_hidden_idle) clearInterval(msg_hidden_idle); if(id) { var mid=document.getElementById(id); mid.style.display=''; mid.style.visibility='visible'; } } function msg_hidden (id, f) { if(f) hidden(id); else msg_hidden_idle=setInterval("hidden('"+id+"')",100); } function hidden (id) { var mid=document.getElementById(id); mid.style.display='none'; mid.style.visibility='hid ...
# <input id="mode" name="mode" type="hidden" value="column"/>
# <input id="section" name="section" type="hidden" value="image"/>
# <input id="img_query" name="query" type="hidden" value="태연"/>
# <input id="res_fr" name="res_fr" type="hidden" value="0"/>
# <input id="res_to" name="res_to" type="hidden" value="0"/>
# <input id="img_sm_id" name="sm" type="hidden" value="tab_opt"/>
# <input id="color" name="color" type="hidden"/>
# <input id="ccl" name="ccl" type="hidden" value="0"/>
# <input id="img_nso" name="nso" type="hidden" value="so:r,a:all,p:all"/>
# <input id="recent" name="recent" type="hidden" value="0"/>
# <input id="img_datetype" name="datetype" type="hidden" value="0"/>
# <input id="img_startdate" name="startdate" type="hidden" value="0"/>
# <input id="img_enddate" name="enddate" type="hidden" value="0"/>
# <input id="img_gif" name="gif" type="hidden" value="0"/>
# <input id="img_optStr" name="optStr" type="hidden"/>
# <input id="img_nq" name="nq" type="hidden"/>
# <input id="img_dq" name="dq" type="hidden"/>
# <input id="img_rq" name="rq" type="hidden"/>
# <input id="img_tq" name="tq" type="hidden"/>
# <input id="nso_open" name="nso_open" type="hidden" value="1"/>
# <input id="pq" name="pq" type="hidden"/></form><div class="ani_fadein" id="snb"><div class="mod_group_option_filter image_option _search_option_simple_wrap"><div class="mod_list_option_filter"><div aria-label="정렬 필터를 선택하세요" class="option_area type_multi" role="listbox"><a aria-selected="false" class="spnew_bf item" data-cr-area="opt.recent" data-param="datetype=2&amp;recent=1&amp;nso=so:r,p:1w,a:" data-search-option-item="" href="#" role="option">최근</a><a aria-selected="false" class="spnew_bf item" data-cr-area="opt.hd" data-param="res_fr=786432&amp;res_to=100000000" data-search-option-item="" href="#" role="option">고화질</a><a aria-selected="false" class="spnew_bf item" data-cr-area="opt.gif" data-param="gif=1" data-search-option-item="" href="#" role="option">GIF</a></div><div class="option_filter"><a aria-expanded="false" aria-haspopup="listbox" aria-label="검색옵션 열기" class="btn_option _search_option_open_btn" href="javascript:;" onclick="return tCR('a=opt.open')" role="button">옵션<i class="spnew ico_filter_arr"></i></a></div></div></div><div class="mod_group_option_sort _search_option_detail_wrap" role="listbox" style="display:none"><div class="mod_list_option_filter"><div class="option_filter"><a aria-expanded="true" aria-haspopup="listbox" aria-label="검색옵션 닫기" class="btn_option _search_option_close_btn" href="javascript:;" onclick="return tCR('a=opt.close')" role="button">옵션<i class="spnew ico_filter_arr"></i></a></div></div><ul class="lst_option"><li class="bx size"><div class="bx_inner"><strong class="tit">크기</strong><div class="option" role="tablist"><a aria-selected="true" class="txt" data-cr-area="opt.sizeall" data-param="res_fr=&amp;res_to=&amp;optStr=" data-search-option-item="" href="#" role="tab">전체</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.hd" data-param="res_fr=786432&amp;res_to=100000000&amp;nso_open=1" data-search-option-item="" href="#" role="tab">고화질</a></div></div></li><li class="bx type"><div class="bx_inner"><strong class="tit">유형</strong><div class="option" role="tablist"><a aria-selected="true" class="txt" data-cr-area="opt.typeall" data-param="gif=" data-search-option-item="" href="#" role="tab">전체</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.gif" data-param="gif=1&amp;nso_open=1" data-search-option-item="" href="#" role="tab">GIF</a></div></div></li><li class="bx term"><div class="bx_inner"><strong class="tit">기간</strong><div class="option" role="tablist"><a aria-selected="true" class="txt" data-cr-area="opt.periodall" data-param="datetype=0&amp;nso=so:r,p:all,a:" data-search-option-item="" href="#" role="tab">전체</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.day" data-param="datetype=1&amp;nso=so:r,p:1d,a:&amp;nso_open=1" data-search-option-item="" href="#" role="tab">1일</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.week" data-param="datetype=2&amp;nso=so:r,p:1w,a:&amp;nso_open=1" data-search-option-item="" href="#" role="tab">1주</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.month" data-param="datetype=3&amp;nso=so:r,p:1m,a:&amp;nso_open=1" data-search-option-item="" href="#" role="tab">1개월</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.3months" data-param="datetype=8&amp;nso=so:r,p:3m,a:&amp;nso_open=1" data-search-option-item="" href="#" role="tab">3개월</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.6months" data-param="datetype=4&amp;nso=so:r,p:6m,a:&amp;nso_open=1" data-search-option-item="" href="#" role="tab">6개월</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.year" data-param="datetype=5&amp;nso=so:r,p:1y,a:&amp;nso_open=1" data-search-option-item="" href="#" role="tab">1년</a>
# <a aria-selected="false" class="txt txt_option _calendar_select_trigger" data-cr-area="opt.calendar" data-select-trigger="" href="#" role="tab">직접입력<i class="spnew ico_check">옵션<em class="open">펼치기</em><em class="close">접기</em></i></a></div><div class="mod_select_option type_calendar _calendar_select_layer" data-select-layer="" style="display: none"><div class="set_calendar" role="tablist"><span class="set"><span class="blind">기간 설정시작</span>
# <a aria-selected="true" class="spnew_bf ico_calendar _start_trigger" data-cr-area="opt_cal.startdate" href="#" onclick="return tCR('a=opt.startdate')" role="tab"></a></span>
# <span class="set etc"><span class="ico_since">~</span></span>
# <span class="set"><span class="blind">기간 설정끝</span>
# <a aria-selected="false" class="spnew_bf ico_calendar _end_trigger" data-cr-area="opt_cal.enddate" href="#" onclick="return tCR('a=opt.enddate')" role="tab"></a></span></div><div class="select_wrap _root"><div class="group_select _list_root"><strong class="blind">년(Year)</strong><div class="select_cont"><div class="select_area _scroll_wrapper"><div><ul class="lst_item _ul" role="tablist"></ul></div></div></div></div><div class="group_select _list_root"><strong class="blind">월(Month)</strong><div class="select_cont"><div class="select_area _scroll_wrapper"><div><ul class="lst_item _ul" role="tablist"></ul></div></div></div></div><div class="group_select _list_root"><strong class="blind">일(Day)</strong><div class="select_cont"><div class="select_area _scroll_wrapper"><div><ul class="lst_item _ul" role="tablist"></ul></div></div></div></div></div><div class="btn_area"><button class="btn_apply _apply_btn" data-cr-area="opt.calendarapply" type="button">적용</button></div></div></div></li><li class="bx color"><div class="bx_inner"><strong class="tit">색상</strong><div class="option"><div class="option_color type_default"><label aria-label="전체" class="spnew choice_all selected" data-cr-area="opt.opncolor" data-param="color=" data-search-option-item="" for="ch_all"><input checked="" id="ch_all" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="red" class="choice0" data-cr-area="opt.opncolor" data-param="color=red&amp;nso_open=1" data-search-option-item="" for="ch0"><input id="ch0" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="orange" class="choice1" data-cr-area="opt.opncolor" data-param="color=orange&amp;nso_open=1" data-search-option-item="" for="ch1"><input id="ch1" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="yellow" class="choice2" data-cr-area="opt.opncolor" data-param="color=yellow&amp;nso_open=1" data-search-option-item="" for="ch2"><input id="ch2" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="lime" class="choice3" data-cr-area="opt.opncolor" data-param="color=lime&amp;nso_open=1" data-search-option-item="" for="ch3"><input id="ch3" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="green" class="choice4" data-cr-area="opt.opncolor" data-param="color=green&amp;nso_open=1" data-search-option-item="" for="ch4"><input id="ch4" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="cyan" class="choice5" data-cr-area="opt.opncolor" data-param="color=cyan&amp;nso_open=1" data-search-option-item="" for="ch5"><input id="ch5" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="blue" class="choice6" data-cr-area="opt.opncolor" data-param="color=blue&amp;nso_open=1" data-search-option-item="" for="ch6"><input id="ch6" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="purple" class="choice7" data-cr-area="opt.opncolor" data-param="color=purple&amp;nso_open=1" data-search-option-item="" for="ch7"><input id="ch7" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="pink" class="choice8" data-cr-area="opt.opncolor" data-param="color=pink&amp;nso_open=1" data-search-option-item="" for="ch8"><input id="ch8" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="apricot" class="choice9" data-cr-area="opt.opncolor" data-param="color=apricot&amp;nso_open=1" data-search-option-item="" for="ch9"><input id="ch9" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="ocher" class="choice10" data-cr-area="opt.opncolor" data-param="color=ocher&amp;nso_open=1" data-search-option-item="" for="ch10"><input id="ch10" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="sepia" class="choice11" data-cr-area="opt.opncolor" data-param="color=sepia&amp;nso_open=1" data-search-option-item="" for="ch11"><input id="ch11" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="black" class="choice12" data-cr-area="opt.opncolor" data-param="color=black&amp;nso_open=1" data-search-option-item="" for="ch12"><input id="ch12" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="gray" class="choice13" data-cr-area="opt.opncolor" data-param="color=gray&amp;nso_open=1" data-search-option-item="" for="ch13"><input id="ch13" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="white" class="choice14" data-cr-area="opt.opncolor" data-param="color=white&amp;nso_open=1" data-search-option-item="" for="ch14"><input id="ch14" type="checkbox"/><span class="spnew ic_check"></span></label></div></div></div></li><li class="bx source"><div class="bx_inner"><strong class="tit">출처</strong><div class="option" role="tablist"><a aria-selected="true" class="txt" data-cr-area="opt.srcall" data-param="section=image" data-search-option-item="" href="#" role="tab">전체</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.srcblog" data-param="section=blog&amp;nso_open=1" data-search-option-item="" href="#" role="tab">블로그</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.srcabdb" data-param="section=abdb&amp;nso_open=1" data-search-option-item="" href="#" role="tab">웹</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.srccafe" data-param="section=cafe&amp;nso_open=1" data-search-option-item="" href="#" role="tab">카페</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.srcnews" data-param="section=news&amp;nso_open=1" data-search-option-item="" href="#" role="tab">포토뉴스</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.srcnshopping" data-param="section=nshopping&amp;nso_open=1" data-search-option-item="" href="#" role="tab">쇼핑</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.srcpost" data-param="section=post&amp;nso_open=1" data-search-option-item="" href="#" role="tab">포스트</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.srcplace" data-param="section=place&amp;nso_open=1" data-search-option-item="" href="#" role="tab">플레이스</a></div></div></li><li class="bx ccl"><div class="bx_inner"><strong class="tit">CCL</strong><div class="option" role="tablist"><a aria-selected="true" class="txt" data-cr-area="opt.cclnone" data-param="ccl=0" data-search-option-item="" href="#" role="tab">선택 안함</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.cclall" data-param="ccl=1&amp;nso_open=1" data-search-option-item="" href="#" role="tab">CCL 전체</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.commercial" data-param="ccl=2&amp;nso_open=1" data-search-option-item="" href="#" role="tab">상업적 이용 가능</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.modifiable" data-param="ccl=4&amp;nso_open=1" data-search-option-item="" href="#" role="tab">원본 수정 가능</a></div></div></li><li class="bx clear"><div class="bx_inner"><div class="option"><a class="link_help" data-cr-area="opt.help" href="https://m.help.naver.com/support/alias/search/integration_m/integration_m109.naver" onclick="return goOtherCR(this,'a=opt.help&amp;u='+urlencode(this.href))">검색옵션 가이드<i class="spnew api_ico_help"></i></a></div></div></li></ul></div></div><script>(function(){var a="https://ssl.pstatic.net/sstatic/fe/sfe/searchOption/Controller_230920.js".replace(/\.js$/,""),b=function(){var b=window.require.config({context:"_fe_search_option",paths:{Controller:a.replace(/\.js$/,"")}});define("jquery",[],function(){return jQuery}),b(["Controller"],function(a){var b=new a({$form:jQuery("#image_form")});b.on({selectCalendar:function(a){var d=a.param,g={area:a.$item.data("cr-area")},b=a.startDate,c=a.endDate,e=b.year+"."+b.month+"."+b.date,f=c.year+"."+c.month+"."+c.date,h=e.replace(/\./gi,""),i=f.replace(/\./gi,"");d="datetype=6&startdate="+e+"&enddate="+f+"&nso=so:r,p:from"+h+"to"+i,this.submit(d,g)},clickDirectInputTrigger:function(a){var b=a.param;a.bOpen?tCR('a=opt.calendar'):tCR('a=opt.calendar')},clickItem:function(a){var b=a.param,c={area:a.$item.data("cr-area")};this.submit(b,c)}})})};naver.common.load_js(null,b,!0,150)})()</script><link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_nimage_231214.css" rel="stylesheet"/><script>var imageSearchModulePaths={ImageSearchTab:"https://ssl.pstatic.net/sstatic/fe/sfe/image-search/pc-tab/ImageSearchTab_240401.js".replace(/\.js$/,"")},imageSearchServerPaths={shopAdExposureAPIUrl:"",photoAPIUrl:"https://s.search.naver.com/p/image/46/search.naver?ac=0\u0026aq=0\u0026display=100\u0026json_type=6\u0026mode=\u0026nlu_query=%7B%22r_category%22%3A%2212\u002b11%22%7D\u0026nqx_theme=%7B%22theme%22%3A%7B%22main%22%3A%7B%22name%22%3A%22people_star%22%2C%22os%22%3A%22145072%22%2C%22pkid%22%3A%221%22%7D%7D%7D\u0026nso=so%3Ar%2Cp%3Aall%2Ca%3Aall\u0026nx_search_query=%ED%83%9C%EC%97%B0\u0026query=%ED%83%9C%EC%97%B0\u0026section=image\u0026spq=2\u0026where=image"}</script><link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_viewer_231214.css" rel="stylesheet"/><section class="sc_new sp_viewer _fe_image_viewer_root" style="display: none;"></section><script>var imageSearchViewerModulePaths={ImageSearchViewer:"https://ssl.pstatic.net/sstatic/fe/sfe/image-search/pc-viewer/ImageSearchViewer_240426.js".replace(/\.js$/,"")},imageSearchViewerServerPaths={relatedImagesAPIUrl:"https://s.search.naver.com/p/image/46/search.naver?ac=0\u0026aq=0\u0026json_type=11\u0026mode=related\u0026nlu_query=%7B%22r_category%22%3A%2212\u002b11%22%7D\u0026nqx_theme=%7B%22theme%22%3A%7B%22main%22%3A%7B%22name%22%3A%22people_star%22%2C%22os%22%3A%22145072%22%2C%22pkid%22%3A%221%22%7D%7D%7D\u0026nx_search_query=%ED%83%9C%EC%97%B0\u0026query=%ED%83%9C%EC%97%B0\u0026where=image",singlePhotoAPIUrl:"https://s.search.naver.com/p/image/46/search.naver?ac=0\u0026json_type=10\u0026where=image",reportAPIUrl:"https://s.search.naver.com/p/image/46/search.naver?json_type=2\u0026query=%ED%83%9C%EC%97%B0",lensAPIUrl:"https://s.search.naver.com/p/image/46/search.naver?json_type=16\u0026mode=\u0026query=%ED%83%9C%EC%97%B0\u0026vintageid=\u0026where=image"}</script><script>(function(){var a=function(){var a=window.require.config({context:"image-search-viewer",paths:{ImageSearchViewer:imageSearchViewerModulePaths.ImageSearchViewer}});define("jquery",[],function(){return jQuery}),a(["ImageSearchViewer"],function(a){var b={target:"._fe_image_viewer_prepend_target",root:"._fe_image_viewer_root",focusTarget:"._fe_image_viewer_focus_target"},c={lensViewer:{lensAPI:{url:imageSearchViewerServerPaths.lensAPIUrl+"&p_nvmid={=nvmid}&articleid={=articleid}&parentid={=parentid}&querySource={=querySource}&from={=from}&sbiid={=sbiid}&lensThumb={=lensThumb}"}},viewer:{singlePho ...

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
image_list = soup.find_all('script')

# %%
image_list[46]
# Out:
# <script> function splugin_oninitialize(sTargetId) { var elTarget = document.getElementById(sTargetId); var sUrl = $$.getSingle("a._sp_each_url", elTarget).href; var sTitle = $Element($$.getSingle("._sp_each_title", elTarget)).text(); var sSource = $Element($$.getSingle("._sp_each_source", elTarget)); if (sSource) sSource = sSource.text(); return { "url": sUrl, "title": sTitle, "option": { "baseElement": sTargetId + "_base", "layerPosition": "outside-bottom", "align": "right", "top": 18, "left": -28, "marginLeft": 8, "marginTop": 10 }, "me": { "display": "off" }, "mail": { "display": "off" }, "sourceName": sSource }; } (function () { var jsUrl = "https://ssl.pstatic.net/spi/js/release/ko_KR/splugin.js"; var startApplication = function () { var require = window.require.config({ "context": "search_common_modules", "paths": { "splugin": jsUrl.replace(/\.js$/, "") }, "shim": { "splugin": { "exports": "SocialPlugIn_Core" } }, "urlArgs": function(id, url) { if (id !== "splugin" && id !== "like-it") return ""; var args = "v=" + Math.floor(new Date().getTime() / 1200000); return (url.indexOf("?") === -1 ? "?" : "&") + args; } }); require(["splugin"], function (SocialPlugIn_Core) { g_nx_splugin = SocialPlugIn_Core({ "evKey": "search", "serviceName" : "이미지검색" }); }); }; naver.common.load_js(null, startApplication, true); })(); </script>

# %%
for im in image_list :
    if 'script' in im :
        print(im)

# %%
image_list[40]
# Out:
# <script>var imageSearchViewerModulePaths={ImageSearchViewer:"https://ssl.pstatic.net/sstatic/fe/sfe/image-search/pc-viewer/ImageSearchViewer_240426.js".replace(/\.js$/,"")},imageSearchViewerServerPaths={relatedImagesAPIUrl:"https://s.search.naver.com/p/image/46/search.naver?ac=0\u0026aq=0\u0026json_type=11\u0026mode=related\u0026nlu_query=%7B%22r_category%22%3A%2212\u002b11%22%7D\u0026nqx_theme=%7B%22theme%22%3A%7B%22main%22%3A%7B%22name%22%3A%22people_star%22%2C%22os%22%3A%22145072%22%2C%22pkid%22%3A%221%22%7D%7D%7D\u0026nx_search_query=%ED%83%9C%EC%97%B0\u0026query=%ED%83%9C%EC%97%B0\u0026where=image",singlePhotoAPIUrl:"https://s.search.naver.com/p/image/46/search.naver?ac=0\u0026json_type=10\u0026where=image",reportAPIUrl:"https://s.search.naver.com/p/image/46/search.naver?json_type=2\u0026query=%ED%83%9C%EC%97%B0",lensAPIUrl:"https://s.search.naver.com/p/image/46/search.naver?json_type=16\u0026mode=\u0026query=%ED%83%9C%EC%97%B0\u0026vintageid=\u0026where=image"}</script>

# %%
'<script>' in image_list[40]
# Out:
# False

# %%
type(image_list[40])
# Out:
# bs4.element.Tag

# %%
image_list[46]
# Out:
# <script> function splugin_oninitialize(sTargetId) { var elTarget = document.getElementById(sTargetId); var sUrl = $$.getSingle("a._sp_each_url", elTarget).href; var sTitle = $Element($$.getSingle("._sp_each_title", elTarget)).text(); var sSource = $Element($$.getSingle("._sp_each_source", elTarget)); if (sSource) sSource = sSource.text(); return { "url": sUrl, "title": sTitle, "option": { "baseElement": sTargetId + "_base", "layerPosition": "outside-bottom", "align": "right", "top": 18, "left": -28, "marginLeft": 8, "marginTop": 10 }, "me": { "display": "off" }, "mail": { "display": "off" }, "sourceName": sSource }; } (function () { var jsUrl = "https://ssl.pstatic.net/spi/js/release/ko_KR/splugin.js"; var startApplication = function () { var require = window.require.config({ "context": "search_common_modules", "paths": { "splugin": jsUrl.replace(/\.js$/, "") }, "shim": { "splugin": { "exports": "SocialPlugIn_Core" } }, "urlArgs": function(id, url) { if (id !== "splugin" && id !== "like-it") return ""; var args = "v=" + Math.floor(new Date().getTime() / 1200000); return (url.indexOf("?") === -1 ? "?" : "&") + args; } }); require(["splugin"], function (SocialPlugIn_Core) { g_nx_splugin = SocialPlugIn_Core({ "evKey": "search", "serviceName" : "이미지검색" }); }); }; naver.common.load_js(null, startApplication, true); })(); </script>

# %%
image_list[46].p

# %%
soup.body.script
# Out:
# <script> (function() { var startApplication = function() { var $ = jQuery; var jsUrl = "https://ssl.pstatic.net/sstatic/fe/sfe/ime/app-1.1.0.js"; var cssUrl = "https://ssl.pstatic.net/sstatic/search/pc/css/api_keyboard_231116.css"; var ime; $("#ke_kbd_btn").on("click", function() { require([jsUrl], function(IMEKeyboard) { if (ime) { ime.toggle(); return; } ime = new IMEKeyboard({ "cssUrl": cssUrl, "selector": { "TOGGLE_BTN": "#ke_kbd_btn", "CONTENTS_AREA": "#_nx_kbd", "INPUT": "#nx_query" }, "onSearchBtnClick": function() { $("#nx_search_form").submit(); } }).toggle(); }, function(e) { alert("네트워크 상태가 안 좋아 한영 입력기를 불러오지 못했습니다.\n잠시 후 다시 시도해 주세요."); }); }); }; naver.common.load_js(null, startApplication, true, 150); })(); </script>

# %%
len(soup.contents)
# Out:
# 3

# %%
soup.contents[2]
# Out:
# <html lang="ko"><head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="태연 : 네이버 이미지검색" property="og:title"> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'태연'의 네이버 이미지검색 결과입니다." property="og:description"/> <meta content="'태연'의 네이버 이미지검색 결과입니다." lang="ko" name="description"/> <title>태연 : 네이버 이미지검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_240314.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_240502.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_240502.css" rel="stylesheet" type="text/css"/><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; </script><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); function nx_add_event_handler (event, func) { $Fn(func).attach(document, event) ; } function bt(id, after) { document.getElementById(id).src = after; } function document_write (s) { document.write(s) ; } </script><script> var nx_au_cookie_domain = ".search.naver.com" ; var g_site = "" ; function nx_defer_eval (id) { var codeElement = document.getElementById(id), code = codeElement.innerHTML; eval(code.replace(/\/\*/, '').replace(/\*\//, '')); } function trim_crlf (q) { var crlf = /[\r|\n]/ ; q = q.replace(crlf, "") ; return q ; } function include_script (type, defer, src, charset) { var script = document.createElement("script") ; script.type = type, script.defer = defer ; script.src = src ; if (charset) script.charset = charset ; else script.charset = 'utf-8' ; document.getElementsByTagName('head')[0].appendChild(script) ; return script ; } function include_style (src, charset) { var h = document.getElementsByTagName("head")[0] ; var l = document.createElement('link') ; l.type = 'text/css' ; l.rel = 'stylesheet' ; if (charset) l.charset = charset ; else l.charset = 'utf-8' ; l.media = 'screen' ; l.href = src ; h.appendChild(l) ; } function rank_val (rank, name, sign, number, ad_onair) { this.rank = rank ; this.name = name ; this.sign = sign ; this.number = number ; this.ad_onair = ad_onair ; } function rr_hotquery_val (titleImg, totalLink, ad_onair) { this.titleImg = titleImg ; this.totalLink = totalLink ; this.ad_onair = ad_onair ; } function rr_append () { for (var i=0; i<rr_list.length; i++) if (rr_list[i].qname==hotqry_Name && rr_list[i].dir==hotqry_Dir) return 0 ; var o = { order:hotqry_Order, contid:hotqry_ContID, qname:hotqry_Name, dir:hotqry_Dir, toprank:hotqry_TopRank, rankdown:hotqry_RankDown, clicklog:hotqry_ClickLog, toprank_idx:toprank_idx, lowrank_idx:lowrank_idx, topranklist:toprank, lowranklist:lowrank_idx>=0?lowrank:null } ; rr_list = rr_list.concat(o) ; return 1 ; } var msg_hidden_idle=null; function msg (id) { if(msg_hidden_idle) clearInterval(msg_hidden_idle); if(id) { var mid=document.getElementById(id); mid.style.display=''; mid.style.visibility='visible'; } } function msg_hidden (id, f) { if(f) hidden(id); else msg_hidden_idle=setInterval("hidden('"+id+"')",100); } function hidden (id) { var mid=document.getElementById(id); mid.style.display='none'; mid.style.visibility='hidd ...
# <input id="mode" name="mode" type="hidden" value="column"/>
# <input id="section" name="section" type="hidden" value="image"/>
# <input id="img_query" name="query" type="hidden" value="태연"/>
# <input id="res_fr" name="res_fr" type="hidden" value="0"/>
# <input id="res_to" name="res_to" type="hidden" value="0"/>
# <input id="img_sm_id" name="sm" type="hidden" value="tab_opt"/>
# <input id="color" name="color" type="hidden"/>
# <input id="ccl" name="ccl" type="hidden" value="0"/>
# <input id="img_nso" name="nso" type="hidden" value="so:r,a:all,p:all"/>
# <input id="recent" name="recent" type="hidden" value="0"/>
# <input id="img_datetype" name="datetype" type="hidden" value="0"/>
# <input id="img_startdate" name="startdate" type="hidden" value="0"/>
# <input id="img_enddate" name="enddate" type="hidden" value="0"/>
# <input id="img_gif" name="gif" type="hidden" value="0"/>
# <input id="img_optStr" name="optStr" type="hidden"/>
# <input id="img_nq" name="nq" type="hidden"/>
# <input id="img_dq" name="dq" type="hidden"/>
# <input id="img_rq" name="rq" type="hidden"/>
# <input id="img_tq" name="tq" type="hidden"/>
# <input id="nso_open" name="nso_open" type="hidden" value="1"/>
# <input id="pq" name="pq" type="hidden"/></form><div class="ani_fadein" id="snb"><div class="mod_group_option_filter image_option _search_option_simple_wrap"><div class="mod_list_option_filter"><div aria-label="정렬 필터를 선택하세요" class="option_area type_multi" role="listbox"><a aria-selected="false" class="spnew_bf item" data-cr-area="opt.recent" data-param="datetype=2&amp;recent=1&amp;nso=so:r,p:1w,a:" data-search-option-item="" href="#" role="option">최근</a><a aria-selected="false" class="spnew_bf item" data-cr-area="opt.hd" data-param="res_fr=786432&amp;res_to=100000000" data-search-option-item="" href="#" role="option">고화질</a><a aria-selected="false" class="spnew_bf item" data-cr-area="opt.gif" data-param="gif=1" data-search-option-item="" href="#" role="option">GIF</a></div><div class="option_filter"><a aria-expanded="false" aria-haspopup="listbox" aria-label="검색옵션 열기" class="btn_option _search_option_open_btn" href="javascript:;" onclick="return tCR('a=opt.open')" role="button">옵션<i class="spnew ico_filter_arr"></i></a></div></div></div><div class="mod_group_option_sort _search_option_detail_wrap" role="listbox" style="display:none"><div class="mod_list_option_filter"><div class="option_filter"><a aria-expanded="true" aria-haspopup="listbox" aria-label="검색옵션 닫기" class="btn_option _search_option_close_btn" href="javascript:;" onclick="return tCR('a=opt.close')" role="button">옵션<i class="spnew ico_filter_arr"></i></a></div></div><ul class="lst_option"><li class="bx size"><div class="bx_inner"><strong class="tit">크기</strong><div class="option" role="tablist"><a aria-selected="true" class="txt" data-cr-area="opt.sizeall" data-param="res_fr=&amp;res_to=&amp;optStr=" data-search-option-item="" href="#" role="tab">전체</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.hd" data-param="res_fr=786432&amp;res_to=100000000&amp;nso_open=1" data-search-option-item="" href="#" role="tab">고화질</a></div></div></li><li class="bx type"><div class="bx_inner"><strong class="tit">유형</strong><div class="option" role="tablist"><a aria-selected="true" class="txt" data-cr-area="opt.typeall" data-param="gif=" data-search-option-item="" href="#" role="tab">전체</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.gif" data-param="gif=1&amp;nso_open=1" data-search-option-item="" href="#" role="tab">GIF</a></div></div></li><li class="bx term"><div class="bx_inner"><strong class="tit">기간</strong><div class="option" role="tablist"><a aria-selected="true" class="txt" data-cr-area="opt.periodall" data-param="datetype=0&amp;nso=so:r,p:all,a:" data-search-option-item="" href="#" role="tab">전체</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.day" data-param="datetype=1&amp;nso=so:r,p:1d,a:&amp;nso_open=1" data-search-option-item="" href="#" role="tab">1일</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.week" data-param="datetype=2&amp;nso=so:r,p:1w,a:&amp;nso_open=1" data-search-option-item="" href="#" role="tab">1주</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.month" data-param="datetype=3&amp;nso=so:r,p:1m,a:&amp;nso_open=1" data-search-option-item="" href="#" role="tab">1개월</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.3months" data-param="datetype=8&amp;nso=so:r,p:3m,a:&amp;nso_open=1" data-search-option-item="" href="#" role="tab">3개월</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.6months" data-param="datetype=4&amp;nso=so:r,p:6m,a:&amp;nso_open=1" data-search-option-item="" href="#" role="tab">6개월</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.year" data-param="datetype=5&amp;nso=so:r,p:1y,a:&amp;nso_open=1" data-search-option-item="" href="#" role="tab">1년</a>
# <a aria-selected="false" class="txt txt_option _calendar_select_trigger" data-cr-area="opt.calendar" data-select-trigger="" href="#" role="tab">직접입력<i class="spnew ico_check">옵션<em class="open">펼치기</em><em class="close">접기</em></i></a></div><div class="mod_select_option type_calendar _calendar_select_layer" data-select-layer="" style="display: none"><div class="set_calendar" role="tablist"><span class="set"><span class="blind">기간 설정시작</span>
# <a aria-selected="true" class="spnew_bf ico_calendar _start_trigger" data-cr-area="opt_cal.startdate" href="#" onclick="return tCR('a=opt.startdate')" role="tab"></a></span>
# <span class="set etc"><span class="ico_since">~</span></span>
# <span class="set"><span class="blind">기간 설정끝</span>
# <a aria-selected="false" class="spnew_bf ico_calendar _end_trigger" data-cr-area="opt_cal.enddate" href="#" onclick="return tCR('a=opt.enddate')" role="tab"></a></span></div><div class="select_wrap _root"><div class="group_select _list_root"><strong class="blind">년(Year)</strong><div class="select_cont"><div class="select_area _scroll_wrapper"><div><ul class="lst_item _ul" role="tablist"></ul></div></div></div></div><div class="group_select _list_root"><strong class="blind">월(Month)</strong><div class="select_cont"><div class="select_area _scroll_wrapper"><div><ul class="lst_item _ul" role="tablist"></ul></div></div></div></div><div class="group_select _list_root"><strong class="blind">일(Day)</strong><div class="select_cont"><div class="select_area _scroll_wrapper"><div><ul class="lst_item _ul" role="tablist"></ul></div></div></div></div></div><div class="btn_area"><button class="btn_apply _apply_btn" data-cr-area="opt.calendarapply" type="button">적용</button></div></div></div></li><li class="bx color"><div class="bx_inner"><strong class="tit">색상</strong><div class="option"><div class="option_color type_default"><label aria-label="전체" class="spnew choice_all selected" data-cr-area="opt.opncolor" data-param="color=" data-search-option-item="" for="ch_all"><input checked="" id="ch_all" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="red" class="choice0" data-cr-area="opt.opncolor" data-param="color=red&amp;nso_open=1" data-search-option-item="" for="ch0"><input id="ch0" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="orange" class="choice1" data-cr-area="opt.opncolor" data-param="color=orange&amp;nso_open=1" data-search-option-item="" for="ch1"><input id="ch1" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="yellow" class="choice2" data-cr-area="opt.opncolor" data-param="color=yellow&amp;nso_open=1" data-search-option-item="" for="ch2"><input id="ch2" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="lime" class="choice3" data-cr-area="opt.opncolor" data-param="color=lime&amp;nso_open=1" data-search-option-item="" for="ch3"><input id="ch3" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="green" class="choice4" data-cr-area="opt.opncolor" data-param="color=green&amp;nso_open=1" data-search-option-item="" for="ch4"><input id="ch4" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="cyan" class="choice5" data-cr-area="opt.opncolor" data-param="color=cyan&amp;nso_open=1" data-search-option-item="" for="ch5"><input id="ch5" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="blue" class="choice6" data-cr-area="opt.opncolor" data-param="color=blue&amp;nso_open=1" data-search-option-item="" for="ch6"><input id="ch6" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="purple" class="choice7" data-cr-area="opt.opncolor" data-param="color=purple&amp;nso_open=1" data-search-option-item="" for="ch7"><input id="ch7" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="pink" class="choice8" data-cr-area="opt.opncolor" data-param="color=pink&amp;nso_open=1" data-search-option-item="" for="ch8"><input id="ch8" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="apricot" class="choice9" data-cr-area="opt.opncolor" data-param="color=apricot&amp;nso_open=1" data-search-option-item="" for="ch9"><input id="ch9" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="ocher" class="choice10" data-cr-area="opt.opncolor" data-param="color=ocher&amp;nso_open=1" data-search-option-item="" for="ch10"><input id="ch10" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="sepia" class="choice11" data-cr-area="opt.opncolor" data-param="color=sepia&amp;nso_open=1" data-search-option-item="" for="ch11"><input id="ch11" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="black" class="choice12" data-cr-area="opt.opncolor" data-param="color=black&amp;nso_open=1" data-search-option-item="" for="ch12"><input id="ch12" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="gray" class="choice13" data-cr-area="opt.opncolor" data-param="color=gray&amp;nso_open=1" data-search-option-item="" for="ch13"><input id="ch13" type="checkbox"/><span class="spnew ic_check"></span></label>
# <label aria-label="white" class="choice14" data-cr-area="opt.opncolor" data-param="color=white&amp;nso_open=1" data-search-option-item="" for="ch14"><input id="ch14" type="checkbox"/><span class="spnew ic_check"></span></label></div></div></div></li><li class="bx source"><div class="bx_inner"><strong class="tit">출처</strong><div class="option" role="tablist"><a aria-selected="true" class="txt" data-cr-area="opt.srcall" data-param="section=image" data-search-option-item="" href="#" role="tab">전체</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.srcblog" data-param="section=blog&amp;nso_open=1" data-search-option-item="" href="#" role="tab">블로그</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.srcabdb" data-param="section=abdb&amp;nso_open=1" data-search-option-item="" href="#" role="tab">웹</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.srccafe" data-param="section=cafe&amp;nso_open=1" data-search-option-item="" href="#" role="tab">카페</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.srcnews" data-param="section=news&amp;nso_open=1" data-search-option-item="" href="#" role="tab">포토뉴스</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.srcnshopping" data-param="section=nshopping&amp;nso_open=1" data-search-option-item="" href="#" role="tab">쇼핑</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.srcpost" data-param="section=post&amp;nso_open=1" data-search-option-item="" href="#" role="tab">포스트</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.srcplace" data-param="section=place&amp;nso_open=1" data-search-option-item="" href="#" role="tab">플레이스</a></div></div></li><li class="bx ccl"><div class="bx_inner"><strong class="tit">CCL</strong><div class="option" role="tablist"><a aria-selected="true" class="txt" data-cr-area="opt.cclnone" data-param="ccl=0" data-search-option-item="" href="#" role="tab">선택 안함</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.cclall" data-param="ccl=1&amp;nso_open=1" data-search-option-item="" href="#" role="tab">CCL 전체</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.commercial" data-param="ccl=2&amp;nso_open=1" data-search-option-item="" href="#" role="tab">상업적 이용 가능</a>
# <a aria-selected="false" class="txt" data-cr-area="opt.modifiable" data-param="ccl=4&amp;nso_open=1" data-search-option-item="" href="#" role="tab">원본 수정 가능</a></div></div></li><li class="bx clear"><div class="bx_inner"><div class="option"><a class="link_help" data-cr-area="opt.help" href="https://m.help.naver.com/support/alias/search/integration_m/integration_m109.naver" onclick="return goOtherCR(this,'a=opt.help&amp;u='+urlencode(this.href))">검색옵션 가이드<i class="spnew api_ico_help"></i></a></div></div></li></ul></div></div><script>(function(){var a="https://ssl.pstatic.net/sstatic/fe/sfe/searchOption/Controller_230920.js".replace(/\.js$/,""),b=function(){var b=window.require.config({context:"_fe_search_option",paths:{Controller:a.replace(/\.js$/,"")}});define("jquery",[],function(){return jQuery}),b(["Controller"],function(a){var b=new a({$form:jQuery("#image_form")});b.on({selectCalendar:function(a){var d=a.param,g={area:a.$item.data("cr-area")},b=a.startDate,c=a.endDate,e=b.year+"."+b.month+"."+b.date,f=c.year+"."+c.month+"."+c.date,h=e.replace(/\./gi,""),i=f.replace(/\./gi,"");d="datetype=6&startdate="+e+"&enddate="+f+"&nso=so:r,p:from"+h+"to"+i,this.submit(d,g)},clickDirectInputTrigger:function(a){var b=a.param;a.bOpen?tCR('a=opt.calendar'):tCR('a=opt.calendar')},clickItem:function(a){var b=a.param,c={area:a.$item.data("cr-area")};this.submit(b,c)}})})};naver.common.load_js(null,b,!0,150)})()</script><link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_nimage_231214.css" rel="stylesheet"/><script>var imageSearchModulePaths={ImageSearchTab:"https://ssl.pstatic.net/sstatic/fe/sfe/image-search/pc-tab/ImageSearchTab_240401.js".replace(/\.js$/,"")},imageSearchServerPaths={shopAdExposureAPIUrl:"",photoAPIUrl:"https://s.search.naver.com/p/image/46/search.naver?ac=0\u0026aq=0\u0026display=100\u0026json_type=6\u0026mode=\u0026nlu_query=%7B%22r_category%22%3A%2212\u002b11%22%7D\u0026nqx_theme=%7B%22theme%22%3A%7B%22main%22%3A%7B%22name%22%3A%22people_star%22%2C%22os%22%3A%22145072%22%2C%22pkid%22%3A%221%22%7D%7D%7D\u0026nso=so%3Ar%2Cp%3Aall%2Ca%3Aall\u0026nx_search_query=%ED%83%9C%EC%97%B0\u0026query=%ED%83%9C%EC%97%B0\u0026section=image\u0026spq=2\u0026where=image"}</script><link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_viewer_231214.css" rel="stylesheet"/><section class="sc_new sp_viewer _fe_image_viewer_root" style="display: none;"></section><script>var imageSearchViewerModulePaths={ImageSearchViewer:"https://ssl.pstatic.net/sstatic/fe/sfe/image-search/pc-viewer/ImageSearchViewer_240426.js".replace(/\.js$/,"")},imageSearchViewerServerPaths={relatedImagesAPIUrl:"https://s.search.naver.com/p/image/46/search.naver?ac=0\u0026aq=0\u0026json_type=11\u0026mode=related\u0026nlu_query=%7B%22r_category%22%3A%2212\u002b11%22%7D\u0026nqx_theme=%7B%22theme%22%3A%7B%22main%22%3A%7B%22name%22%3A%22people_star%22%2C%22os%22%3A%22145072%22%2C%22pkid%22%3A%221%22%7D%7D%7D\u0026nx_search_query=%ED%83%9C%EC%97%B0\u0026query=%ED%83%9C%EC%97%B0\u0026where=image",singlePhotoAPIUrl:"https://s.search.naver.com/p/image/46/search.naver?ac=0\u0026json_type=10\u0026where=image",reportAPIUrl:"https://s.search.naver.com/p/image/46/search.naver?json_type=2\u0026query=%ED%83%9C%EC%97%B0",lensAPIUrl:"https://s.search.naver.com/p/image/46/search.naver?json_type=16\u0026mode=\u0026query=%ED%83%9C%EC%97%B0\u0026vintageid=\u0026where=image"}</script><script>(function(){var a=function(){var a=window.require.config({context:"image-search-viewer",paths:{ImageSearchViewer:imageSearchViewerModulePaths.ImageSearchViewer}});define("jquery",[],function(){return jQuery}),a(["ImageSearchViewer"],function(a){var b={target:"._fe_image_viewer_prepend_target",root:"._fe_image_viewer_root",focusTarget:"._fe_image_viewer_focus_target"},c={lensViewer:{lensAPI:{url:imageSearchViewerServerPaths.lensAPIUrl+"&p_nvmid={=nvmid}&articleid={=articleid}&parentid={=parentid}&querySource={=querySource}&from={=from}&sbiid={=sbiid}&lensThumb={=lensThumb}"}},viewer:{singlePho ...

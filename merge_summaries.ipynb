# %%
import pandas as pd

# %%
import pickle

# %%
directory='/home/osung/work/summary.0516/final/'

# %%
filenames = ['summary2_local_outputs_r0_191255_final.pkl', 
             'summary2_local_outputs_r1_382511_final.pkl', 
             'summary2_local_outputs_r2_573767_final.pkl', 
             'summary2_local_outputs_r3_765025_final.pkl']

# %%
df_summary = pd.read_csv('summary_output.tsv', sep='\t')

# %%
df_summary[:10]
# Out:
#                      id topic  \
# 0  NLRW1900000024.16590     S
# 1  NWRW1900000009.21980     S
# 2  NLRW1900000144.10274     S
# 3  NLRW2200000008.12137     S
# 4   NWRW1900000011.9505     S
# 5   NLRW1900000023.2202     S
# 6   NLRW2200000015.8183     S
# 7  NLRW2000000014.29543     S
# 8  NPRW2000000003.10588     S
# 9  NWRW1900000015.22167     S
#
#                                                 text  ksic  max_scores  \
# 0  1221m 초콜릿 파이 “3만명이 함께 먹을 수 있어” 1221m 초콜릿 파이가 등...  c107    0.930233
# 1  고등어야, 어디 있니? 어획량 20년 새 3분의 1로 국내산 고등어 어획량이 20년...  c102    0.718052
# 2  고령 우곡 농민들 "올해 수박농사 빈손…막막할 뿐" 이상기후 물량 줄고 품질 떨어져...  c103    0.639269
# 3  태안군, 해풍을 맞고 자란 명품 양파 수확 ‘한창!’ 태안의 비옥한 황토에서 갯바람...  c103    0.612410
# 4  친환경 농산물 약진… 생산량 10% 넘어 국내에서 생산되는 농산물 10개 가운데 1...  c103    0.588431
# 5  강화군, 친환경 영농 조례 추진 강화군이 친환경 농업에 대한 지원을 늘린다. 군은 ...  c103    0.585025
# 6  청주서 친환경 복숭아 첫 수확 청주시는 이달부터 유기농마케팅센터 내 친환경 로컬푸드...  c103    0.580181
# ...

# %%
len(df_summary)
# Out:
# 765026

# %%
df_summary[-10:]
# Out:
#                           id topic  \
# 765016  NWRW1900000038.41308     T
# 765017  NLRW2000000006.29408     T
# 765018  NWRW1900000038.41370     T
# 765019  NWRW1900000038.41769     T
# 765020  NWRW1900000038.41820     T
# 765021  NWRW1900000038.41782     T
# 765022  NLRW2000000006.29284     T
# 765023  NLRW2000000006.29247     T
# 765024  NWRW1900000038.41262     T
# 765025  NLRW2000000006.29470     T
#
#                                                      text ksic  max_scores  \
# 765016  “가족 생일 선물까지 추천한다”…롯데, IBM AI 왓슨 도입 롯데가 IBM과 손잡...  NaN         0.0
# 765017  있지 안다르, 캐시슬라이드 초성퀴즈 및 할인쿠폰 이벤트 "에어쿨링 래쉬가드" 애슬레...  NaN         0.0
# 765018  1월에는 유성우, 8월에는 부분월식 내년 1월에는 유성우를 관찰할 수 있고, 8월에...  NaN         0.0
# 765019  “윈도 10이 4200원” 해외직구 소동 ㆍ베네수엘라 화폐가치 급락에 최신 운영체제...  NaN         0.0
# 765020  베네수엘라 직구 운영체제 윈도10 사용 못하게 차단 ㆍMS, 구매자엔 환불키로 마이...  NaN         0.0
# 765021  네이버·다음 실시간 검색어 순위 ‘정부 요청 시 삭제’ 규정 운영했다 ㆍ자동완성·연...  NaN         0.0
# ...

# %%
df = pd.read_csv('/home/osung/data/korean/modu/json/news_PEST_ksic_score.tsv', sep='\t')

# %%
len(df)
# Out:
# 1530052

# %%
df.loc[765026]
# Out:
# id                                         NLRW1900000024.16590
# topic                                                         S
# text          1221m 초콜릿 파이 “3만명이 함께 먹을 수 있어” 1221m 초콜릿 파이가 등...
# ksic                                                       c107
# max_scores                                             0.930233
# Name: 765026, dtype: object

# %%
len(df[:765025])
# Out:
# 765025

# %%
summaries = []

# %%
with open(directory+filenames, 'rb') as file:
    readed = pickle.load(file)
    summaries.append(readed)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1554202/3019901412.py in <module>
# ----> 1 with open(directory+filenames, 'rb') as file:
#       2     readed = pickle.load(file)
#       3     summaries.append(readed)
#
# TypeError: can only concatenate str (not "list") to str

# %%
file = open(directory+filenames[0])

# %%
readed = pickle.load(file)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipykernel_1554202/1006812928.py in <module>
# ----> 1 readed = pickle.load(file)
#
# ~/anaconda3/lib/python3.9/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte

# %%
pickle_name = '/home/osung/work/summary.0516/final/summary2_local_outputs_r0_191255_final.pkl'

# %%
file = open(pickle_name, 'rb')

# %%
tmp = pickle.load(file)

# %%
summaries[0] = tmp

# %%
pickle_name = '/home/osung/work/summary.0516/final/summary2_local_outputs_r3_765025_final.pkl'

# %%
file = open(pickle_name, 'rb')

# %%
tmp = pickle.load(file)

# %%
summaries.append(tmp)

# %%
summaries
# Out:
# [['코로나 바이러스 확산으로 위중증 환자가 급격히 늘어나자 의료 인력이 코코나 치료에 집중하면서 일반 중환자 대처에 차질이 생기고 있어 의료 현장에서는 코로나 확산으로 암 환자 등 일반중환자 치료에 공백이 생기고 있다는 목소리가 나오고 있다. 의료 현장에서 김 교수는 이 때문에 소외된 환자들이 방치되고 있다는 사실을 알아야 한다고 말했다. 김 교수는 코로나가 환자도 중요하지만, 이 때문에 소외되는 환자들이 방치되는 사실을 알아야 한다고 말했다.  ',
#   '허태열 대통령비서실장이 최근 수석비서관회의를 주재하면서 휴가 때 (골프를) 꼭 치고 싶은 사람은 문제가 되지 않을 사람과 자비로 쳐도 된다며 웬만하면 필드(골프장) 대신 스크린골프를 이용하는 게 좋겠다고 말한 것으로 전해졌다. 2월 박근혜 정부 출범 이후 골프 금지령이 내려진 적은 없지만 북한의 위협이 이어진 데다 정권 출범의 긴장감이 더해져 공직자들은 자연스레 골프를 칠 엄두를 내지 못했다.청와대 관계자는 자비를 들여 취미로 치는 것까지 문제 삼을 수야 있겠느냐라며 그렇다고 이제부터 골프를 쳐도 된다고 선언하는 것도 우습고 자연스럽게 분위기가 잡힐 것이라고 말했다. ',
#   '이계안 민주통합당 후보는 4일 현대중공업 지배주주 정몽준 새누리당 후보와 현대중공업 이재성 대표이사를 공직선거법 위반 혐의로 검찰에 고발했으며 이유는 현대중공업의 광고 때문이었다고 주장했으나 현대중공업 쪽은 창립 40주년을 맞이하여 기업 본연의 정상적인 광고활동을 수행한 것이라며 총선과의 연관성을 일축했다. 현대그룹 전문경영인 출신의 이계 안 민주통합당 후보가 서울 동작을에서 맞붙고 있는, 현대중공업 지주 정몽준 새누리당 후보를 광고로 간접 지원했다는 주장이다. 이에 대해 현대중공업 측은 창립 40주년을 맞아 기업 본연의 정상적 광고활동 수행이라고 반박했다. ',
# ...

# %%
len(summaries[0])
# Out:
# 191260

# %%
len(summaries[0])
# Out:
# 191259

# %%
len(summaries[1])
# Out:
# 191260

# %%
len(summaries[2])
# Out:
# 191260

# %%
len(summaries[3])
# Out:
# 191262

# %%
191260 * 3 + 191262
# Out:
# 765042

# %%
765025/4
# Out:
# 191256.25

# %%
summaries[0][0]
# Out:
# '코로나 바이러스 확산으로 위중증 환자가 급격히 늘어나자 의료 인력이 코코나 치료에 집중하면서 일반 중환자 대처에 차질이 생기고 있어 의료 현장에서는 코로나 확산으로 암 환자 등 일반중환자 치료에 공백이 생기고 있다는 목소리가 나오고 있다. 의료 현장에서 김 교수는 이 때문에 소외된 환자들이 방치되고 있다는 사실을 알아야 한다고 말했다. 김 교수는 코로나가 환자도 중요하지만, 이 때문에 소외되는 환자들이 방치되는 사실을 알아야 한다고 말했다.  '

# %%
summaries[0][191259]
# Out:
# '이준석 바른미래당 최고위원이 추석연휴기간 올린 페이스북 글 때문에 곤혹을 치르고 있는데 명절 때 아무렇지 않게 하는 질문들이 당사자에게 상처가 될 수 있다는 것을 이준석 최고위원의 상황에 대한 질문을 통해 꼬집는 내용이다. 명절 때마다 일상적인 질문이라고 묻는 결혼, 출산, 취업 등의 내용이 당사자에게 상처로 돌아올 수 있다는 비판이 제기돼왔고, 세대 갈등으로도 확산될 수 있어 조심하자는 분위기가 형성돼 있는데 이 최고위원의 주장에 공감하는 의견도 있지만 누리꾼들은 이 최고위원이 보편적인 사회 정서를 이해하지 못하고 있다면서 비난하는 모습이다. 돈 안주실거면 잔소리는 사양할게요라며 쓰여진 추석 잔소리 메뉴판도 올라왔다. 이##는 언제쯤 당선되시나요?라는 질문을 댓글로 달았는데 명절 때 나오는 일상적인 질문 역시 당사자에게 아픔이 될 수 있다고 꼬집는 질문으로 김##는 우리들처럼 같은 감정 느끼고 페북에 이런글 못올릴텐데 왜 그걸 모르는지?라고 썼고 조##는 "친한주위사람한테도 애기 안가지냐 결혼안하냐 이런말 안합니다만;; 뭐라도 해주고 그런 얘기하던지 인사라고 툭던지는말이 다수의사람들이 공통적으로 싫어하니 저런 문화가 생기는거 아닙니까라고 되물었다. 유##은 오래 만난 친구사이에도 저런 질문과 오지랖은 실례라는 걸 왜 이해 못할까라고 지적했다. 반면 황##는 세상 아무리 각박하고 까칠하지만 가까운 친인척의 인삿말이라 너그럽게 이해하고 삽시다라고 썼다. '

# %%
df.loc[0].text
# Out:
# '코로나 환자 늘어 일반 중환자 치료 공백 코로나 바이러스 확산으로 위중증 환자가 급격히 늘어나자 의료 인력이 코로나 치료에 집중하면서 일반 중환자 대처에 차질이 생기고 있다. 의료 현장에서는 “코로나 확산으로 암 환자 등 일반 중환자 치료에 공백이 생기고 있다”는 목소리가 나온다. 18일 김범석 서울대 혈액종양내과 교수팀이 2019~2020년 서울대병원에서 사망한 암 환자 1456명을 분석한 결과 2019년 서울대병원 응급실에서 세상을 떠난 암 환자는 53명에서 2020년 99명으로 약 86% 대폭 증가한 것으로 나타났다. 말기 암 환자의 응급실 체류 시간도 늘었고, 환자의 생존을 위해 강제로 혈압을 높이는 승압제를 사용한 환자 수도 52.3%에서 59.2%로 약 7%포인트 늘었다. 심폐소생술을 받은 암 환자도 12.5%에서 16.3%로 증가했다. 김 교수는 “코로나 환자도 중요하지만, 이 때문에 소외된 환자들이 방치되고 있다는 사실을 알아야 한다”고 말했다.'

# %%
df.loc[191255].text
# Out:
# '‘명절 단골 질문 뭐 어때’ 이준석에 “언제 당선되실래요?” 이준석 바른미래당 최고위원이 추석연휴기간 올린 페이스북 글 때문에 곤혹을 치르고 있다. 이 최고위원은 지난 23일 페이스북에 “꼭 명절이 아니더라도 오랜만에 만난 친구들 사이에도 요즘 누구 만나니, 결혼은 안하니, 요즘 회사 잘 다니니, 애는 안 낳니 등등은 종종 물어보는 주제”라며 “그런데 1년에 한두번 만나기도 어려운 친척들이 궁금해서 물어볼 수도 있는 걸 궁금해도 안물어보는 것이 사회적으로 ‘예의’인 것처럼 만들어 가고 있다. 나는 오히려 그런 문화가 불편하다. 오랜만에 만나면 좀 물어볼 수도 있지”라고 주장했다. 이 최고위원의 주장에 반응은 뜨거웠다. “언제 당선되시나요”, “언제 정계은퇴 하시네요”, “언제 여당 되실래요”, “박근혜 면회 갔다 왔나요”, “바른미래당 재정상태가 어떤가요”라는 등의 댓글이 달렸다. 명절 때 아무렇지 않게 하는 질문들이 당사자에게 상처가 될 수 있다는 것을 이준석 최고위원의 상황에 대한 질문을 통해 꼬집는 내용이다. 명절 때마다 일상적인 질문이라고 묻는 결혼, 출산, 취업 등의 내용이 당사자에게 상처로 돌아올 수 있다는 비판이 제기돼왔고, 세대 갈등으로도 확산될 수 있어 조심하자는 분위기가 형성돼 있는데 이 최고위원의 주장은 불에 기름을 얹은 꼴이 된 셈이다. 이 최고위원의 주장에 공감하는 의견도 있지만 누리꾼들은 이 최고위원이 보편적인 사회 정서를 이해하지 못하고 있다면서 비난하는 모습이다. 한 누리꾼이 “말씀하신 질문들이 평소에도 하면 실례인 질문”이라고 지적하자 이에 공감하는 댓글들이 연이어 달렸다. 다른 누리꾼은 “단순한 애정과 관심으로 현 상태를 물어볼 수는 있으나 이에 대해 옳고 그름을 따지려하고 본인의 사상을 강요하려드니 문제”라고 지적했다. “돈 안주실거면 잔소리는 사양할게요”라며 쓰여진 ‘추석 잔소리 메뉴판’도 올라왔다. “너 반에서 몇등하니?”, “대학은 어디 갈 거니?”, “취업은 도대체 언제 하는거니?”, “그 회사 비전은 있나?”, 
# ...

# %%
index = 3
count = 0
for idx in range(len(summaries[index]) - 1) :
    if summaries[index][idx] == summaries[index][idx+1] :
        print(idx, idx+1)
        count += 1
        
print(count)
# Out:
# 157 158
# 391 392
# 656 657
# 1183 1184
# 1383 1384
# 1534 1535
# 1895 1896
# 2012 2013
# 2072 2073
# 2190 2191
# 2292 2293
# 2372 2373
# 2550 2551
# 2704 2705
# 2842 2843
# 2860 2861
# 2987 2988
# 3363 3364
# 4066 4067
# 4758 4759
# 5126 5127
# 5676 5677
# 5876 5877
# 6514 6515
# 7401 7402
# 8897 8898
# 8908 8909
# 8925 8926
# 9347 9348
# 9365 9366
# 9401 9402
# 9513 9514
# 9661 9662
# 10277 10278
# 10315 10316
# 10695 10696
# 10808 10809
# 11059 11060
# 11439 11440
# 11827 11828
# 12024 12025
# 12084 12085
# 12322 12323
# 12399 12400
# 13014 13015
# 13405 13406
# 13441 13442
# 13491 13492
# 14144 14145
# 15106 15107
# 15493 15494
# 16083 16084
# 17196 17197
# 17395 17396
# 17529 17530
# 17702 17703
# 18187 18188
# 18401 18402
# 18576 18577
# 18593 18594
# 18827 18828
# 19054 19055
# 19082 19083
# 19479 19480
# 19903 19904
# 20542 20543
# 20681 20682
# 21060 21061
# 21509 21510
# 21646 21647
# 21652 21653
# 22417 22418
# 22861 22862
# 23800 23801
# 23970 23971
# 25204 25205
# ...

# %%
len(summaries[3])
# Out:
# 191258

# %%
range(191259)
# Out:
# range(0, 191259)

# %%
count = 0
start = 191256*3
for idx in range(start, start+191256) :
    if df.loc[idx].text == df.loc[idx+1].text :
        print(idx, idx+1, idx-start, idx+1-start)
        count += 1
        
print(count)
# Out:
# 573925 573926 157 158
# 574159 574160 391 392
# 574951 574952 1183 1184
# 575151 575152 1383 1384
# 575302 575303 1534 1535
# 575663 575664 1895 1896
# 575780 575781 2012 2013
# 575840 575841 2072 2073
# 575958 575959 2190 2191
# 576060 576061 2292 2293
# 576140 576141 2372 2373
# 576318 576319 2550 2551
# 576472 576473 2704 2705
# 576610 576611 2842 2843
# 576628 576629 2860 2861
# 576755 576756 2987 2988
# 577131 577132 3363 3364
# 577834 577835 4066 4067
# 578526 578527 4758 4759
# 578894 578895 5126 5127
# 579444 579445 5676 5677
# 579644 579645 5876 5877
# 580282 580283 6514 6515
# 581169 581170 7401 7402
# 582665 582666 8897 8898
# 582676 582677 8908 8909
# 582693 582694 8925 8926
# 583115 583116 9347 9348
# 583133 583134 9365 9366
# 583169 583170 9401 9402
# 583281 583282 9513 9514
# 583429 583430 9661 9662
# 584045 584046 10277 10278
# 584083 584084 10315 10316
# 584463 584464 10695 10696
# 584576 584577 10808 10809
# 584827 584828 11059 11060
# 585207 585208 11439 11440
# ...

# %%
summaries[3][132232]
# Out:
# '서울에서 중형 아파트 전세 보증금을 마련하려면 월급을 5년동안 한 푼도 쓰지 않고 모아야 가능한 것으로 나타났으며 강남 지역 전셋집을 원한다면 7년 이상 걸리는 것으로 조사되었다. 최근 몇년간 주택 구매 수요는 줄고 전세 수요는 늘면서 전셋값이 고공행진을 하고 있다. 부동산정보업체 리얼투데이는 서울 지역 전용면적 84m2 아파트의 평균 전셋값은 2억4893만원으로 조사됐다고 25일 밝혔으며 강남구 전셋집은 7.3년이 걸리는 것으로 나타났다. '

# %%
summaries[3][132233]
# Out:
# '서울에서 중형 아파트 전세 보증금을 마련하려면 월급을 5년동안 한 푼도 쓰지 않고 모아야 가능한 것으로 나타났으며 강남 지역 전셋집을 원한다면 7년 이상 걸리는 것으로 조사되었다. 최근 몇년간 주택 구매 수요는 줄고 전세 수요는 늘면서 전셋값이 고공행진을 하고 있다. 부동산정보업체 리얼투데이는 서울 지역 전용면적 84m2 아파트의 평균 전셋값은 2억4893만원으로 조사됐다고 25일 밝혔으며 강남구 전셋집은 7.3년이 걸리는 것으로 나타났다. '

# %%
summaries[3][132234]
# Out:
# '(재)대구문화재단은 2020년도 통합문화이용권(문화누리카드)사업 우수기관 및 우수사례 공모전에서 우수로 선정되었는데, 이번 공모전을 통해 코로나19 상황에도 불구하고 문화격차 완화를 위한 대구 통합문화 이용권은 전방위적인 노력에 대한 긍정적인 평가를 받았다. 특히 코코나19로 인해 전년대비 이용률이 10% 이상 감소했고, 특히 문화·관광 분야가 대폭 감소한 점을 분석하여 기획된 특별여행주간 : 슬기로운 대구문화여행을 떠나요(이하 프로그램)로 우수에 선정되었다. '

# %%
df.loc[start+132232].text
# Out:
# '서울 전셋집 구하려면 월급 5년치 꼬박 모아야 서울에서 중형 아파트 전세 보증금을 마련하려면 월급을 5년동안 한 푼도 쓰지 않고 모아야 가능한 것으로 나타났다. 강남 지역 전셋집을 원한다면 7년 이상 걸린다. 부동산정보업체 리얼투데이는 서울 지역 전용면적 84㎡ 아파트의 평균 전셋값은 2억4893만원으로 조사됐다고 25일 밝혔다. 지난해 3인 가구 기준 도시근로자 월 평균 소득이 425만원인 것을 감안하면 월급을 모두 저축하더라도 전세금 마련에 4.9년이 걸리는 셈이다. 최근 몇년간 주택 구매 수요는 줄고 전세 수요는 늘면서 전셋값이 고공행진을 하고 있다. 올해도 서울 지역 아파트 3.3㎡당 전셋값은 1월 807만원에서 이달 829만원으로 2.7% 올랐다. 84㎡ 아파트 전세금을 모으는데 걸리는 시간도 같은 기간 4.7년에서 4.9년으로 늘어났다. 특히 서초구는 84㎡ 아파트 평균 전셋값이 3억7785만원에 이르러 7.4년간 월급을 모아야 하는 것으로 나타났다. 서초구는 올 한해동안 전셋값이 5.9% 뛰어올라 서울 지역 25개 구 중에서 가장 높은 상승률을 보였다. 강남구도 84㎡ 전셋값이 3억7289만원으로 전세금을 모으는데 7.3년이 걸린다. 반면 금천구의 경우 84㎡ 전셋값이 1억7157만원으로 3.4년치 월급이면 전셋집을 구할 수 있는 것으로 조사됐다. 내년 초 전세난은 더욱 심화될 것으로 우려된다. 리얼투데이 조사를 보면 내년 1월 전국 입주 예정 아파트는 6217가구로 올해 1월 1만3526가구의 절반에도 못 미치는 것으로 나타났다. 양지영 리얼투데이 팀장은 “월급을 한 푼도 안 쓰고 살 수는 없기 때문에 서울에서 전세금을 모으는 데 10년 이상 걸린다고 봐야 한다”면서 “매매 시장이 회복될만한 계기가 마련되기 어렵고 내년에 입주 물량이 줄어들기 때문에 전셋값 부담은 가중될 것으로 보인다”고 말했다.'

# %%
df.loc[start+132233].text
# Out:
# '대구문화재단, 통합문화이용권 우수기관 선정 (재)대구문화재단(대표이사 이승익, 이하 재단)은 2020년도 통합문화이용권(문화누리카드)사업 우수기관 및 우수사례 공모전에서 ‘우수’로 선정됐다. 기관평가 및 공모전은 한국문화예술위원회의 주최로 지역주관처 17개와 문화누리카드 담당자(광역·기초지자체, 주민센터, 지역주관처)를 대상으로 했다. 2019년 첫 시행된 지역주관처 평가 최우수상 수상에 이어, 올해는 기관평가와 이용활성화 우수사례 공모전에서도 ‘우수’를 수상했다. 이번 기관평가 및 공모전을 통해 코로나19 상황에도 불구하고 문화격차 완화를 위한 대구 통합문화이용권은 전방위적인 노력에 대한 긍정적인 평가를 받았다. 올해는 전국이 코로나19로 발급 및 집행률이 현저히 감소한 상황과 더불어 대구의 경우 2월 집단 확진자 발생으로 인해 더욱이 어려움을 겪었다. 그러나 재단은 발 빠른 대응으로 지역주관처 중 제일 먼저 비대면 발급을 독려하여 전화결제 가맹점 16개, 신규가맹점 98개를 발굴하였다. 우수사례 공모전은 코로나19로 문화·관광·체육 활동 등이 위축된 가운데 자발적 혹은 타 기관과의 협력을 통해 추진한 사례로 전국 문화누리 담당자를 대상으로 하였으며, 재단은 7월에 추진한 ‘특별여행주간 : 슬기로운 “대구문화여행”을 떠나요(이하 프로그램)’로 우수에 선정됐다. 이 프로그램은 코로나19로 인해 전년대비 이용률이 10% 이상 감소했고, 특히 문화·관광 분야가 대폭 감소한 점을 분석하여 기획됐다. 문화누리카드를 통해 코로나블루를 이겨내자는 취지로 지역 문화예술기관 및 가맹점과 논의하여 테마별 문화활동 기반 코스를 개발하여 추진했다. 재단은 기관평가 부분에서도 2019년 이용률 기준 광역시 중 가장 높은 이용률로 마감하였으며, 올해도 문화누리카드 지원금 자동소멸을 방지하고자 ‘빵빵한 잔액소진 이벤트’를 추진하고 있다. 한편, ‘빵빵한 잔액소진 이벤트’와 더불어 여행과 문화체험 분야의 기획상품을 추가 발굴하여 매주 화요일마다 카카오톡(ID:대구문화누리카드)을 통
# ...

# %%
summaries[3].pop(132233)
# Out:
# '서울에서 중형 아파트 전세 보증금을 마련하려면 월급을 5년동안 한 푼도 쓰지 않고 모아야 가능한 것으로 나타났으며 강남 지역 전셋집을 원한다면 7년 이상 걸리는 것으로 조사되었다. 최근 몇년간 주택 구매 수요는 줄고 전세 수요는 늘면서 전셋값이 고공행진을 하고 있다. 부동산정보업체 리얼투데이는 서울 지역 전용면적 84m2 아파트의 평균 전셋값은 2억4893만원으로 조사됐다고 25일 밝혔으며 강남구 전셋집은 7.3년이 걸리는 것으로 나타났다. '

# %%
summaries[0][4001]
# Out:
# '방역당국이 최근 김부겸 국무총리의 사적모임 제한 조치 위반 사건에 대해 사실 여부를 파악 중이라며 법에 따라 신속하게 조치하겠다는 입장을 밝혔고 이 제1통제관은 사실 여부가 잘 밝혀지게 되면 법에 따라 신속히 조치하도록 할 것이라고 밝혔다. 중대본 본부장인 김부엉 총리의 방역수칙 위반에 대한 방역당국의 입장이 궁금하다는 출입기자단 질문에 이같이 답했다. 방역당국이 김부총리의 방역위반 여부, 사실 여부를 확인 중이라며 법 따라 신속하게 처리하겠다는 입장을 밝혔다. '

# %%
len(summaries[1])
# Out:
# 191256

# %%
len(summaries[0])
# Out:
# 191256

# %%
len(summaries[2])
# Out:
# 191256

# %%
len(summaries[3])
# Out:
# 191258

# %%
191256*3 + 191258
# Out:
# 765026

# %%
df.loc[765025].text
# Out:
# "동부증권 `동부990` `모바일앱 DOMA` 동부증권이 사회 초년생들에게 부담없는 비용과 접근성으로 주식투자를 시작할 수 있는 금융상품을 내놨다. 한 달에 990원만 내면 추가 수수료 없이 주식거래를 마음대로 할 수 있는 ’동부990’서비스와 휴대폰으로 일상에서 주식 얘기를 나눌 수 있는 ’DOMA’가 그것이다. 동부990은 매월 거래금액 1억원까지 주식 매매를 몇 번 하더라도 수수료를 990원만 내면 되는 서비스다. 매매할 때마다 과금되는 기존 수수료체계와 달리 매월 초 지불 한 번으로 자유롭게 주식을 거래할 수 있다. 단 월 1억원을 넘어설 경우 초과 금액에 대해 기존 수수료율(0.099164%)이 적용된다. 유관기관 수수료는 별도 적용된다. 동부990 정액제로 월 1억원을 거래한다면 업계 최저 수수료율(0.01%)보다 27% 수수료 절감이 가능하다. 동부990에 가입하면 모바일트레이딩 시스템(MTS)뿐만 아니라 홈트레이딩시스템(HTS), 홈페이지 주식 거래도 같은 수수료율을 적용 받는다. 이용 매체에 구애받지 않아 고객 편의성이 한층 높아진 셈이다. 동부증권측은 '많은 소액투자자들이 수수료 부담 때문에 기간 한정 무료 수수료 이벤트를 쫓는 현실에 착안했다'고 설명했다. 아울러 소셜주식앱인 DOMA는 주식이라는 콘텐츠를 내세우면서도 골치 아픈 숫자가 아닌 이미지와 이야기를 친구들과 공유할 수 있게 짜여졌다. 일상적인 사진 이미지에 관련 종목이 태그처리돼 있어 이를 페이스북, 트위터 등에서 공유하며 주식 관련 이야기를 다양하게 접할 수 있다."

# %%
summaries[3][-1]
# Out:
# "동부증권이 사회 초년생들에게 부담없는 비용과 접근성으로 주식투자를 시작할 수 있는 금융상품을 내놓았는데 매월 거래금액 1억원까지 주식 매매를 몇 번 하더라도 수수료를 990원만 내면 되는 동부990서비스와 휴대폰으로 일상에서 주식 얘기를 나눌 수 있는 DOMA가 그것이다. 동부증권측은 '많은 소액투자자들이 수수료 부담 때문에 기간 한정 무료 수수료 이벤트를 쫓는 현실에 착안했다'고 설명했다. 또한 소셜주식앱인 DOMA는 주식이라는 콘텐츠를 내세우면서도 골치 아픈 숫자가 아닌 이미지와 이야기를 친구들과 공유할 수 있게 짜여졌다. "

# %%
df_half = df.loc[:765025]

# %%
len(df_half)
# Out:
# 765026

# %%
df_half.loc[765025].text
# Out:
# "동부증권 `동부990` `모바일앱 DOMA` 동부증권이 사회 초년생들에게 부담없는 비용과 접근성으로 주식투자를 시작할 수 있는 금융상품을 내놨다. 한 달에 990원만 내면 추가 수수료 없이 주식거래를 마음대로 할 수 있는 ’동부990’서비스와 휴대폰으로 일상에서 주식 얘기를 나눌 수 있는 ’DOMA’가 그것이다. 동부990은 매월 거래금액 1억원까지 주식 매매를 몇 번 하더라도 수수료를 990원만 내면 되는 서비스다. 매매할 때마다 과금되는 기존 수수료체계와 달리 매월 초 지불 한 번으로 자유롭게 주식을 거래할 수 있다. 단 월 1억원을 넘어설 경우 초과 금액에 대해 기존 수수료율(0.099164%)이 적용된다. 유관기관 수수료는 별도 적용된다. 동부990 정액제로 월 1억원을 거래한다면 업계 최저 수수료율(0.01%)보다 27% 수수료 절감이 가능하다. 동부990에 가입하면 모바일트레이딩 시스템(MTS)뿐만 아니라 홈트레이딩시스템(HTS), 홈페이지 주식 거래도 같은 수수료율을 적용 받는다. 이용 매체에 구애받지 않아 고객 편의성이 한층 높아진 셈이다. 동부증권측은 '많은 소액투자자들이 수수료 부담 때문에 기간 한정 무료 수수료 이벤트를 쫓는 현실에 착안했다'고 설명했다. 아울러 소셜주식앱인 DOMA는 주식이라는 콘텐츠를 내세우면서도 골치 아픈 숫자가 아닌 이미지와 이야기를 친구들과 공유할 수 있게 짜여졌다. 일상적인 사진 이미지에 관련 종목이 태그처리돼 있어 이를 페이스북, 트위터 등에서 공유하며 주식 관련 이야기를 다양하게 접할 수 있다."

# %%
summary = summaries[0] + summaries[1] + summaries[2] + summaries[3]

# %%
len(summary)
# Out:
# 765026

# %%
summary[0]
# Out:
# '코로나 바이러스 확산으로 위중증 환자가 급격히 늘어나자 의료 인력이 코코나 치료에 집중하면서 일반 중환자 대처에 차질이 생기고 있어 의료 현장에서는 코로나 확산으로 암 환자 등 일반중환자 치료에 공백이 생기고 있다는 목소리가 나오고 있다. 의료 현장에서 김 교수는 이 때문에 소외된 환자들이 방치되고 있다는 사실을 알아야 한다고 말했다. 김 교수는 코로나가 환자도 중요하지만, 이 때문에 소외되는 환자들이 방치되는 사실을 알아야 한다고 말했다.  '

# %%
df_half.loc[0].text
# Out:
# '코로나 환자 늘어 일반 중환자 치료 공백 코로나 바이러스 확산으로 위중증 환자가 급격히 늘어나자 의료 인력이 코로나 치료에 집중하면서 일반 중환자 대처에 차질이 생기고 있다. 의료 현장에서는 “코로나 확산으로 암 환자 등 일반 중환자 치료에 공백이 생기고 있다”는 목소리가 나온다. 18일 김범석 서울대 혈액종양내과 교수팀이 2019~2020년 서울대병원에서 사망한 암 환자 1456명을 분석한 결과 2019년 서울대병원 응급실에서 세상을 떠난 암 환자는 53명에서 2020년 99명으로 약 86% 대폭 증가한 것으로 나타났다. 말기 암 환자의 응급실 체류 시간도 늘었고, 환자의 생존을 위해 강제로 혈압을 높이는 승압제를 사용한 환자 수도 52.3%에서 59.2%로 약 7%포인트 늘었다. 심폐소생술을 받은 암 환자도 12.5%에서 16.3%로 증가했다. 김 교수는 “코로나 환자도 중요하지만, 이 때문에 소외된 환자들이 방치되고 있다는 사실을 알아야 한다”고 말했다.'

# %%
df_half['summary'] = summary
# Out:
# /tmp/ipykernel_1554202/2908309106.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_half['summary'] = summary

# %%
df_half.loc[:10]
# Out:
#                       id topic  \
# 0   NWRW2200000004.11879     P
# 1   NWRW1900000015.17529     P
# 2    NWRW1900000054.4560     P
# 3   NWRW2200000004.12649     P
# 4   NWRW1900000017.11178     P
# 5    NWRW1900000015.4072     P
# 6    NPRW2100000003.6303     P
# 7   NPRW1900000055.31119     P
# 8    NWRW1900000034.5678     P
# 9   NWRW1900000019.14197     P
# 10   NWRW2200000004.2885     P
#
#                                                  text  ksic  max_scores  \
# 0   코로나 환자 늘어 일반 중환자 치료 공백 코로나 바이러스 확산으로 위중증 환자가 급...  c271    0.462100
# 1   靑 “휴가때 골프 꼭 치고 싶으면 자비로 쳐라” 허태열 대통령비서실장이 최근 수석비...  c333    0.438204
# 2   이계안 “정몽준, 현대중 광고로 불법선거운동” 현대그룹 전문경영인 출신의 이계안 민...  c311    0.423902
# 3   인기끄는 포도·딸기… 바나나는 시들 소비자 입맛과 취향이 변하면서 대형 마트 인기 ...  c103    0.412846
# 4   울산 현대重 찾은 모디 “조선업 파트너 돼달라” “야드(선박 건조장)가 내려다보이는...  c311    0.397418
# 5   농업분야 저서 10여권… “農心과 30년” 농림축산부 장관 후보자로 내정된 이동필 ...  c103    0.395620
# 6   안철수 "마스크 값만 월 60만원…6,500원짜리 마저도 품절" 안철수 국민의당 대...  c271    0.394926
# ...

# %%
df_summary.loc[:10]
# Out:
#                       id topic  \
# 0   NLRW1900000024.16590     S
# 1   NWRW1900000009.21980     S
# 2   NLRW1900000144.10274     S
# 3   NLRW2200000008.12137     S
# 4    NWRW1900000011.9505     S
# 5    NLRW1900000023.2202     S
# 6    NLRW2200000015.8183     S
# 7   NLRW2000000014.29543     S
# 8   NPRW2000000003.10588     S
# 9   NWRW1900000015.22167     S
# 10  NWRW2000000003.28936     S
#
#                                                  text  ksic  max_scores  \
# 0   1221m 초콜릿 파이 “3만명이 함께 먹을 수 있어” 1221m 초콜릿 파이가 등...  c107    0.930233
# 1   고등어야, 어디 있니? 어획량 20년 새 3분의 1로 국내산 고등어 어획량이 20년...  c102    0.718052
# 2   고령 우곡 농민들 "올해 수박농사 빈손…막막할 뿐" 이상기후 물량 줄고 품질 떨어져...  c103    0.639269
# 3   태안군, 해풍을 맞고 자란 명품 양파 수확 ‘한창!’ 태안의 비옥한 황토에서 갯바람...  c103    0.612410
# 4   친환경 농산물 약진… 생산량 10% 넘어 국내에서 생산되는 농산물 10개 가운데 1...  c103    0.588431
# 5   강화군, 친환경 영농 조례 추진 강화군이 친환경 농업에 대한 지원을 늘린다. 군은 ...  c103    0.585025
# 6   청주서 친환경 복숭아 첫 수확 청주시는 이달부터 유기농마케팅센터 내 친환경 로컬푸드...  c103    0.580181
# ...

# %%
len(df2)
# Out:
# 1530052

# %%
df_half.columns
# Out:
# Index(['id', 'topic', 'text', 'ksic', 'max_scores', 'summary'], dtype='object')

# %%
df_summary.columns
# Out:
# Index(['id', 'topic', 'text', 'ksic', 'max_scores', 'summary'], dtype='object')

# %%
df_summary = df_summary.rename(columns = {'summary_new': 'summary'})

# %%
df2 = pd.concat([df_half, df_summary], axis=0)

# %%
df2[-71580:-71560]
# Out:
#                           id topic  \
# 693446   NPRW2200000005.1193     T
# 693447   NPRW2200000005.3709     T
# 693448  NIRW2200000001.35388     T
# 693449   NPRW1900000046.1183     T
# 693450   NWRW1900000009.9259     T
# 693451   NPRW1900000006.1753     T
# 693452    NIRW1900000019.238     T
# 693453  NPRW2000000004.25821     T
# 693454    NPRW1900000008.482     T
# 693455  NPRW1900000070.22010     T
# 693456   NLRW2100000001.3679     T
# 693457    NPRW1900000049.342     T
# 693458  NWRW1900000051.17354     T
# 693459    NIRW1900000012.936     T
# 693460   NPRW2100000007.9546     T
# 693461  NPRW2100000007.18171     T
# 693462    NIRW2000000002.907     T
# 693463   NPRW1900000068.9286     T
# 693464  NPRW1900000054.17862     T
# 693465   NIRW1900000029.8638     T
#
#                                                      text  ksic  max_scores  \
# 693446  [아주경제 코이너스 브리핑] 금융보안원, AI·IoT·인증기술·블록체인 보안취약점 ...  c272    0.018586
# ...

# %%
df2 = df2.reset_index(drop=True)

# %%
df2.to_csv('/home/osung/data/korean/modu/json/news_PEST_ksic_score_summary.tsv', sep='\t', index=False)

# %%
count = 0
for idx in range(len(df2)) :
    if df2.loc[idx].summary == df2.loc[idx+1].summary :
        print(idx, idx+1)
        count += 1
        
print(count)
# Out:
# 1262 1263
# 2120 2121
# 6242 6243
# 7130 7131
# 7415 7416
# 7540 7541
# 7822 7823
# 8106 8107
# 10708 10709
# 14029 14030
# 14580 14581
# 17519 17520
# 18014 18015
# 18579 18580
# 19494 19495
# 19739 19740
# 23784 23785
# 23945 23946
# 25344 25345
# 27981 27982
# 30568 30569
# 31072 31073
# 31172 31173
# 32075 32076
# 32190 32191
# 33111 33112
# 33359 33360
# 36958 36959
# 37346 37347
# 38441 38442
# 40652 40653
# 40658 40659
# 43031 43032
# 43178 43179
# 43262 43263
# 44389 44390
# 44989 44990
# 45187 45188
# 45192 45193
# 48665 48666
# 48793 48794
# 49477 49478
# 50337 50338
# 50959 50960
# 51014 51015
# 51669 51670
# 51958 51959
# 52462 52463
# 52861 52862
# 52978 52979
# 53508 53509
# 53541 53542
# 53926 53927
# 54329 54330
# 54475 54476
# 54804 54805
# 54983 54984
# 55319 55320
# 56554 56555
# 58210 58211
# 59289 59290
# 61334 61335
# 61376 61377
# 61960 61961
# 62107 62108
# 62342 62343
# 63623 63624
# 63716 63717
# 64522 64523
# 66141 66142
# 67651 67652
# 68368 68369
# ...

# %%
df_cleaned = df2.loc[df2['summary'].shift() != df2['summary']]

# %%
len(df_cleaned)
# Out:
# 1527056

# %%
len(df2)
# Out:
# 1530052

# %%
df_cleaned = df_cleaned.reset_index(drop=True)

# %%
count = 0
for idx in range(len(df_cleaned)-1) :
    if df_cleaned.loc[idx].summary == df_cleaned.loc[idx+1].summary :
        print(idx, idx+1)
        count += 1
        
print(count)
# Out:
# 0

# %%
df_cleaned.to_csv('/home/osung/data/korean/modu/json/news_PEST_ksic_score_summary_no_dup.tsv', sep='\t', index=False)

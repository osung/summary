# %%
import pandas as pd
import numpy as np

# %%
from konlpy.tag import Okt
from collections import Counter

# %%
from tqdm import tqdm

# %%
import pickle

# %%
def parse_text_file(file_path):
    result_dict = {}

    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            # 줄의 앞뒤 공백 제거
            line = line.strip()

            # C?? 형식의 코드와 나머지 문자열 분리
            if line:
                parts = line.split(' ', 1)  # 첫 번째 공백으로 나눔
                
                if len(parts) == 2:
                    key = parts[0]
                    values = parts[1].split(',')  # 쉼표와 공백으로 구분하여 리스트 생성
                    result_dict[key] = values

    return result_dict

# %%
def get_ksic_code(file_path):
    ksic_dict = {}

    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            # 줄의 앞뒤 공백 제거
            line = line.strip()

            # C?? 형식의 코드와 나머지 문자열 분리
            if line:
                parts = line.split(' ', 1)  # 첫 번째 공백으로 나눔
                ksic_dict[parts[0]] = parts[1]

    return ksic_dict

# %%
def extract_nouns_and_count(text):
    # Okt 형태소 분석기 객체 생성
    okt = Okt()
    
    # 텍스트에서 명사 추출
    nouns = okt.nouns(text)
    
    # 명사의 등장 횟수를 세어 dict로 변환
    noun_count = dict(Counter(nouns))
    
    sorted_noun_count = dict(sorted(noun_count.items(), key=lambda item: item[1], reverse=True))
    
    return sorted_noun_count

# %%
def get_KSIC(keyword) :
    keys_with_value = []
    
    for key, value_list in KSIC_keyword.items():
        if keyword in value_list:
            keys_with_value.append(key)
            
    return keys_with_value

# %%
file_path = '/home/osung/data/korean/KSIC_keyword.txt'

# %%
KSIC_keyword = parse_text_file(file_path)

# %%
type(KSIC_keyword)
# Out:
# dict

# %%
KSIC_keyword.keys()
# Out:
# dict_keys(['c101', 'c102', 'c103', 'c104', 'c105', 'c106', 'c107', 'c108', 'c111', 'c112', 'c120', 'c131', 'c132', 'c133', 'c134', 'c139', 'c141', 'c142', 'c143', 'c144', 'c151', 'c152', 'c161', 'c162', 'c163', 'c171', 'c172', 'c179', 'c181', 'c182', 'c191', 'c192', 'c201', 'c202', 'c203', 'c204', 'c211', 'c212', 'c213', 'c221', 'c222', 'c231', 'c232', 'c233', 'c239', 'c241', 'c242', 'c243', 'c251', 'c252', 'c259', 'c261', 'c262', 'c263', 'c264', 'c265', 'c266', 'c271', 'c272', 'c273', 'c274', 'c281', 'c282', 'c283', 'c284', 'c285', 'c289', 'c291', 'c292', 'c301', 'c302', 'c303', 'c304', 'c311', 'c312', 'c313', 'c319', 'c320', 'c331', 'c332', 'c333', 'c334', 'c339', 'c340'])

# %%
get_KSIC('공격')
# Out:
# ['c313', 'c319']

# %%
KSIC_keyword['c319']
# Out:
# ['오토바이',
#  '스쿠터',
#  '차량',
#  '모빌리티',
#  '장갑차',
#  '전차',
#  '탱크',
#  '전투용',
#  '사이클',
#  '사이드카',
#  '이륜자동차',
#  '실버카',
#  '유모차',
#  '손수레',
#  '리어카',
#  '우마차',
#  '쇼핑카트',
#  '전쟁',
#  '군수',
#  '공격',
#  '발포']

# %%
combined_keywords = []

# %%
for key in KSIC_keyword :
    combined_keywords.extend(KSIC_keyword[key])

# %%
combined_keywords
# Out:
# ['도축장',
#  '도축',
#  '축산물',
#  '도축업',
#  '도축',
#  '육류',
#  '한우',
#  '냉동',
#  '토종닭',
#  '축산',
#  '마리',
#  '사육',
#  '고래고기',
#  '햄',
#  '소시지',
#  '선지',
#  '소고기',
#  '돼지고기',
#  '양고기',
#  '오리고기',
#  '닭고기',
#  '훈제',
#  '닭가슴살',
#  '닭발',
#  '닭갈비',
#  '닭꼬치',
#  '양꼬치',
#  '돈까스',
#  '돈가스',
#  '족발',
#  '갈비',
#  '베이컨',
#  '편육',
#  '생산량',
#  '쇠고기',
#  '농민',
#  '농가',
#  '고기',
#  '광우병',
#  '귀농',
#  '농촌',
#  '돼지',
#  '한돈',
#  '불고기',
#  '식품',
#  '수산물',
#  '양식',
#  '수산',
#  '광어',
#  '항만',
#  '해조',
#  '어란',
#  '어육',
#  '캐비어',
#  '어묵',
#  '젓갈',
#  '생선통조림',
#  '생선페이스트',
#  '건어물',
#  '오징어',
#  '우럭',
#  '도미',
#  '도다리',
#  '가자미',
#  '갈치',
#  '고등어',
#  '멍게',
#  '해삼',
#  '굴',
#  '석화',
#  '조개',
#  '가리비',
#  '키조개',
#  '참돔',
#  '돌돔',
#  '줄돔',
#  '방어',
#  '쥐포',
#  '먹태',
#  '황태',
#  '게장',
#  '맛살',
#  '생선가스',
#  '생선까스',
#  '액젓',
#  '북어채',
#  '황태채',
#  '미역',
#  '김부각',
#  '구운김',
#  '조미김',
#  '생선',
#  '김',
#  '수확',
#  '생산량',
#  '어장',
#  '어민',
#  '아구',
#  '아귀',
#  '어선',
#  '어업',
#  '바지락',
#  '어촌',
#  '어업인',
#  '멸치액젓',
#  '멸치',
#  '주꾸미',
#  '어획량',
#  '남해안',
#  '서해안',
#  '동해안',
#  '수중',
#  '백합',
#  '대합',
#  '생합',
#  '식품',
#  '농업',
#  '농가',
#  '농산물',
#  '농협',
#  '식품',
#  '양파',
#  '마늘',
#  '과일',
#  '채소주스',
#  '과일주스',
#  '과채주스',
#  '알로에',
#  '과실주스',
#  '딸기잼',
#  '사과잼',
#  '포도잼',
#  '과일페이스트',
#  '과일통조림',
#  '과일샐러드',
#  '김치',
#  '단무지',
#  '건채소',
#  '건과일',
#  '장아찌',
#  '무쌈',
#  '쌈무',
#  '오이지',
#  '피클',
#  '감귤주스',
#  '녹즙',
#  '매실액',
#  '배즙',
#  '사과즙',
#  '감말랭이',
#  '고구마말랭이',
#  '채소',
#  '야채',
#  '배추',
#  '무',
#  '사과',
#  '복숭아',
#  '토마토',
#  '수박',
#  '참외',
#  '오이',
#  '양파',
#  '당근',
#  '귤',
#  '고구마',
#  '감자',
#  '옥수수',
#  '포도',
#  '딸기',
#  '키위',
#  '감',
#  '시금치',
#  '상추',
#  '피망',
#  '양배추',
#  '브로콜리',
#  '파프리카',
#  '자두',
#  '생산량',
#  '수확',
#  '농민',
#  '콩나물',
#  '나물',
#  '바나나',
#  '채식',
#  '비건',
#  '인삼',
#  '깻잎',
#  '친환경',
#  '유기농',
#  '하우스',
#  '출하',
#  '농업인',
#  '귀농',
#  '농사',
#  '농촌',
#  '농경지',
#  '쌀',
#  '보리',
#  '밀',
#  '양곡',
#  '가마니',
#  '콩',
#  '팥',
#  '농작물',
#  '농장',
#  '작물',
#  '영농',
#  '팜유',
#  '중유',
#  '정제유',
#  '음식물',
#  '두유',
#  '옥수수기름',
#  '피마자유',
#  '참기름',
#  '들기름',
#  '마가린',
#  '쇼트닝',
#  '올리브유',
#  '콩기름',
#  '채종유',
#  '유채유',
#  '마아가린',
#  '가공유',
#  '식품',
#  '낙농',
#  '낙농업',
#  '유업',
#  '유제품',
#  '우유',
#  '원유',
#  '생크림',
#  '탈지유',
#  '버터',
#  '치즈',
#  '발효유',
#  '농축유',
#  '연유',
#  '분유',
#  '유당',
#  '아이스크림',
#  '빙수',
#  '샤베트',
#  '요구르트',
#  '유산균음료',
#  '비피더스',
#  '식품',
#  '곡물',
#  '반죽',
#  '방앗간',
#  '제분소',
#  '제분',
#  '귀리',
#  '도정',
#  '정비',
#  '정미소',
#  '밀가루',
#  '콩가루',
#  '제분소',
#  '방앗간',
#  '만두피',
#  '떡고물',
#  '콘플레이크',
#  '글루텐',
#  '타피오카',
#  '이눌린',
#  '물엿',
#  '포도당',
#  '현미',
#  '찹쌀가루',
#  '옥수수가루',
#  '쌀가루',
#  '밀가루',
#  '앙금',
#  '식품',
#  '떡',
#  '빵',
#  '베이커리',
#  '과자',
#  '곡류',
#  '밀가루',
#  '스낵',
#  '술안주',
#  '파이',
#  '케이크',
#  '약과',
#  '비스킷',
#  '크래커',
#  '라이스페이퍼',
#  '설탕',
#  '사탕수수',
#  '코코아',
#  '초콜릿',
#  '메밀국수',
#  '당면',
#  '스파게티',
#  '마카로니',
#  '식초',
#  '후추',
#  '고추가루',
#  '계피가루',
#  '마요네즈',
#  '케첩',
#  '간장',
#  '고추장',
#  '된장',
#  '춘장',
#  '청국장',
#  '조미료',
#  '맛소금',
#  '누룩',
#  '베이킹파우더',
#  '효모',
#  '이스트',
#  '두부',
#  '커피',
#  '홍차',
#  '녹차',
#  '수프',
#  '유부',
#  '인삼차',
#  '인삼즙',
#  '홍삼차',
#  '도시락',
#  '피자',
#  '건강원',
#  '간편식',
#  '제일제당',
#  '한식',
#  '라면',
#  '농심',
#  '삼양',
#  '만두',
#  '인스턴트',
#  '즉석조리',
#  '식품',
#  '가공식품',
#  '죽염',
#  '장류',
#  '햇반',
#  '사료',
#  '사육',
#  '양돈',
#  '양계',
#  '배합',
#  '육골분',
#  '반려',
#  '동물',
#  '강아지',
#  '고양이',
#  '햄스터',
#  '관상어',
#  '개껌',
#  '배합사료',
#  '애완동물',
#  '애완동물사료',
#  '단미사료',
#  '주류',
#  '맥주',
#  '하이트진로',
#  '주정',
#  '소주',
#  '에탄올',
#  '탁주',
#  '위스키',
#  '꼬냑',
#  '브랜디',
#  '고량주',
#  '보드카',
#  '매실주',
#  '인삼주',
#  '오가피주',
#  '약주',
#  '막걸리',
#  '동동주',
#  '곡주',
#  '모주',
#  '포도주',
#  '와인',
#  '맥아',
#  '테라',
#  '캘리',
#  '카스',
#  '참이슬',
#  '처음처럼',
#  '발효주',
#  '청주',
#  '샴페인',
#  '복분자주',
#  '사케',
#  '정종',
#  '진로',
#  '하이트',
#  '식품',
#  '커피',
#  '음료',
#  '탄산',
#  '생수',
#  '삼다수',
#  '얼음',
#  '콜라',
#  '사이다',
#  '펩시',
#  '식혜',
#  '수정과',
#  '탄산음료',
#  '이온음료',
#  '섬유음료',
#  '인삼음료',
#  '과실음료',
#  '채소음료',
#  '두유',
#  '소다',
#  '코카콜라',
#  '칠성사이다',
#  '롯데칠성',
#  '동아오츠카',
#  '담배',
#  '궐련',
#  '필립',
#  '모리스',
#  '담뱃값',
#  '담뱃세',
#  '금연',
#  'bat',
#  'jti',
#  '담뱃잎',
#  '말보로',
#  '레종',
#  '에쎄',
#  '아이코스',
#  '전자담배',
#  '담배잎',
#  '시가',
#  '섬유',
#  '패브릭',
#  '방적',
#  '가공사',
#  '코튼',
#  '면사',
#  '견방사',
#  '견노일',
#  '혼방사',
#  '실크',
#  '마모사',
#  '섬수모사',
#  '조수모사',
#  '자수사',
#  '가연사',
#  '편물사',
#  '견재봉사',
#  '마사',
#  '코이어사',
#  '라미사',
#  '아바카사',
#  '사이잘마사',
#  '나일론',
#  '비스코스',
#  '아크릴사',
#  '직물',
#  '직조',
#  '광폭',
#  '침구',
#  '침구류',
#  '이불',
#  '혼수',
#  '타월',
#  '매트',
#  '포대',
#  '수건',
#  '혼방',
#  '인견',
#  '원단',
#  '인조섬유',
#  '종이직물',
#  '담요',
#  '침낭',
#  '방석',
#  '쿠션',
#  '커튼',
#  '블라인드',
#  '텐트',
#  '천막',
#  '천마스크',
#  '구명조끼',
#  '구명대',
#  '깃발',
#  '국기',
#  '휘장',
#  '보자기',
#  '섬유',
#  '편조',
#  '원단',
#  '니트',
#  '뜨게질',
#  '메리야스',
#  '편물',
#  '섬유',
#  '견편조',
#  '견편조물',
#  '면편조',
#  '면편조물',
#  '편조물',
#  '인조섬유',
#  '인조섬유편조물',
#  '섬유',
#  '염색',
#  '날염',
#  '원단',
#  '의류',
#  '표백',
#  '탈색',
#  '정련',
#  '호부처리',
#  '실',
#  '카펫',
#  '덮개',
#  '융단',
#  '양탄자',
#  '부직',
#  '부직포',
#  '마스크',
#  '필터',
#  '로프',
#  '끈',
#  '그물',
#  '어망',
#  '양파망',
#  '낚시망',
#  '줄사다리',
#  '펠트',
#  '타포린',
#  '캔버스',
#  '기저귀',
#  '생리대',
#  '냅킨',
#  '탐폰',
#  '템포',
#  '카페트',
#  '섬유',
#  '마루덮개',
#  '망',
#  '세폭직물',
#  '타이어코드',
#  '타이어직물',
#  '비닐도포직물',
#  '고무도포직물',
#  '워딩',
#  '솜',
#  '레이스',
#  '봉제',
#  '겉옷',
#  '속옷',
#  '한복',
#  '정장',
#  '양복',
#  '드레스',
#  '원피스',
#  '스커트',
#  '코트',
#  '슬립',
#  '브래지어',
#  '콜셋',
#  '거들',
#  '전통의상',
#  '블라우스',
#  '셔츠',
#  '체육복',
#  '반바지',
#  '재킷',
#  '잠바',
#  '유아복',
#  '아동복',
#  '청바지',
#  '턱시도',
#  '민속의상',
#  '방탄복',
#  '가운',
#  '수의',
#  '승복',
#  '우의',
#  '레인코트',
#  '의복',
#  '바지',
#  '치마',
#  '티셔츠',
#  '내복',
#  '보정의복',
#  '보정속옷',
#  '교복',
#  '운동복',
#  '유니폼',
#  '과잠',
#  '모피',
#  '밍크',
#  '편조',
#  '의류',
#  '스웨터',
#  '가디건',
#  '카디건',
#  '조끼',
#  '풀오버',
#  '저지',
#  '니트',
#  '나이트웨어',
#  '풀오버',
#  '의복',
#  '편직결합',
#  '양말',
#  '모자',
#  '장갑',
#  '악세서리',
#  '가죽',
#  '타이즈',
#  '스타킹',
#  '벙거지',
#  '넥타이',
#  '숄',
#  '쇼올',
#  '손수건',
#  '스카프',
#  '머플러',
#  '허리띠',
#  '벨트',
#  '의복',
#  '액세서리',
#  '목도리',
#  '혁대',
#  '가죽',
#  '가방',
#  '핸드백',
#  '지갑',
#  '캐리어',
#  '모피',
#  '시계',
#  '시곗줄',
#  '시계줄',
#  '명품',
#  '쇼핑백',
#  '등산가방',
#  '공구백',
#  '트렁크',
#  '캐리어',
#  '신발',
#  '구두',
#  '스니커즈',
#  '부츠',
#  '캐주얼',
#  '운동',
#  '슬리퍼',
#  '군화',
#  '제화공',
#  '제화',
#  '컨버스',
#  '짚신',
#  '발레슈즈',
#  '토슈즈',
#  '장화',
#  '레인부츠',
#  '운동화',
#  '실내화',
#  '단화',
#  '고무장화',
#  '샌달',
#  '등산화',
#  '고무신',
#  '목재',
#  '원목',
#  '제재',
#  '판재',
#  '침목',
#  '제재목',
#  '펠릿',
#  '집성재',
#  '일반재',
#  '목공물',
#  '마루판',
#  '우드몰딩',
#  '목모',
#  '목분',
#  '목재',
#  '목제품',
#  '합판',
#  '보드',
#  '마루',
#  '마루판',
#  '파렛',
#  '나투',
#  '스진',
#  '나투스',
#  '바닥재',
#  '블록보드',
#  '배튼보드',
#  '베니어패널',
#  '파이버보드',
#  '파티클보드',
#  '칩보드',
#  '셀룰라우드패널',
#  '지붕용패널',
#  '파켓트패널',
#  '케이블드럼',
#  '나무못',
#  '울타리',
#  '사다리',
#  '작업대',
#  '목제',
#  '나무',
#  '목관',
#  '단판',
#  '강화마루',
#  '파티클보드',
#  '중밀도섬유판',
#  'MDF',
#  '코르크',
#  '밀짚모자',
#  '새끼줄',
#  '매트',
#  '가마니',
#  '수세미',
#  '광주리',
#  '등나무',
#  '대나무',
#  '밀짚모자',
#  '망태기',
#  '와인마개',
#  '콜크',
#  '돗자리',
#  '코르크칩',
#  '다다미',
#  '방석',
#  '자리',
#  '야자',
#  '야자매트',
#  '마대',
#  '죽공예',
#  '공예',
#  '펄프',
#  '종이',
#  '판지',
#  '제지',
#  '가공지',
#  '인쇄용지',
#  '한솔제지',
#  '제지업',
#  '용지',
#  '페이퍼',
#  '백상지',
#  '아트지',
#  '감열지',
#  '원지',
#  '신문용지',
#  '셀룰로오스',
#  '크라프트지',
#  '넝마',
#  '벽지',
#  '레이어지',
#  '화장지',
#  '타월',
#  '골판지',
#  '상자',
#  '칸막이',
#  '택배',
#  '박스',
#  '포장',
#  '포장재',
#  '테이크아웃',
#  '배달',
#  '식품',
#  '용기',
#  '가방',
#  '한솔제지',
#  '종이컵',
#  '쇼핑백',
#  '종이봉지',
#  '식품백',
#  '보관함',
#  '서류받침',
#  '캐비닛',
#  '문구',
#  '위생',
#  '인테리어',
#  '벽지',
#  '여과',
#  '복사지',
#  '앨범',
#  '영수증',
#  '표지',
#  '커버',
#  '화장지',
#  '탐폰',
#  '기저귀',
#  '티슈',
#  '장판지',
#  '필터',
#  '스티커',
#  '라벨',
#  '바인더',
#  '카본지',
#  '휴지',
#  '템포',
#  '장판',
#  '벽지',
#  '포장지',
#  '인쇄',
#  '인쇄업',
#  '출판물',
#  '인쇄물',
#  '인쇄용지',
#  '인쇄술',
#  '프린트',
#  '프린팅',
#  '제판',
#  '도서',
#  '서적',
#  '제책',
#  '제본',
#  '재단',
#  '신문',
#  'pod',
#  '공판',
#  '마스타제판',
#  '단식옵셋',
#  '활판',
#  '음반',
#  '음악',
#  '오디오',
#  '비디오',
#  '플로피',
#  '디스크',
#  '복제',
#  '필름',
#  '전자책',
#  '오디오북',
#  '도서관',
#  'CD',
#  '디스켓',
#  '레코드',
#  '코크스',
#  '석탄',
#  '연탄',
#  '갈탄',
#  '토탄',
#  '타르',
#  '조개탄',
#  '레토르트카본',
#  '가공탄',
#  '응집탄',
#  '고체연료',
#  '알탄',
#  '석유',
#  '가스',
#  '원료',
#  '윤활유',
#  '윤활',
#  '그리스',
#  '원유',
#  '가솔린',
#  '경유',
#  '등유',
#  '나프타',
#  '정제',
#  '중유',
#  '정유',
#  '오일',
#  '주유소',
#  '배럴',
#  '유가',
#  '휘발유',
#  '연료',
#  '기름',
#  '액화천연가스',
#  '바이오디젤',
#  '유지',
#  '왁스',
#  '아스팔트',
#  'LPG',
#  '천연가스',
#  '비축량',
#  '화학',
#  '가스',
#  '산소',
#  '질소',
#  '수소',
#  '탄소',
#  '고압가스',
#  '탄산가스',
#  '석유',
#  '케미컬',
#  '화학제품',
#  '롯데케미칼',
#  '듀폰',
#  '분자',
#  'NMR',
#  'X선 회절법',
#  '유기화학',
#  '석유화학',
#  '천연수지',
#  '석탄화학',
#  '산업용 가스',
#  '기초 무기화학',
#  '염료',
#  '안료',
#  '착색제',
#  '유기질비료',
#  '합성유기유연제',
#  '에틸알콜',
#  '석유정제',
#  '글리세린',
#  '방향유',
#  '활성탄소',
#  '부동조제품',
#  '벤졸',
#  '톨루올',
#  '피치코크스',
#  '광물타르',
#  '목탄',
#  '알데히드',
#  '희소가스',
#  '드라이아이스',
#  '수은',
#  '카본블랙',
#  '텅스텐',
#  '',
#  '화학',
#  '석유',
#  '합성수지',
#  '합성',
#  '고무',
#  '플라스틱',
#  '라텍스',
#  '비닐',
#  'pe',
#  'pp',
#  'pvc',
#  'abs',
#  '이수화학',
#  '페놀',
#  'nbr',
#  '페트병',
#  '석화',
#  '폴리프로필렌',
#  '주사기',
#  '스티렌',
#  '이소부렌',
#  '아크릴로니트릴',
#  '에틸렌중합체',
#  '폴리아미드',
#  '폴리우레탄',
#  '아미노수지',
#  '에폭시수지',
#  '페놀수지',
#  '실리콘수지',
#  '비료',
#  '농약',
#  '살균',
#  '살충',
#  '질소',
#  '질산',
#  '요소',
#  '암모니아',
#  '톱밥',
#  '퇴비',
#  '질소질',
#  '인산질',
#  '칼리질',
#  '유기질',
#  '부산물',
#  '소독',
#  '방충',
#  '성장촉진제',
#  '발아억제제',
#  '퇴비',
#  '배합토',
#  '구충제',
#  '에프킬라',
#  '전자모기향',
#  '홈키파',
#  '방역',
#  '구제역',
#  '확산',
#  '잉크',
#  '도료',
#  '페인트',
#  '비누',
#  '세정',
#  '소독',
#  '화장품',
#  '뷰티',
#  '접착제',
#  '세제',
#  '위생',
#  '화학',
#  '물질',
#  '바니쉬',
#  '에나멜',
#  '디스템퍼',
#  '카슈',
#  '수지시멘트',
#  '매스틱',
#  ...]

# %%
unique_keywords = list(set(combined_keywords))

# %%
unique_keywords
# Out:
# ['스피커',
#  '임신진단기',
#  '펌프',
#  'NVIDIA',
#  '텐트',
#  '타이머',
#  '인터넷',
#  '제재',
#  '주사기',
#  '크래커',
#  '유성',
#  '주물',
#  '봉합',
#  '사과즙',
#  '비건',
#  '분유',
#  '철골',
#  '필립',
#  '전화기',
#  '찬장',
#  '가리비',
#  '부동액',
#  '전화',
#  '종이컵',
#  '건조기',
#  '연삭기',
#  '세라믹파이버',
#  '광전관',
#  '인테리어',
#  '방송통신기',
#  '편물사',
#  '곡물세척기',
#  '명패',
#  '축구',
#  '고구마',
#  '시력교정',
#  '철강',
#  '무선기기',
#  '젤라틴',
#  '젖꼭지',
#  '압연',
#  '글리세린',
#  '콩기름',
#  '조개',
#  '생합',
#  '소주',
#  '은제',
#  '마늘',
#  '철광석',
#  '고압가스',
#  '카메라',
#  '철강분말',
#  '상추',
#  '만두피',
#  '인쇄업',
#  '합성',
#  '혼방사',
#  '망간',
#  '민속의상',
#  '합판',
#  '항균',
#  '목공물',
#  '부유구조물',
#  '손수레',
#  '의료',
#  '트럭',
#  '가그린',
#  '조개탄',
#  '비축량',
#  '엑스레이',
#  '평삭기',
#  '가솔린',
#  '피자',
#  '중계기',
#  '견노일',
#  '암면',
#  '갤럭시',
#  '카본블랙',
#  '보건복지부',
#  '리코더',
#  '제책',
#  '대나무',
#  '형광램프',
#  '이륜자동차',
#  '롯데칠성',
#  '글러브',
#  '피스톤',
#  '현대제철',
#  '비타민',
#  '소화기',
#  '평형검사',
#  '살충',
#  '면도',
#  '원자로',
#  '시소',
#  '게임',
#  '석고',
#  '비내화',
#  '바지락',
#  '비디오',
#  '머플러',
#  '착화탄',
#  '다이스',
#  '체육',
#  '아미노수지',
#  '워딩',
#  '컴퓨터',
#  '양탄자',
#  '드라이아이스',
#  '제동장치',
#  '도정',
#  '유기질',
#  '전통의상',
#  '케첩',
#  '김',
#  '가공유',
#  '양돈',
#  '여과',
#  '현대자동차',
#  '윤활',
#  '수산물',
#  '렌치',
#  '수박',
#  '사다리',
#  '원심분리기',
#  '디스켓',
#  '카디건',
#  '현미',
#  '부목',
#  '끈',
#  '재활용',
#  '파프리카',
#  '드론',
#  '술병',
#  '도서관',
#  '쌈무',
#  '비스코스',
#  '배터리',
#  '발효유',
#  '어민',
#  '산화억제제',
#  '코마롬',
#  '알탄',
#  '블록보드',
#  '스웨터',
#  '단조기',
#  '진통제',
#  '전기매트',
#  '재단기',
#  '고무장화',
#  '탄산음료',
#  '카보드',
#  '스캐너',
#  '절연대',
#  '핀셋',
#  '등산',
#  '흑연',
#  '광석',
#  '승복',
#  'bat',
#  '안테나',
#  '니켈',
#  '도요타',
#  '강아지',
#  '소음',
#  '운전대',
#  '모뎀',
#  '도축장',
#  '천연가스',
#  '야자매트',
#  '밥솥',
#  '우주선',
#  'lcd',
#  '현대로템',
#  '이어폰',
#  '떡',
#  '청소',
#  '저울',
#  '새시',
#  '동아오츠카',
#  '열전자관',
#  '거들',
#  '강관',
#  '광폭',
#  '비피더스',
#  '비스킷',
#  '의치',
#  '풀리태클',
#  '요구르트',
#  '침구류',
#  '타이어',
#  '비광학',
#  '분자',
#  '에틸알콜',
#  'PC',
#  '기압식',
#  '전철',
#  '트렁크',
#  '라디오',
#  '항아리',
#  '도가니',
#  '시추기',
#  '기저귀',
#  '샴페인',
#  '냉동',
#  '카슈',
#  '공군',
#  '마이크로피쉐',
#  '목제',
#  '페이퍼',
#  '교통음향신호',
#  '앙금',
#  '표구',
#  '수중',
#  '턴테이블',
#  '케어',
#  'MDF',
#  '레토르트카본',
#  '감염',
#  '보드카',
#  '바나나',
#  'LPG',
#  '통신',
#  '처음처럼',
#  '참돔',
#  '무쌈',
#  '섬유',
#  '고무밴드',
#  '돼지',
#  '광우병',
#  '관제',
#  '걸레',
#  '아케이드',
#  '어업',
#  '아귀',
#  '셔터',
#  '빵',
#  '구명조끼',
#  '수프',
#  'GPU',
#  '안전유리',
#  '자동판매기',
#  '활성탄',
#  '이불',
#  '저지',
#  '수혈',
#  'LTE',
#  '감자',
#  '피치코크스',
#  '윤활유',
#  '커버',
#  '호부처리',
#  '공기총',
#  '고철',
#  '전자총',
#  '기초 무기화학',
#  '스포츠',
#  '파스텔',
#  '전자축전기',
#  '주유소',
#  '장류',
#  '미군',
#  '크라프트지',
#  '오일',
#  '페니실린',
#  '유리',
#  'ROM',
#  '음향',
#  'pet',
#  '직조',
#  'TSMC',
#  '원유',
#  '타이어직물',
#  '전압측정',
#  '레이저',
#  '질병',
#  '신문',
#  '가공탄',
#  '몰리브덴',
#  '하이트진로',
#  '대륙간탄도미사일',
#  '부직',
#  '르노',
#  '매트리스',
#  '모주',
#  '양회반죽',
#  '소니',
#  '핀펫',
#  '나프타',
#  '콩나물',
#  '난로',
#  '크레용',
#  '정미소',
#  '휘장',
#  '공',
#  '회로판',
#  '바이오',
#  'tv',
#  '브래지어',
#  '살균램프',
#  '샤베트',
#  '인견',
#  '먼지털이',
#  '장고',
#  '합금철',
#  '도료',
#  '마이크로필름',
#  '개껌',
#  '활자주조',
#  '플란트',
#  '소각로',
#  '석유',
#  '단무지',
#  '전기이온정수기',
#  '샌달',
#  '치료제',
#  '진단',
#  '마이크로폰',
#  '포도당',
#  '박스',
#  '인조섬유편조물',
#  '롤링도어',
#  '방위',
#  '어업인',
#  '건강원',
#  '광섬유',
#  '애완동물사료',
#  '포석',
#  'vr',
#  '양파',
#  '부품',
#  '한솔제지',
#  '페놀수지',
#  '금호타이어',
#  '건전지',
#  '위스키',
#  '스크루',
#  '조미김',
#  '공격',
#  '견방사',
#  '목제품',
#  '다이오드',
#  '크레인',
#  '작두',
#  '낚시',
#  '비누',
#  '국기',
#  '소고기',
#  '세신테크',
#  '등나무',
#  '프레스키',
#  '싱크대',
#  '헬스',
#  '범퍼',
#  '임신테스트기',
#  '렌즈',
#  '내복',
#  '베니어패널',
#  '플라스틱',
#  '서류받침',
#  '디펜스',
#  '편육',
#  '사케',
#  '인산질',
#  '인듐',
#  '미쉐린',
#  '철문',
#  '광물',
#  '밧데리',
#  '곡물선별기',
#  '스쿠터',
#  '녹즙',
#  '이온음료',
#  '농경지',
#  '건과일',
#  '깃발',
#  '탄소',
#  '주사제',
#  '세척기',
#  '유조선',
#  '후추',
#  '프리즘',
#  '고무도포직물',
#  '코코몽',
#  '판재',
#  '유전자',
#  '나일론',
#  '첼로',
#  '스토브',
#  '아크릴사',
#  '미포조선',
#  '반바지',
#  '채소',
#  '구충제',
#  '화장지',
#  '수력터빈',
#  '찬솔',
#  '해군',
#  '모리스',
#  '배합사료',
#  '편직결합',
#  '포장지',
#  '포스코',
#  '망원경',
#  '닭갈비',
#  '퍼시스',
#  '압형',
#  '대우',
#  '질산',
#  '파일드라이버',
#  '관상어',
#  '쇼핑카트',
#  '멍게',
#  '18K',
#  '구제역',
#  '세탁',
#  '알로에',
#  '마그네틱드',
#  '고량주',
#  '면도기',
#  '데릭',
#  '리어카',
#  '쌍용',
#  '부식방지제',
#  '콜크',
#  '동양금속공업',
#  '시럽',
#  '베어링',
#  '강화마루',
#  '텔레프린터',
#  '변기',
#  '크리스탈',
#  '호닝기',
#  '석회',
#  '방향탐지',
#  '타요',
#  '갈치',
#  '오디오북',
#  '유도체',
#  '닛산',
#  '에어컨필터',
#  '음반',
#  '실크',
#  '온열매트',
#  'BMW',
#  '신발',
#  '알루미늄',
#  '생선통조림',
#  '제약',
#  '수성',
#  '팜유',
#  '인삼음료',
#  '풀리',
#  '강옥',
#  '착유기',
#  '한약',
#  '생선',
#  '나무',
#  '재활',
#  '제지업',
#  '하소석고',
#  '금속업',
#  '전지가위',
#  '약과',
#  '압축기',
#  '가글',
#  '농기계',
#  '혈청',
#  '석탄화학',
#  '물엿',
#  '블라인드',
#  '배합토',
#  '재생',
#  '호이스트',
#  '우의',
#  '닭가슴살',
#  '중유',
#  '냅킨',
#  '글라스',
#  '스탬핑',
#  '채종유',
#  '아크릴로니트릴',
#  '식탁',
#  '어묵',
#  '복제',
#  '골절치료',
#  '자두',
#  '골프',
#  '고등어',
#  '마이크로톰',
#  '캠핑카',
#  '휠',
#  '콘버터',
#  '철도궤도',
#  '귀걸이',
#  '뮤지컬박스',
#  '코진테크',
#  '엑티노마이신',
#  '의료기기',
#  '불스원',
#  '탐폰',
#  '프린트',
#  '감귤주스',
#  '자주포',
#  '염색',
#  '베릴륨',
#  '스마트폰',
#  '로켓',
#  '자수기',
#  '퇴비',
#  '타피오카',
#  '연탄집게',
#  '엘지',
#  '물질',
#  '차량',
#  '건채소',
#  '자리',
#  '미미',
#  '렉서스',
#  '마카로니',
#  '피클',
#  '합성수지',
#  '마루덮개',
#  '마찰재',
#  '테니스',
#  '제화',
#  '바나듐',
#  '슬립',
#  '옥토넛',
#  '말보로',
#  'TV',
#  '클러치',
#  '스키',
#  '농작물',
#  '나무못',
#  '인삼',
#  '파이버보드',
#  '광학',
#  '도로포장',
#  '어선',
#  '샹들리에',
#  '방석',
#  '유제품',
#  '출판물',
#  '발아억제제',
#  '메디컬',
#  '드라이크리닝',
#  '지혈제',
#  '인형',
#  '비디오게임',
#  '냉장',
#  '목재',
#  '투석',
#  '정제유',
#  '자기',
#  '변속기',
#  '칼리질',
#  'LG',
#  '버스',
#  '열쇠',
#  '차체',
#  '목관',
#  '전자담배',
#  '샤시',
#  '돗자리',
#  '저항검사기',
#  '백신',
#  '포드',
#  '매트',
#  '레종',
#  '스티커',
#  '낫',
#  '농구',
#  '목모',
#  '석유화학',
#  '누리호',
#  '영수증',
#  '믹서기',
#  '항바이러스',
#  '가마솥',
#  '소다',
#  '인공보육기',
#  '솜',
#  '봉합재',
#  '광어',
#  '인쇄물',
#  '강판',
#  '조미료',
#  '제본',
#  '종이직물',
#  '훈제',
#  '곡물',
#  '원피스',
#  '구급',
#  '견재봉사',
#  '젓가락',
#  '낙농업',
#  '광고',
#  '카펫',
#  '전류측정',
#  '울타리',
#  '장판',
#  '플레이스테이션',
#  '오이지',
#  '낚시망',
#  '디젤',
#  '수확',
#  '사진',
#  '토마토',
#  '알칼로이드',
#  '세척',
#  '먹태',
#  '레코드',
#  '헬리콥터',
#  '버터',
#  '라벨',
#  'NMR',
#  'PET',
#  '인조석',
#  '캐리어',
#  '캘리',
#  '워크맨',
#  '이노텍',
#  '도로표지판',
#  '플럭',
#  '연료',
#  '백상지',
#  '폐기물',
#  '방산',
#  '영농',
#  '카지노',
#  '갈륨',
#  '합금강',
#  '제지',
#  '배달',
#  '농업인',
#  '항공',
#  '양계',
#  '간판',
#  '혼수',
#  '감압밸브',
#  '가스킷',
#  '시계',
#  '내시경',
#  '보정속옷',
#  '운모',
#  '파렛',
#  '석면',
#  '변압기',
#  '춘장',
#  '코튼',
#  '동해안',
#  '허리띠',
#  '파나소닉',
#  'AR',
#  '헤어스프레이',
#  '인스턴트',
#  '침대',
#  '컨버스',
#  '토탄',
#  '유지',
#  '트랜지스터',
#  '감염증',
#  '건어물',
#  '폴리에스터',
#  'LCD',
#  '주철',
#  '이수화학',
#  '포장',
#  '제네시스',
#  '충전',
#  '콩',
#  '포도',
#  '디지털',
#  '캡슐',
#  '불도저',
#  '스테로이드',
#  '밀',
#  '고체연료',
#  '삼성중공업',
#  '피리',
#  '삼성',
#  '폭죽',
#  '굴삭기',
#  '참이슬',
#  '과자',
#  '마모사',
#  '두유',
#  '현금함',
#  '공예',
#  '대합',
#  '토요타',
#  '폭탄',
#  '건조',
#  '현대중공업',
#  '누룩',
#  '실내화',
#  '니트',
#  '내연기관',
#  '숄',
#  '레이스',
#  '철망',
#  '면편조물',
#  '조명',
#  '리튬',
#  '스니커즈',
#  '코이어사',
#  '내화피복재',
#  '선글라스',
#  '어획량',
#  '가방',
#  '디스템퍼',
#  '드라이클리닝',
#  '유업',
#  '편조물',
#  '죽염',
#  '모자',
#  '탬버린',
#  '염료',
#  '농장',
#  '혼방',
#  '도장',
#  '단추',
#  '방역',
#  '과일통조림',
#  '장아찌',
#  'pvc',
#  '골프카트',
#  '혼합물',
#  '한화',
#  '포탄',
#  '양곡',
#  '접착제',
#  '나사',
#  '피복',
#  '데이터',
#  '현미경',
#  '코일가공기',
#  '채굴기',
#  '인삼즙',
#  '해운',
#  '재제조',
#  '나물',
#  '도자기',
#  '나전칠기',
#  '확산',
#  '공구홀더',
#  '사이드카',
#  '재조립',
#  '온열기',
#  '제분소',
#  '셔츠',
#  '양궁',
#  '피마자유',
#  '전자모기향',
#  '공구백',
#  '글리코시드',
#  '텔레비전',
#  '여객선',
#  '향낭',
#  '비디오카드',
#  '세폭직물',
#  '압전기',
#  '편물',
#  '하이닉스',
#  '폴리프로필렌',
#  'KTX',
#  '액세서리',
#  '크롬',
#  '경운기',
#  '부산물',
#  'SRT',
#  '도축',
#  '배기장치',
#  '아쟁',
#  '보관함',
#  '광학유리',
#  '모조진주',
#  '군형검사',
#  '정지기',
#  '키위',
#  '고양이',
#  '탁구',
#  '일반재',
#  '바지',
#  '매스틱',
#  '이스트',
#  '계면활성제',
#  '개수대',
#  '조발기',
#  '주사바늘',
#  '제일제당',
#  '로만시스',
#  '야자',
#  '윈치',
#  '금속선',
#  '선철',
#  '서해안',
#  '암모니아',
#  '저장',
#  '건강',
#  '기압계',
#  '고추가루',
#  '황태',
#  '바인더',
#  '마그네틱',
#  '불고기',
#  '가발',
#  '스테인레스',
#  '토슈즈',
#  '과실주스',
#  '신호',
#  '방탄복',
#  '톱밥',
#  '굴',
#  '동물',
#  '재단',
#  '과실음료',
#  '타일',
#  '보일러',
#  '볼트',
#  '모피',
#  '안경',
#  '브로콜리',
#  '활공기',
#  '날염기',
#  '신성켐텍',
#  '용기',
#  '휴대전화',
#  '공작',
#  '백합',
#  '농업',
#  '바이오디젤',
#  '시곗줄',
#  '전선',
#  '어항',
#  '백열전구',
#  '농사',
#  '도박',
#  '경첩',
#  '카스터',
#  '감광저울',
#  '탈늄',
#  '팥',
#  '브로치',
#  '스파게티',
#  '상패',
#  '패브릭',
#  '하드디스크',
#  '부화기',
#  '코크스',
#  '오토바이',
#  '홍차',
#  '코트',
#  '견편조',
#  '메밀국수',
#  '에쎄',
#  '농협',
#  '네온사인',
#  '참외',
#  '원격조절',
#  '목탄',
#  '패널',
#  '도금',
#  '시금치',
#  '농심',
#  '발전기',
#  '중밀도섬유판',
#  '현대미포조선',
#  '운동화',
#  '목걸이',
#  '봉제',
#  '전자저항기',
#  '테이프',
#  '애플',
#  '유당',
#  '침구',
#  '위성',
#  'CCTV',
#  '속옷',
#  '식기세척기',
#  '고추장',
#  '당구',
#  '충전기',
#  '영사기',
#  '사이클',
#  '측정',
#  '형강',
#  '도시락',
#  '산소',
#  '가변저항기',
#  '써머스터',
#  '확진',
#  '지붕용패널',
#  '도축업',
#  '캔버스',
#  '생산량',
#  '코어',
#  '넥타이',
#  '배선판',
#  '효모',
#  '보닛',
#  '장판지',
#  '잉크',
#  '쇼파',
#  '장갑',
#  '자물쇠',
#  '맥아',
#  '부츠',
#  '토스트기',
#  '사과잼',
#  '오징어',
#  '폴리에틸렌',
#  '고래고기',
#  '에이스',
#  '풀오버',
#  'dvd',
#  '장기',
#  '아크램프',
#  '농산물',
#  '벌크선',
#  '베이컨',
#  '우체통',
#  '공판',
#  '바이올린',
#  '모빌리티',
#  '양꼬치',
#  '농약',
#  '목분',
#  '가스총',
#  '케이크',
#  '스패너',
#  '화웨이',
#  '단식옵셋',
#  '혈압측정기',
#  '복숭아',
#  '이눌린',
#  '담요',
#  '바닥재',
#  '탈지유',
#  '캐스터네츠',
#  '황태채',
#  '해조',
#  '모르타르',
#  '조선소',
#  '교통안전표시판',
#  '온도',
#  '냉동고',
#  '남해안',
#  '성장촉진제',
#  '안경유리',
#  '숟가락',
#  '천마스크',
#  'atm',
#  '현대차',
#  '고무신',
#  '제판',
#  '앰프',
#  '천연수지',
#  '팽창퍼라이트',
#  '디에스아이',
#  '작업대',
#  '미사일',
#  '가구',
#  '나투',
#  '온열기구',
#  '섬광전구',
#  '절단기',
#  '유압식',
#  '플라이휠',
#  '씨디',
#  '수세미',
#  '하우스',
#  '감말랭이',
#  '팬오션',
#  '전기자동차',
#  'PVC',
#  '사이다',
#  '매실주',
#  '양극',
#  '역량계',
#  '가스터빈',
#  '펀칭기',
#  '니오레늄',
#  '사이잘마사',
#  '찹쌀가루',
#  '습도계',
#  '강재',
#  '전차',
#  '한국타이어',
#  '야구',
#  '공정',
#  '노트북',
#  '착색제',
#  '인쇄회로판',
#  '소시지',
#  '쐐기',
#  '고무장갑',
#  '생선까스',
#  '아우디',
#  ...]

# %%
unique_keywords.pop(0)
# Out:
# ''

# %%
len(unique_keywords)
# Out:
# 2009

# %%
KSIC_keywords = unique_keywords

# %%
with open('ksic_keywords.pkl', 'wb') as file:
    pickle.dump(KSIC_keywords, file)

# %%
with open('ksic_keywords.pkl', 'rb') as file:
    loaded_list = pickle.load(file)

# %%
loaded_list
# Out:
# ['스피커',
#  '임신진단기',
#  '펌프',
#  'NVIDIA',
#  '텐트',
#  '타이머',
#  '인터넷',
#  '제재',
#  '주사기',
#  '크래커',
#  '유성',
#  '주물',
#  '봉합',
#  '사과즙',
#  '비건',
#  '분유',
#  '철골',
#  '필립',
#  '전화기',
#  '찬장',
#  '가리비',
#  '부동액',
#  '전화',
#  '종이컵',
#  '건조기',
#  '연삭기',
#  '세라믹파이버',
#  '광전관',
#  '인테리어',
#  '방송통신기',
#  '편물사',
#  '곡물세척기',
#  '명패',
#  '축구',
#  '고구마',
#  '시력교정',
#  '철강',
#  '무선기기',
#  '젤라틴',
#  '젖꼭지',
#  '압연',
#  '글리세린',
#  '콩기름',
#  '조개',
#  '생합',
#  '소주',
#  '은제',
#  '마늘',
#  '철광석',
#  '고압가스',
#  '카메라',
#  '철강분말',
#  '상추',
#  '만두피',
#  '인쇄업',
#  '합성',
#  '혼방사',
#  '망간',
#  '민속의상',
#  '합판',
#  '항균',
#  '목공물',
#  '부유구조물',
#  '손수레',
#  '의료',
#  '트럭',
#  '가그린',
#  '조개탄',
#  '비축량',
#  '엑스레이',
#  '평삭기',
#  '가솔린',
#  '피자',
#  '중계기',
#  '견노일',
#  '암면',
#  '갤럭시',
#  '카본블랙',
#  '보건복지부',
#  '리코더',
#  '제책',
#  '대나무',
#  '형광램프',
#  '이륜자동차',
#  '롯데칠성',
#  '글러브',
#  '피스톤',
#  '현대제철',
#  '비타민',
#  '소화기',
#  '평형검사',
#  '살충',
#  '면도',
#  '원자로',
#  '시소',
#  '게임',
#  '석고',
#  '비내화',
#  '바지락',
#  '비디오',
#  '머플러',
#  '착화탄',
#  '다이스',
#  '체육',
#  '아미노수지',
#  '워딩',
#  '컴퓨터',
#  '양탄자',
#  '드라이아이스',
#  '제동장치',
#  '도정',
#  '유기질',
#  '전통의상',
#  '케첩',
#  '김',
#  '가공유',
#  '양돈',
#  '여과',
#  '현대자동차',
#  '윤활',
#  '수산물',
#  '렌치',
#  '수박',
#  '사다리',
#  '원심분리기',
#  '디스켓',
#  '카디건',
#  '현미',
#  '부목',
#  '끈',
#  '재활용',
#  '파프리카',
#  '드론',
#  '술병',
#  '도서관',
#  '쌈무',
#  '비스코스',
#  '배터리',
#  '발효유',
#  '어민',
#  '산화억제제',
#  '코마롬',
#  '알탄',
#  '블록보드',
#  '스웨터',
#  '단조기',
#  '진통제',
#  '전기매트',
#  '재단기',
#  '고무장화',
#  '탄산음료',
#  '카보드',
#  '스캐너',
#  '절연대',
#  '핀셋',
#  '등산',
#  '흑연',
#  '광석',
#  '승복',
#  'bat',
#  '안테나',
#  '니켈',
#  '도요타',
#  '강아지',
#  '소음',
#  '운전대',
#  '모뎀',
#  '도축장',
#  '천연가스',
#  '야자매트',
#  '밥솥',
#  '우주선',
#  'lcd',
#  '현대로템',
#  '이어폰',
#  '떡',
#  '청소',
#  '저울',
#  '새시',
#  '동아오츠카',
#  '열전자관',
#  '거들',
#  '강관',
#  '광폭',
#  '비피더스',
#  '비스킷',
#  '의치',
#  '풀리태클',
#  '요구르트',
#  '침구류',
#  '타이어',
#  '비광학',
#  '분자',
#  '에틸알콜',
#  'PC',
#  '기압식',
#  '전철',
#  '트렁크',
#  '라디오',
#  '항아리',
#  '도가니',
#  '시추기',
#  '기저귀',
#  '샴페인',
#  '냉동',
#  '카슈',
#  '공군',
#  '마이크로피쉐',
#  '목제',
#  '페이퍼',
#  '교통음향신호',
#  '앙금',
#  '표구',
#  '수중',
#  '턴테이블',
#  '케어',
#  'MDF',
#  '레토르트카본',
#  '감염',
#  '보드카',
#  '바나나',
#  'LPG',
#  '통신',
#  '처음처럼',
#  '참돔',
#  '무쌈',
#  '섬유',
#  '고무밴드',
#  '돼지',
#  '광우병',
#  '관제',
#  '걸레',
#  '아케이드',
#  '어업',
#  '아귀',
#  '셔터',
#  '빵',
#  '구명조끼',
#  '수프',
#  'GPU',
#  '안전유리',
#  '자동판매기',
#  '활성탄',
#  '이불',
#  '저지',
#  '수혈',
#  'LTE',
#  '감자',
#  '피치코크스',
#  '윤활유',
#  '커버',
#  '호부처리',
#  '공기총',
#  '고철',
#  '전자총',
#  '기초 무기화학',
#  '스포츠',
#  '파스텔',
#  '전자축전기',
#  '주유소',
#  '장류',
#  '미군',
#  '크라프트지',
#  '오일',
#  '페니실린',
#  '유리',
#  'ROM',
#  '음향',
#  'pet',
#  '직조',
#  'TSMC',
#  '원유',
#  '타이어직물',
#  '전압측정',
#  '레이저',
#  '질병',
#  '신문',
#  '가공탄',
#  '몰리브덴',
#  '하이트진로',
#  '대륙간탄도미사일',
#  '부직',
#  '르노',
#  '매트리스',
#  '모주',
#  '양회반죽',
#  '소니',
#  '핀펫',
#  '나프타',
#  '콩나물',
#  '난로',
#  '크레용',
#  '정미소',
#  '휘장',
#  '공',
#  '회로판',
#  '바이오',
#  'tv',
#  '브래지어',
#  '살균램프',
#  '샤베트',
#  '인견',
#  '먼지털이',
#  '장고',
#  '합금철',
#  '도료',
#  '마이크로필름',
#  '개껌',
#  '활자주조',
#  '플란트',
#  '소각로',
#  '석유',
#  '단무지',
#  '전기이온정수기',
#  '샌달',
#  '치료제',
#  '진단',
#  '마이크로폰',
#  '포도당',
#  '박스',
#  '인조섬유편조물',
#  '롤링도어',
#  '방위',
#  '어업인',
#  '건강원',
#  '광섬유',
#  '애완동물사료',
#  '포석',
#  'vr',
#  '양파',
#  '부품',
#  '한솔제지',
#  '페놀수지',
#  '금호타이어',
#  '건전지',
#  '위스키',
#  '스크루',
#  '조미김',
#  '공격',
#  '견방사',
#  '목제품',
#  '다이오드',
#  '크레인',
#  '작두',
#  '낚시',
#  '비누',
#  '국기',
#  '소고기',
#  '세신테크',
#  '등나무',
#  '프레스키',
#  '싱크대',
#  '헬스',
#  '범퍼',
#  '임신테스트기',
#  '렌즈',
#  '내복',
#  '베니어패널',
#  '플라스틱',
#  '서류받침',
#  '디펜스',
#  '편육',
#  '사케',
#  '인산질',
#  '인듐',
#  '미쉐린',
#  '철문',
#  '광물',
#  '밧데리',
#  '곡물선별기',
#  '스쿠터',
#  '녹즙',
#  '이온음료',
#  '농경지',
#  '건과일',
#  '깃발',
#  '탄소',
#  '주사제',
#  '세척기',
#  '유조선',
#  '후추',
#  '프리즘',
#  '고무도포직물',
#  '코코몽',
#  '판재',
#  '유전자',
#  '나일론',
#  '첼로',
#  '스토브',
#  '아크릴사',
#  '미포조선',
#  '반바지',
#  '채소',
#  '구충제',
#  '화장지',
#  '수력터빈',
#  '찬솔',
#  '해군',
#  '모리스',
#  '배합사료',
#  '편직결합',
#  '포장지',
#  '포스코',
#  '망원경',
#  '닭갈비',
#  '퍼시스',
#  '압형',
#  '대우',
#  '질산',
#  '파일드라이버',
#  '관상어',
#  '쇼핑카트',
#  '멍게',
#  '18K',
#  '구제역',
#  '세탁',
#  '알로에',
#  '마그네틱드',
#  '고량주',
#  '면도기',
#  '데릭',
#  '리어카',
#  '쌍용',
#  '부식방지제',
#  '콜크',
#  '동양금속공업',
#  '시럽',
#  '베어링',
#  '강화마루',
#  '텔레프린터',
#  '변기',
#  '크리스탈',
#  '호닝기',
#  '석회',
#  '방향탐지',
#  '타요',
#  '갈치',
#  '오디오북',
#  '유도체',
#  '닛산',
#  '에어컨필터',
#  '음반',
#  '실크',
#  '온열매트',
#  'BMW',
#  '신발',
#  '알루미늄',
#  '생선통조림',
#  '제약',
#  '수성',
#  '팜유',
#  '인삼음료',
#  '풀리',
#  '강옥',
#  '착유기',
#  '한약',
#  '생선',
#  '나무',
#  '재활',
#  '제지업',
#  '하소석고',
#  '금속업',
#  '전지가위',
#  '약과',
#  '압축기',
#  '가글',
#  '농기계',
#  '혈청',
#  '석탄화학',
#  '물엿',
#  '블라인드',
#  '배합토',
#  '재생',
#  '호이스트',
#  '우의',
#  '닭가슴살',
#  '중유',
#  '냅킨',
#  '글라스',
#  '스탬핑',
#  '채종유',
#  '아크릴로니트릴',
#  '식탁',
#  '어묵',
#  '복제',
#  '골절치료',
#  '자두',
#  '골프',
#  '고등어',
#  '마이크로톰',
#  '캠핑카',
#  '휠',
#  '콘버터',
#  '철도궤도',
#  '귀걸이',
#  '뮤지컬박스',
#  '코진테크',
#  '엑티노마이신',
#  '의료기기',
#  '불스원',
#  '탐폰',
#  '프린트',
#  '감귤주스',
#  '자주포',
#  '염색',
#  '베릴륨',
#  '스마트폰',
#  '로켓',
#  '자수기',
#  '퇴비',
#  '타피오카',
#  '연탄집게',
#  '엘지',
#  '물질',
#  '차량',
#  '건채소',
#  '자리',
#  '미미',
#  '렉서스',
#  '마카로니',
#  '피클',
#  '합성수지',
#  '마루덮개',
#  '마찰재',
#  '테니스',
#  '제화',
#  '바나듐',
#  '슬립',
#  '옥토넛',
#  '말보로',
#  'TV',
#  '클러치',
#  '스키',
#  '농작물',
#  '나무못',
#  '인삼',
#  '파이버보드',
#  '광학',
#  '도로포장',
#  '어선',
#  '샹들리에',
#  '방석',
#  '유제품',
#  '출판물',
#  '발아억제제',
#  '메디컬',
#  '드라이크리닝',
#  '지혈제',
#  '인형',
#  '비디오게임',
#  '냉장',
#  '목재',
#  '투석',
#  '정제유',
#  '자기',
#  '변속기',
#  '칼리질',
#  'LG',
#  '버스',
#  '열쇠',
#  '차체',
#  '목관',
#  '전자담배',
#  '샤시',
#  '돗자리',
#  '저항검사기',
#  '백신',
#  '포드',
#  '매트',
#  '레종',
#  '스티커',
#  '낫',
#  '농구',
#  '목모',
#  '석유화학',
#  '누리호',
#  '영수증',
#  '믹서기',
#  '항바이러스',
#  '가마솥',
#  '소다',
#  '인공보육기',
#  '솜',
#  '봉합재',
#  '광어',
#  '인쇄물',
#  '강판',
#  '조미료',
#  '제본',
#  '종이직물',
#  '훈제',
#  '곡물',
#  '원피스',
#  '구급',
#  '견재봉사',
#  '젓가락',
#  '낙농업',
#  '광고',
#  '카펫',
#  '전류측정',
#  '울타리',
#  '장판',
#  '플레이스테이션',
#  '오이지',
#  '낚시망',
#  '디젤',
#  '수확',
#  '사진',
#  '토마토',
#  '알칼로이드',
#  '세척',
#  '먹태',
#  '레코드',
#  '헬리콥터',
#  '버터',
#  '라벨',
#  'NMR',
#  'PET',
#  '인조석',
#  '캐리어',
#  '캘리',
#  '워크맨',
#  '이노텍',
#  '도로표지판',
#  '플럭',
#  '연료',
#  '백상지',
#  '폐기물',
#  '방산',
#  '영농',
#  '카지노',
#  '갈륨',
#  '합금강',
#  '제지',
#  '배달',
#  '농업인',
#  '항공',
#  '양계',
#  '간판',
#  '혼수',
#  '감압밸브',
#  '가스킷',
#  '시계',
#  '내시경',
#  '보정속옷',
#  '운모',
#  '파렛',
#  '석면',
#  '변압기',
#  '춘장',
#  '코튼',
#  '동해안',
#  '허리띠',
#  '파나소닉',
#  'AR',
#  '헤어스프레이',
#  '인스턴트',
#  '침대',
#  '컨버스',
#  '토탄',
#  '유지',
#  '트랜지스터',
#  '감염증',
#  '건어물',
#  '폴리에스터',
#  'LCD',
#  '주철',
#  '이수화학',
#  '포장',
#  '제네시스',
#  '충전',
#  '콩',
#  '포도',
#  '디지털',
#  '캡슐',
#  '불도저',
#  '스테로이드',
#  '밀',
#  '고체연료',
#  '삼성중공업',
#  '피리',
#  '삼성',
#  '폭죽',
#  '굴삭기',
#  '참이슬',
#  '과자',
#  '마모사',
#  '두유',
#  '현금함',
#  '공예',
#  '대합',
#  '토요타',
#  '폭탄',
#  '건조',
#  '현대중공업',
#  '누룩',
#  '실내화',
#  '니트',
#  '내연기관',
#  '숄',
#  '레이스',
#  '철망',
#  '면편조물',
#  '조명',
#  '리튬',
#  '스니커즈',
#  '코이어사',
#  '내화피복재',
#  '선글라스',
#  '어획량',
#  '가방',
#  '디스템퍼',
#  '드라이클리닝',
#  '유업',
#  '편조물',
#  '죽염',
#  '모자',
#  '탬버린',
#  '염료',
#  '농장',
#  '혼방',
#  '도장',
#  '단추',
#  '방역',
#  '과일통조림',
#  '장아찌',
#  'pvc',
#  '골프카트',
#  '혼합물',
#  '한화',
#  '포탄',
#  '양곡',
#  '접착제',
#  '나사',
#  '피복',
#  '데이터',
#  '현미경',
#  '코일가공기',
#  '채굴기',
#  '인삼즙',
#  '해운',
#  '재제조',
#  '나물',
#  '도자기',
#  '나전칠기',
#  '확산',
#  '공구홀더',
#  '사이드카',
#  '재조립',
#  '온열기',
#  '제분소',
#  '셔츠',
#  '양궁',
#  '피마자유',
#  '전자모기향',
#  '공구백',
#  '글리코시드',
#  '텔레비전',
#  '여객선',
#  '향낭',
#  '비디오카드',
#  '세폭직물',
#  '압전기',
#  '편물',
#  '하이닉스',
#  '폴리프로필렌',
#  'KTX',
#  '액세서리',
#  '크롬',
#  '경운기',
#  '부산물',
#  'SRT',
#  '도축',
#  '배기장치',
#  '아쟁',
#  '보관함',
#  '광학유리',
#  '모조진주',
#  '군형검사',
#  '정지기',
#  '키위',
#  '고양이',
#  '탁구',
#  '일반재',
#  '바지',
#  '매스틱',
#  '이스트',
#  '계면활성제',
#  '개수대',
#  '조발기',
#  '주사바늘',
#  '제일제당',
#  '로만시스',
#  '야자',
#  '윈치',
#  '금속선',
#  '선철',
#  '서해안',
#  '암모니아',
#  '저장',
#  '건강',
#  '기압계',
#  '고추가루',
#  '황태',
#  '바인더',
#  '마그네틱',
#  '불고기',
#  '가발',
#  '스테인레스',
#  '토슈즈',
#  '과실주스',
#  '신호',
#  '방탄복',
#  '톱밥',
#  '굴',
#  '동물',
#  '재단',
#  '과실음료',
#  '타일',
#  '보일러',
#  '볼트',
#  '모피',
#  '안경',
#  '브로콜리',
#  '활공기',
#  '날염기',
#  '신성켐텍',
#  '용기',
#  '휴대전화',
#  '공작',
#  '백합',
#  '농업',
#  '바이오디젤',
#  '시곗줄',
#  '전선',
#  '어항',
#  '백열전구',
#  '농사',
#  '도박',
#  '경첩',
#  '카스터',
#  '감광저울',
#  '탈늄',
#  '팥',
#  '브로치',
#  '스파게티',
#  '상패',
#  '패브릭',
#  '하드디스크',
#  '부화기',
#  '코크스',
#  '오토바이',
#  '홍차',
#  '코트',
#  '견편조',
#  '메밀국수',
#  '에쎄',
#  '농협',
#  '네온사인',
#  '참외',
#  '원격조절',
#  '목탄',
#  '패널',
#  '도금',
#  '시금치',
#  '농심',
#  '발전기',
#  '중밀도섬유판',
#  '현대미포조선',
#  '운동화',
#  '목걸이',
#  '봉제',
#  '전자저항기',
#  '테이프',
#  '애플',
#  '유당',
#  '침구',
#  '위성',
#  'CCTV',
#  '속옷',
#  '식기세척기',
#  '고추장',
#  '당구',
#  '충전기',
#  '영사기',
#  '사이클',
#  '측정',
#  '형강',
#  '도시락',
#  '산소',
#  '가변저항기',
#  '써머스터',
#  '확진',
#  '지붕용패널',
#  '도축업',
#  '캔버스',
#  '생산량',
#  '코어',
#  '넥타이',
#  '배선판',
#  '효모',
#  '보닛',
#  '장판지',
#  '잉크',
#  '쇼파',
#  '장갑',
#  '자물쇠',
#  '맥아',
#  '부츠',
#  '토스트기',
#  '사과잼',
#  '오징어',
#  '폴리에틸렌',
#  '고래고기',
#  '에이스',
#  '풀오버',
#  'dvd',
#  '장기',
#  '아크램프',
#  '농산물',
#  '벌크선',
#  '베이컨',
#  '우체통',
#  '공판',
#  '바이올린',
#  '모빌리티',
#  '양꼬치',
#  '농약',
#  '목분',
#  '가스총',
#  '케이크',
#  '스패너',
#  '화웨이',
#  '단식옵셋',
#  '혈압측정기',
#  '복숭아',
#  '이눌린',
#  '담요',
#  '바닥재',
#  '탈지유',
#  '캐스터네츠',
#  '황태채',
#  '해조',
#  '모르타르',
#  '조선소',
#  '교통안전표시판',
#  '온도',
#  '냉동고',
#  '남해안',
#  '성장촉진제',
#  '안경유리',
#  '숟가락',
#  '천마스크',
#  'atm',
#  '현대차',
#  '고무신',
#  '제판',
#  '앰프',
#  '천연수지',
#  '팽창퍼라이트',
#  '디에스아이',
#  '작업대',
#  '미사일',
#  '가구',
#  '나투',
#  '온열기구',
#  '섬광전구',
#  '절단기',
#  '유압식',
#  '플라이휠',
#  '씨디',
#  '수세미',
#  '하우스',
#  '감말랭이',
#  '팬오션',
#  '전기자동차',
#  'PVC',
#  '사이다',
#  '매실주',
#  '양극',
#  '역량계',
#  '가스터빈',
#  '펀칭기',
#  '니오레늄',
#  '사이잘마사',
#  '찹쌀가루',
#  '습도계',
#  '강재',
#  '전차',
#  '한국타이어',
#  '야구',
#  '공정',
#  '노트북',
#  '착색제',
#  '인쇄회로판',
#  '소시지',
#  '쐐기',
#  '고무장갑',
#  '생선까스',
#  '아우디',
#  ...]

# %%
file_path = '/home/osung/data/korean/KSIC_code.txt'

# %%
KSIC_code = get_ksic_code(file_path)

# %%
KSIC_code
# Out:
# {'c101': '도축, 육류 가공 및 저장 처리업',
#  'c102': '수산물 가공 및 저장 처리업',
#  'c103': '과실, 체소 가공 및 저장 처리업',
#  'c104': '동,식물성 유지 및 낙농제품 제조업',
#  'c105': '낙농제품 및 식용빙과류 제조업',
#  'c106': '곡물 가공품, 전분 및 전분제품 제조업',
#  'c107': '기타 식품 제조업',
#  'c108': '동물용 사료 및 조제식품 제조업',
#  'c111': '알코올 음료 제조업',
#  'c112': '비알코올 음료 및 얼음 제조업',
#  'c120': '담배 제조업',
#  'c131': '방적 및 가공사 제조업',
#  'c132': '직물 직조 및 직물제품 제조업',
#  'c133': '편조 원단 제조업',
#  'c134': '섬유제품 염색, 정리 및 마무리 가공업',
#  'c139': '기타 섬유제품 제조업',
#  'c141': '봉제의복 제조업',
#  'c142': '모피제품 제조업',
#  'c143': '편조의복 제조업',
#  'c144': '의복 액세서리 제조업',
#  'c151': '가죽, 가방 및 유사 제품 제조업',
#  'c152': '신발 및 신발 부분품 제조업',
#  'c161': '제재 및 목재 가공업',
#  'c162': '나무제품 제조업',
#  'c163': '코르크 및 조물 제품 제조업',
#  'c171': '펄프, 종이 및 판지 제조업',
#  'c172': '골판지, 종이 상자 및 종이 용기 제조업',
#  'c179': '기타 종이 및 판지 제품 제조업',
#  'c181': '인쇄 및 인쇄관련 산업',
#  'c182': '기록매체 복제업',
#  'c191': '코크스 및 연탄 제조업',
#  'c192': '석유 정제품 제조업',
#  'c201': '기초 화학물질 제조업',
#  'c202': '합성고무 및 플라스틱 물질 제조업',
#  'c203': '비료, 농약 및 살균,살충제 제조업',
#  'c204': '기타 화학제품 제조업',
#  'c205': '화학섬유 제조업',
#  'c211': '기초 의약물질 제조업',
#  'c212': '의약품 제조업',
#  'c213': '의료용품 및 기타 의약 관련제품 제조업',
#  'c221': '고무제품 제조업',
#  'c222': '플라스틱 제품 제조업',
#  'c231': '유리 및 유리제품 제조업',
#  'c232': '내화, 비내화 요업제품 제조업',
#  'c233': '시멘트, 석회, 플라스틱 및 그 제품 제조업',
#  'c239': '기타 비금속 광물제품 제조업',
#  'c241': '1차 철강 제조업',
#  'c242': '1차 비철금속 제조업',
#  'c243': '금속 주조업',
#  'c251': '구조용 금속제품, 탱크 및 증기발생기 제조업',
#  'c252': '무기 및 총포탄 제조업',
#  'c259': '기타 금속 가공제품 제조업',
#  'c261': '반도체 제조업',
#  'c262': '전자 부품 제조업',
#  'c263': '컴퓨터 및 주변 장치 제조업',
#  'c264': '통신 및 방송장비 제조업',
#  'c265': '영상 및 음향 기기 제조업',
#  'c266': '마그네틱 및 광학 매체 제조업',
#  'c271': '의료용 기기 제조업',
#  'c272': '측정, 시험, 항해, 제어 및 기타 정밀 기기 제조업; 광학 기기 제외',
#  'c273': '사진장비 및 광학 기기 제조업',
#  'c281': '전동기, 발전기 및 전기 변환·공급·제어 장치 제조업',
#  'c282': '일차전지 및 이차전지 제조업',
#  'c283': '절연선 및 케이블 제조업',
#  'c284': '전구 및 조명장치 제조업',
#  'c285': '가정용 기기 제조업',
#  'c289': '기타 전기장비 제조업',
#  'c291': '일반 목적용 기계 제조업',
#  'c292': '특수 목적용 기계 제조업',
#  'c301': '자동차용 엔진 및 자동차 제조업',
#  'c302': '자동차 차체 및 트레일러 제조업',
#  'c303': '자동차 신품 부품 제조업',
#  'c304': '자동차 재제조 부품 제조업',
#  'c311': '선박 및 보트 건조업',
#  'c312': '철도장비 제조업',
#  'c313': '항공기, 우주선 및 부품 제조업',
#  'c319': '그 외 기타 운송장비 제조업',
#  'c320': '가구 제조업',
#  'c331': '귀금속 및 장신용품 제조업',
#  'c332': '악기 제조업',
#  'c333': '운동 및 경기용구 제조업',
#  'c334': '인형, 장난감 및 오락용품 제조업',
#  'c339': '그 외 기타 제품 제조업',
#  'c340': '산업용 기계 및 장비 수리업'}

# %%
file_path = '/home/osung/data/korean/modu/json/news_PEST_ksic_score_clean.tsv'

# %%
df = pd.read_csv(file_path, sep='\t')

# %%
len(df)
# Out:
# 1530052

# %%
df[:10]
# Out:
#                      id topic  \
# 0  NWRW2200000004.11879     P
# 1  NWRW1900000015.17529     P
# 2   NWRW1900000054.4560     P
# 3  NWRW2200000004.12649     P
# 4  NWRW1900000017.11178     P
# 5   NWRW1900000015.4072     P
# 6   NPRW2100000003.6303     P
# 7  NPRW1900000055.31119     P
# 8   NWRW1900000034.5678     P
# 9  NWRW1900000019.14197     P
#
#                                                 text  ksic  max_scores
# 0  코로나 환자 늘어 일반 중환자 치료 공백 코로나 바이러스 확산으로 위중증 환자가 급...  c271    0.462100
# 1   휴가때 골프 꼭 치고 싶으면 자비로 쳐라 허태열 대통령비서실장이 최근 수석비서관회...  c333    0.438204
# 2  이계안 정몽준 현대중 광고로 불법선거운동 현대그룹 전문경영인 출신의 이계안 민주통합...  c311    0.423902
# 3  인기끄는 포도딸기 바나나는 시들 소비자 입맛과 취향이 변하면서 대형 마트 인기 과일...  c103    0.412846
# 4  울산 현대 찾은 모디 조선업 파트너 돼달라 야드선박 건조장가 내려다보이는 배경으로 ...  c311    0.397418
# 5  농업분야 저서 10여권 과 30년 농림축산부 장관 후보자로 내정된 이동필 한국농촌경...  c103    0.395620
# 6  안철수 마스크 값만 월 60만원6500원짜리 마저도 품절 안철수 국민의당 대표가 신...  c271    0.394926
# 7  현대 수석부장은 누구 조선소 생활에 흠뻑 빠진 현대중공업의 정기선 경영기획팀 수석부...  c311    0.389997
# 8  안철수 공익재단 이름 안철수재단 확정 안철수 서울대 융합과학기술대학원장이 출연한 공...  c181    0.368741
# 9  청년 농업인 500명에 100만원 준다 문재인 대통령의 대선 공약이었던 청년 농업인...  c103    0.364516

# %%
df['ksic'].unique()
# Out:
# array(['c271', 'c333', 'c311', 'c103', 'c181', 'c301', 'c203', 'c192',
#        'c151', 'c262', 'c212', 'c101', 'c141', 'c319', 'c111', 'c172',
#        'c264', 'c139', 'c201', 'c222', 'c303', 'c182', 'c261', 'c102',
#        'c313', 'c332', 'c241', 'c108', 'c221', 'c259', 'c273', 'c233',
#        'c285', 'c120', 'c106', 'c213', 'c204', 'c171', 'c252', 'c331',
#        'c339', 'c191', 'c272', 'c134', 'c105', 'c211', 'c334', 'c144',
#        'c162', 'c304', 'c152', 'c107', 'c163', 'c283', 'c291', 'c312',
#        'c112', 'c282', 'c231', 'c251', 'c179', 'c232', 'c292', 'c340',
#        'c265', 'c131', 'c202', 'c242', 'c263', 'c132', 'c284', 'c239',
#        'c320', 'c266', 'c289', 'c161', 'c243', 'c281', 'c302', 'c143',
#        'c104', 'c274', 'c133', nan, 'c142'], dtype=object)

# %%
keywords = []
for text in tqdm(df.text) :
    keyword_count = extract_nouns_and_count(text)
    keywords.append(keyword_count)
# Out:
# 100%|██████████████████████████████| 1530052/1530052 [28:14:41<00:00, 15.05it/s]

# %%
len(keywords)
# Out:
# 1530052

# %%
keywords[100]
# Out:
# {'예비': 6,
#  '후보': 6,
#  '등': 6,
#  '오이': 5,
#  '칠곡': 4,
#  '권': 4,
#  '칠곡군': 4,
#  '수확': 3,
#  '권오을': 2,
#  '도지사': 2,
#  '왜관읍': 2,
#  '리': 2,
#  '자원봉사': 2,
#  '농가': 2,
#  '사업': 2,
#  '농촌': 2,
#  '대한': 2,
#  '또': 2,
#  '다른': 2,
#  '지역': 2,
#  '중앙정부': 2,
#  '지방정부': 2,
#  '민생': 1,
#  '투어': 1,
#  '새누리당': 1,
#  '경북': 1,
#  '군민': 1,
#  '민심': 1,
#  '파악': 1,
#  '위해': 1,
#  '직접': 1,
#  '작업': 1,
#  '오전': 1,
#  '로얄': 1,
#  '네거리': 1,
#  '출근': 1,
#  '인사': 1,
#  '뒤': 1,
#  '곧바로': 1,
#  '윤주': 1,
#  '섭씨': 1,
#  '금남': 1,
#  '농장': 1,
#  '동안': 1,
#  '도우': 1,
#  '면서': 1,
#  '윤씨': 1,
#  '로부터': 1,
#  '애로': 1,
#  '사항': 1,
#  '각종': 1,
#  '보조': 1,
#  '문제점': 1,
#  '지원': 1,
#  '개선': 1,
#  '점': 1,
#  '대해': 1,
#  '군청': 1,
#  '기자실': 1,
#  '기자간담회': 1,
#  '시': 1,
#  '승격': 1,
#  '여부': 1,
#  '대강': 1,
#  '중': 1,
#  '칠곡보': 1,
#  '활용': 1,
#  '현황': 1,
#  '현안': 1,
#  '의견': 1,
#  '수렴': 1,
#  '사랑': 1,
#  '집': 1,
#  '무료': 1,
#  '급식': 1,
#  '오후': 1,
#  '왜관': 1,
#  '경로당': 1,
#  '전통': 1,
#  '시장': 1,
#  '중앙': 1,
#  '로': 1,
#  '상가': 1,
#  '방문': 1,
#  '백합': 1,
#  '라이온스': 1,
#  '좌담': 1,
#  '회': 1,
#  '참석': 1,
#  '일정': 1,
#  '소화': 1,
#  '그': 1,
#  '도농복합도시': 1,
#  '소득': 1,
#  '고민': 1,
#  '음': 1,
#  '알': 1,
#  '말': 1,
#  '이제': 1,
#  '지방자치단체': 1,
#  '대집행': 1,
#  '기관': 1,
#  '시대': 1,
#  '가야': 1,
#  '외교': 1,
#  '국방': 1,
#  '안보': 1,
#  '교육': 1,
#  '복지': 1,
#  '삶': 1,
#  '직결': 1,
#  '문제': 1,
#  '실정': 1,
#  '집행': 1,
#  '강조': 1}

# %%
extract_nouns_and_count(df.loc[0].text)
# Out:
# {'환자': 11,
#  '코로나': 5,
#  '암': 5,
#  '일반': 3,
#  '중환자': 3,
#  '치료': 3,
#  '서울대': 3,
#  '명': 3,
#  '공백': 2,
#  '확산': 2,
#  '의료': 2,
#  '생기': 2,
#  '교수': 2,
#  '병원': 2,
#  '응급실': 2,
#  '약': 2,
#  '증가': 2,
#  '로': 2,
#  '바이러스': 1,
#  '위중': 1,
#  '증': 1,
#  '인력': 1,
#  '집중': 1,
#  '대처': 1,
#  '차질': 1,
#  '현장': 1,
#  '등': 1,
#  '목소리': 1,
#  '김범': 1,
#  '석': 1,
#  '혈액': 1,
#  '종양': 1,
#  '내과': 1,
#  '팀': 1,
#  '사망': 1,
#  '분석': 1,
#  '결과': 1,
#  '세상': 1,
#  '대폭': 1,
#  '것': 1,
#  '말기': 1,
#  '체류': 1,
#  '시간': 1,
#  '생존': 1,
#  '위해': 1,
#  '강제': 1,
#  '혈압': 1,
#  '승': 1,
#  '압제': 1,
#  '사용': 1,
#  '수도': 1,
#  '포인트': 1,
#  '심폐소생술': 1,
#  '김': 1,
#  '이': 1,
#  '때문': 1,
#  '소외': 1,
#  '방치': 1,
#  '사실': 1,
#  '말': 1}

# %%
extract_nouns_and_count(df.loc[1].text)
# Out:
# {'골프': 6,
#  '것': 4,
#  '말': 3,
#  '휴가': 2,
#  '때': 2,
#  '꼭': 2,
#  '문제': 2,
#  '출범': 2,
#  '실장': 2,
#  '허태열': 1,
#  '대통령비서실장': 1,
#  '최근': 1,
#  '석비': 1,
#  '서관': 1,
#  '회의': 1,
#  '주재': 1,
#  '사람': 1,
#  '사람과': 1,
#  '필드': 1,
#  '골프장': 1,
#  '대신': 1,
#  '스크린골프': 1,
#  '이용': 1,
#  '게': 1,
#  '박근혜': 1,
#  '정부': 1,
#  '이후': 1,
#  '금지': 1,
#  '령': 1,
#  '북한': 1,
#  '위협': 1,
#  '이어진': 1,
#  '데': 1,
#  '정권': 1,
#  '긴장감': 1,
#  '공직자': 1,
#  '칠': 1,
#  '엄두': 1,
#  '내지': 1,
#  '이': 1,
#  '관련': 1,
#  '박': 1,
#  '대통령': 1,
#  '언론사': 1,
#  '논설': 1,
#  '오찬': 1,
#  '캐디': 1,
#  '수입': 1,
#  '자꾸': 1,
#  '외국': 1,
#  '걱정': 1,
#  '이야기': 1,
#  '지금': 1,
#  '여러': 1,
#  '가지': 1,
#  '생각': 1,
#  '청와대': 1,
#  '관계자': 1,
#  '자비': 1,
#  '취미': 1,
#  '삼': 1,
#  '수야': 1,
#  '며': 1,
#  '이제': 1,
#  '선언': 1,
#  '자연': 1,
#  '분위기': 1,
#  '발언': 1,
#  '관가': 1,
#  '치': 1,
#  '반응': 1}

# %%
A = keywords[10]

# %%
A
# Out:
# {'등': 5,
#  '올해': 4,
#  '현대차': 4,
#  '기아': 4,
#  '것': 3,
#  '차': 3,
#  '판매': 3,
#  '판매량': 2,
#  '절반': 2,
#  '승용차': 2,
#  '중': 2,
#  '대가': 2,
#  '세단': 2,
#  '차종': 2,
#  '제': 2,
#  '업계': 2,
#  '수': 2,
#  '인기': 2,
#  '지속': 2,
#  '현대': 1,
#  '기아차': 1,
#  '판': 1,
#  '미니밴': 1,
#  '레저': 1,
#  '용': 1,
#  '차량': 1,
#  '인': 1,
#  '종이': 1,
#  '사상': 1,
#  '처음': 1,
#  '다른': 1,
#  '비율': 1,
#  '이상': 1,
#  '달성': 1,
#  '가능성': 1,
#  '점': 1,
#  '국내': 1,
#  '집계': 1,
#  '카니발': 1,
#  '투싼': 1,
#  '쏘렌토': 1,
#  '주력': 1,
#  '년': 1,
#  '대비': 1,
#  '배': 1,
#  '제네시스': 1,
#  '고급': 1,
#  '확대': 1,
#  '데': 1,
#  '연초': 1,
#  '연간': 1,
#  '누적': 1,
#  '전망': 1,
#  '수납': 1,
#  '공간': 1,
#  '수년': 1,
#  '작년': 1,
#  '코로나': 1,
#  '여파': 1,
#  '박차': 1,
#  '숙박': 1,
#  '열풍': 1,
#  '불어': 1,
#  '수요': 1,
#  '관계자': 1,
#  '시장': 1,
#  '선호': 1,
#  '현상': 1,
#  '당분간': 1,
#  '말': 1}

# %%
f = {key: A[key]}
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2102719/2302600656.py in <module>
# ----> 1 f = {key: A[key]}
#
# KeyError: 'c340'

# %%
A.keys()
# Out:
# dict_keys(['등', '올해', '현대차', '기아', '것', '차', '판매', '판매량', '절반', '승용차', '중', '대가', '세단', '차종', '제', '업계', '수', '인기', '지속', '현대', '기아차', '판', '미니밴', '레저', '용', '차량', '인', '종이', '사상', '처음', '다른', '비율', '이상', '달성', '가능성', '점', '국내', '집계', '카니발', '투싼', '쏘렌토', '주력', '년', '대비', '배', '제네시스', '고급', '확대', '데', '연초', '연간', '누적', '전망', '수납', '공간', '수년', '작년', '코로나', '여파', '박차', '숙박', '열풍', '불어', '수요', '관계자', '시장', '선호', '현상', '당분간', '말'])

# %%
filtered = {key: A[key] for key in KSIC_keywords if key in A}

# %%
filtered
# Out:
# {'코로나': 1,
#  '종이': 1,
#  '제네시스': 1,
#  '현대차': 4,
#  '기아': 4,
#  '승용차': 2,
#  '현대': 1,
#  '차량': 1,
#  '기아차': 1}

# %%
df.iloc[10].text
# Out:
# '올해 현대기아차 판매량 절반이 RV 올해 들어 현대차기아가 판 승용차 2대 중 1대가 SUV미니밴 등 레저용 차량RV인 것으로 나타났다 올해 RV 차종이 사상 처음으로 세단 등 다른 차종을 제치고 판매 비율 50 이상을 달성할 가능성이 점쳐진다 현대차기아는 올 12월 국내에서 팔린 승용차 15만7488대 중 528만1938대가 RV 차종으로 집계됐다고 21일 밝혔다 카니발1만4196대 투싼1만2602대 쏘렌토1만2425대 등 현대차기아의 주력 SUV 판매가 전년 대비 23배씩 늘었고 제네시스 GV704973대GV803155대 등 고급 SUV 판매도 확대된 데 따른 것이다 아직 연초지만 업계에선 올해는 현대차기아의 연간 누적 판매량에서 RV가 세단 등을 제치고 절반을 넘어설 수 있다는 전망이 나오고 있다 수납공간이 넉넉한 SUV는 수년째 인기가 지속돼왔다 특히 작년부터 코로나 여파로 차박차에서 숙박 열풍까지 불어닥치면서 RV 수요가 많이 늘어났다 업계 관계자는 내수 시장에서 큰 차를 선호하는 현상이 이어지고 있어 당분간 RV 인기가 지속할 것이라고 말했다'

# %%
filtered_keywords = []

for A in tqdm(keywords) :
    filtered = {key: A[key] for key in KSIC_keywords if key in A}
    filtered_keywords.append(filtered)
# Out:
# 100%|███████████████████████████████| 1530052/1530052 [05:23<00:00, 4726.98it/s]

# %%
filtered_keywords[50:150]
# Out:
# [{'공격': 1, '코로나': 16, '전쟁': 7, '의료': 2, '전선': 1, '의사': 7, '전화': 1},
#  {'중공업': 10, '유지': 1, '자동차': 1, '울산': 1, '현대': 7},
#  {'축산': 2, '농가': 1, '방역': 6, '구제역': 9, '김치': 1, '농민': 1, '확산': 3},
#  {'유전자': 1, '김': 2, '코로나': 4, '확진': 1, '격리': 3, '검사': 5, '진단': 2},
#  {'김': 4, '농업': 3, '농협': 6, '농업인': 1, '양곡': 1, '농민': 1, '농촌': 3},
#  {'김': 6, '바이러스': 1, '코로나': 5, '병원': 6, '환자': 1, '감염증': 1, '검사': 11},
#  {'코로나': 3, '확진': 2, '감염증': 1, '검사': 3, '마스크': 2},
#  {'코로나': 5, '병원': 46, '감염': 6, '환자': 5, '의료': 10, '격리': 2, '폭탄': 1, '담요': 1},
#  {'강화': 2, '세제': 1, '유지': 1, '스포츠': 2, '기능': 1, '체육': 14},
#  {'코로나': 6,
#   '방역': 3,
#   '백신': 1,
#   '의료': 8,
#   '감염증': 1,
#   '의사': 1,
#   '정비': 1,
#   '의자': 1,
#   '검사': 3,
#   '확산': 1},
#  {'신문': 11, '인터넷': 1, '광고': 1},
#  {'김': 4, '양복': 5},
#  {'코로나': 4,
#   '병원': 12,
#   '기타': 1,
#   '환자': 5,
#   '의료': 8,
#   '치료': 5,
#   '확진': 2,
#   '격리': 1,
#   '건강': 1,
#   '의사': 1,
#   '컨테이너': 1,
#   '재활': 1,
#   '퇴원': 1},
#  {'농장': 1,
#   '농가': 3,
#   '쌀': 1,
#   '농업': 8,
#   '오이': 1,
#   '귀농': 2,
#   '생산량': 1,
#   '곡물': 1,
#   '농민': 11,
#   '농촌': 9},
#  {'농가': 4,
#   '농업': 4,
#   '친환경': 1,
#   '자리': 1,
#   '오이': 4,
#   '농산물': 1,
#   '농민': 2,
#   '농사': 1,
#   '망': 1,
#   '농촌': 2},
#  {'강화': 5, '자리': 1, '군수': 5},
#  {'코로나': 3, '감염': 4, '감염증': 1, '격리': 1, '과도': 1, '검사': 3, '마스크': 5, '망': 1},
#  {'소주': 1,
#   '코로나': 1,
#   '백신': 1,
#   '의료': 2,
#   '감염증': 1,
#   '건강': 2,
#   '의사': 2,
#   '담배': 2,
#   '가운': 2},
#  {'바이러스': 26, '코로나': 11, '종이': 1, '감염': 4, '백신': 2, '자기': 1, '확산': 3, '복제': 1},
#  {'코로나': 2,
#   '병원': 7,
#   '도미': 1,
#   '산소': 1,
#   '의료': 2,
#   '치료': 6,
#   '확진': 1,
#   '감염증': 1,
#   '격리': 1,
#   '퇴원': 5},
#  {'코로나': 1, '감염': 1, '의료': 1, '콩': 1, '제약': 1, '마스크': 16},
#  {'조선': 2,
#   '조선소': 8,
#   '중공업': 7,
#   '코로나': 1,
#   '장기': 1,
#   '유지': 1,
#   '재활용': 1,
#   '현대': 5,
#   '수소': 1},
#  {'김': 2, '조선': 1, '중공업': 8, '울산': 3, '현대': 7},
#  {'농가': 3,
#   '무': 3,
#   '농협': 1,
#   '광폭': 1,
#   '농산물': 1,
#   '고무장화': 1,
#   '채소': 4,
#   '바지': 1,
#   '출하': 1,
#   '농민': 7,
#   '농사': 3,
#   '농촌': 2,
#   '배추': 8},
#  {'김': 4,
#   '선박': 1,
#   '트럭': 1,
#   '버스': 1,
#   '충전': 1,
#   '항만': 1,
#   '충전기': 1,
#   '모빌리티': 1,
#   '전지': 1,
#   '탄소': 3,
#   '확산': 2,
#   '수소': 11,
#   '전기': 1,
#   '연료': 1},
#  {'폐기물': 3, '플라스틱': 5, '재활용': 1, '포장': 10, '재생': 1, '재활': 2},
#  {'코로나': 2, '보건복지부': 1, '백신': 11},
#  {'수리': 1, '의치': 1, '김': 1, '조선': 5, '조선소': 6, '자리': 1, '석유화학': 1, '해운': 3},
#  {'분석': 1,
#   '바이러스': 1,
#   '코로나': 17,
#   '감염': 3,
#   '방역': 2,
#   '치료': 1,
#   '확진': 8,
#   '감염증': 2,
#   '격리': 2,
#   '건강': 1,
#   '검사': 1,
#   '마스크': 1},
#  {'전자': 1,
#   '부품': 1,
#   '가전': 1,
#   '자동차': 5,
#   '기계': 1,
#   '벤츠': 1,
#   '운전대': 8,
#   '신호': 1,
#   '차량': 1},
#  {'진주': 3,
#   '딸기': 8,
#   '농가': 4,
#   '농업': 5,
#   '부품': 1,
#   '농협': 3,
#   '농업인': 1,
#   '농산물': 1,
#   '수확': 1,
#   '공작': 1,
#   '항공': 1,
#   '농민': 1,
#   '확산': 1,
#   '우주': 1},
#  {'디지털': 1, '커버': 1, '도서관': 24},
#  {'진주': 1,
#   '정장': 3,
#   '재킷': 1,
#   '양복': 2,
#   '청바지': 3,
#   '드레스': 3,
#   '바지': 1,
#   '인터넷': 1,
#   '목걸이': 1,
#   '승용차': 1,
#   '티셔츠': 3,
#   '넥타이': 1,
#   '스카프': 1},
#  {'유전자': 1,
#   '바이러스': 3,
#   '코로나': 2,
#   '방역': 1,
#   '백신': 2,
#   '확진': 3,
#   '격리': 5,
#   '질병': 1,
#   '검사': 1},
#  {'강화': 1, '농업': 11, '농업인': 1, '농촌': 10},
#  {'바이러스': 1, '코로나': 2, '감염': 3, '방역': 2, '환자': 1, '확진': 4, '검사': 5, '진단': 2},
#  {'전자': 6, '분석': 1, '갤럭시': 1, '당면': 1, '삼성': 7},
#  {'화학': 1,
#   '폐기물': 1,
#   '바이러스': 2,
#   '감염': 3,
#   '방역': 5,
#   '운동': 1,
#   '세탁': 1,
#   '마리': 1,
#   '필터': 5,
#   '마스크': 18},
#  {'코로나': 6, '감염': 1, '방역': 1, '백신': 1, '의료': 1, '검사': 6, '진단': 3},
#  {'전자': 13,
#   '반도체': 1,
#   '드라이브': 1,
#   '사진': 1,
#   '소니': 1,
#   '통신': 1,
#   '갤럭시': 1,
#   '재단': 1,
#   '삼성': 14},
#  {'전자': 7, '정비': 1, '삼성': 9},
#  {'코로나': 1, '농업': 6, '농업인': 1, '라면': 1, '농민': 9, '농촌': 5},
#  {'김': 6, '바이러스': 1, '유지': 1, '펌프': 3, '전화': 1, '검사': 32, '도박': 1},
#  {'김': 12,
#   '코로나': 7,
#   '방역': 1,
#   '확진': 8,
#   '조명': 1,
#   '격리': 3,
#   '건강': 1,
#   '검사': 3,
#   '공정': 1},
#  {'코로나': 2, '바이오': 2, '백신': 8, '끈': 1, '출하': 2},
#  {'운동': 2, '스포츠': 11, '체육': 13, '축구': 1},
#  {'코로나': 3, '병원': 3, '환자': 3, '의료': 4, '치료': 10, '격리': 1, '건강': 1},
#  {'컴퓨터': 1, '모자': 1, '사진': 1, '노트북': 1, '재단': 22},
#  {'코로나': 5, '방역': 1, '감염증': 1, '격리': 6, '검사': 2, '진단': 1},
#  {'포드': 1,
#   '전기차': 1,
#   '친환경': 1,
#   '아우디': 1,
#   '제네시스': 2,
#   '현대차': 8,
#   '자동차': 3,
#   '도요타': 1},
#  {'농장': 1, '농가': 2, '백합': 1, '오이': 5, '수확': 3, '국방': 1, '농촌': 2},
#  {'라디오': 1, '방송': 1, '전화': 3, '휴대전화': 6},
#  {'중공업': 5, '유지': 1, '자동차': 1, '재단': 1, '울산': 1, '현대': 5},
#  {'코로나': 3, '전쟁': 1, '감염': 1, '의료': 1, '제약': 1, '필터': 1, '마스크': 11},
#  {'전자': 4,
#   '조선': 1,
#   '확대경': 1,
#   '하이닉스': 2,
#   '반도체': 6,
#   '자동차': 1,
#   '해운': 1,
#   '메모리': 1,
#   '삼성': 4},
#  {'농가': 2,
#   '쌀': 1,
#   '영농': 7,
#   '농업': 5,
#   '친환경': 6,
#   '자리': 1,
#   '옥수수': 1,
#   '유기농': 3,
#   '농산물': 2,
#   '군수': 1,
#   '양배추': 1},
#  {'수산': 5, '스마트': 1, '양식': 2, '항만': 2, '어촌': 2},
#  {'식품': 1, '농업': 3, '친환경': 9, '어업': 9, '양식': 2},
#  {'디지털': 1,
#   '바이러스': 1,
#   '코로나': 2,
#   '친환경': 1,
#   '방역': 1,
#   '자리': 1,
#   '방송': 1,
#   '질병': 1,
#   '탄소': 2,
#   '마스크': 14,
#   '확산': 1,
#   '철도': 1},
#  {'김': 2, '감사패': 2, '쌀': 1, '농업': 2, '농업인': 12, '농민': 1, '농촌': 2},
#  {'화학': 3,
#   '수주': 1,
#   '폴리프로필렌': 1,
#   '가스': 4,
#   '석유화학': 3,
#   '유지': 1,
#   '폴리에틸렌': 1,
#   '천연가스': 1,
#   '현대': 1},
#  {'김': 2,
#   '수산': 1,
#   '농가': 1,
#   '농업': 14,
#   '친환경': 1,
#   '농산물': 1,
#   '감': 1,
#   '자기': 1,
#   '확산': 1,
#   '농촌': 2},
#  {'진주': 1, '부품': 2, '항공': 4, '목도리': 1, '우주': 2},
#  {'중공업': 7, '울산': 2, '현대': 5},
#  {'코로나': 4, '감염': 1, '방역': 1, '확진': 5, '감염증': 1, '격리': 3, '실': 2, '검사': 1},
#  {'코로나': 2, '감염': 3, '소독': 1, '격리': 2, '도정': 1, '의사': 1, '검사': 2, '확산': 1},
#  {'김': 1, '코로나': 6, '병원': 4, '환자': 1, '의료': 4, '감염증': 1, '운동': 1},
#  {'코로나': 1, '방송': 2, '국악': 11},
#  {'친환경': 1, '부품': 5, '자동차': 5},
#  {'코로나': 6, '방역': 1, '확진': 2, '감염증': 1, '검사': 8, '진단': 2},
#  {'자리': 1, '스마트': 20, '스마트폰': 1},
#  {'조선': 1, '조선소': 2, '중공업': 8, '장기': 1, '유지': 2, '울산': 1, '현대': 3},
#  {'전자': 9, '제철소': 1, '반도체': 3, '포스코': 3, '삼성': 11, '철강': 1},
#  {'전자': 4, '부품': 1, '반도체': 4, '의사': 2, '사진': 1, '삼성': 8, '디스플레이': 2},
#  {'강화': 1, '의사': 1, '포스코': 8, '철강': 1},
#  {'면역': 1,
#   '김': 3,
#   '분석': 1,
#   '바이러스': 5,
#   '코로나': 5,
#   '방역': 3,
#   '백신': 1,
#   '질병': 1,
#   '확산': 2,
#   '진단': 1},
#  {'부품': 7, '자동차': 11, '인터넷': 1, '자기': 1},
#  {'코로나': 2, '한복': 18, '방역': 1, '백신': 1, '자리': 1, '감염증': 1, '확산': 1},
#  {'코로나': 5, '방역': 1, '장기': 1, '감': 1, '검사': 3, '확산': 1, '진단': 2},
#  {'코로나': 2, '농가': 1, '선지': 5, '농업인': 6, '농산물': 4, '출하': 2},
#  {'강화': 1, '조선': 6, '조선소': 9, '중공업': 6, '현대': 3},
#  {'고양이': 3, '유지': 1, '사진': 1, '수렵': 1},
#  {'검사': 15},
#  {'코로나': 4, '방역': 3, '백신': 1, '의료': 1, '치료': 2, '드라이브': 1, '라면': 1, '진단': 2},
#  {'스마트': 25, '스마트폰': 1},
#  {'코로나': 1, '감염': 3, '소독': 3, '비닐': 7, '질병': 1, '위생': 11, '장갑': 15},
#  {'바이러스': 1,
#   '코로나': 2,
#   '유가': 10,
#   '석유': 5,
#   '배럴': 7,
#   '정유': 1,
#   '원유': 3,
#   '항공': 1,
#   '탄소': 1,
#   '확산': 1},
#  {'라디오': 1, '김': 1, '기타': 1, '감염': 1, '의료': 1, '제약': 1, '측정': 1, '마스크': 18},
#  {'농가': 6, '건강': 1, '양파': 4, '농촌': 2},
#  {'소음': 1, '친환경': 2, '테슬라': 2, '자동차': 2, '전지': 1, '전기': 1, '전기자동차': 4},
#  {'김': 3, '코로나': 7, '자리': 1, '확진': 3, '검사': 6},
#  {'바이러스': 1,
#   '코로나': 8,
#   '감염': 6,
#   '치료': 1,
#   '확진': 2,
#   '격리': 1,
#   '검사': 2,
#   '마스크': 1,
#   '망': 1},
#  {'코로나': 7,
#   '병원': 3,
#   '감염': 2,
#   '방역': 1,
#   '확진': 2,
#   '감염증': 1,
#   '격리': 3,
#   '질병': 1,
#   '검사': 13,
#   '삼성': 4,
#   '진단': 3},
#  {'강화': 1,
#   '김': 4,
#   '조선': 1,
#   '조선소': 12,
#   '선박': 8,
#   '수주': 3,
#   '상선': 8,
#   '건조': 1,
#   '해운': 1,
#   '유조선': 1,
#   '원유': 1,
#   '현대': 3,
#   '서해안': 1},
#  {'김': 2,
#   '중공업': 2,
#   '선박': 1,
#   '육군': 1,
#   '석유화학': 1,
#   '탑': 2,
#   '자동차': 1,
#   '울산': 15,
#   '포장': 1,
#   '현대': 3,
#   '실': 1},
#  {'원피스': 11,
#   '정장': 3,
#   '자리': 1,
#   '셔츠': 1,
#   '양복': 1,
#   '운동화': 1,
#   '사진': 1,
#   '청바지': 1,
#   '반바지': 3,
#   '인터넷': 1,
#   '티셔츠': 4,
#   '넥타이': 1,
#   '망': 1},
#  {'코로나': 6, '방역': 3, '확진': 2, '감염증': 1, '격리': 1, '검사': 7, '마스크': 2, '진단': 2},
#  {'식품': 2,
#   '쌀': 1,
#   '농업': 10,
#   '자리': 1,
#   '스마트': 3,
#   '농업인': 3,
#   '방어': 1,
#   '축산물': 1,
#   '농민': 1,
#   '농촌': 2},
#  {'분석': 1, '반도체': 20, '통신': 1, '웨이퍼': 2, '데이터': 3},
#  {'병원': 13, '의료': 5}]

# %%
df.columns
# Out:
# Index(['id', 'topic', 'text', 'ksic', 'max_scores', 'keywords',
#        'keywords_orig'],
#       dtype='object')

# %%
df['keywords_orig'] = keywords

# %%
df['keywords'] = filtered_keywords

# %%
df.loc[10].keywords
# Out:
# {'코로나': 1,
#  '종이': 1,
#  '제네시스': 1,
#  '현대차': 4,
#  '기아': 4,
#  '승용차': 2,
#  '현대': 1,
#  '차량': 1,
#  '기아차': 1}

# %%
len(keywords)
# Out:
# 1530052

# %%
keywords[10]
# Out:
# {'등': 5,
#  '올해': 4,
#  '현대차': 4,
#  '기아': 4,
#  '것': 3,
#  '차': 3,
#  '판매': 3,
#  '판매량': 2,
#  '절반': 2,
#  '승용차': 2,
#  '중': 2,
#  '대가': 2,
#  '세단': 2,
#  '차종': 2,
#  '제': 2,
#  '업계': 2,
#  '수': 2,
#  '인기': 2,
#  '지속': 2,
#  '현대': 1,
#  '기아차': 1,
#  '판': 1,
#  '미니밴': 1,
#  '레저': 1,
#  '용': 1,
#  '차량': 1,
#  '인': 1,
#  '종이': 1,
#  '사상': 1,
#  '처음': 1,
#  '다른': 1,
#  '비율': 1,
#  '이상': 1,
#  '달성': 1,
#  '가능성': 1,
#  '점': 1,
#  '국내': 1,
#  '집계': 1,
#  '카니발': 1,
#  '투싼': 1,
#  '쏘렌토': 1,
#  '주력': 1,
#  '년': 1,
#  '대비': 1,
#  '배': 1,
#  '제네시스': 1,
#  '고급': 1,
#  '확대': 1,
#  '데': 1,
#  '연초': 1,
#  '연간': 1,
#  '누적': 1,
#  '전망': 1,
#  '수납': 1,
#  '공간': 1,
#  '수년': 1,
#  '작년': 1,
#  '코로나': 1,
#  '여파': 1,
#  '박차': 1,
#  '숙박': 1,
#  '열풍': 1,
#  '불어': 1,
#  '수요': 1,
#  '관계자': 1,
#  '시장': 1,
#  '선호': 1,
#  '현상': 1,
#  '당분간': 1,
#  '말': 1}

# %%
def get_ksic_score(f_keywords) :
    ksic_score = {}

    for key, value in f_keywords.items() :
        #print(key, value)
    
        ksic_list = get_KSIC(key)
        #print(ksic_list)
        for ksic in ksic_list :
            if ksic not in ksic_score:
                ksic_score[ksic] = 0
            
            ksic_score[ksic] += value
            
    return ksic_score

# %%
ksic_score
# Out:
# {'c271': 1, 'c171': 1, 'c301': 13, 'c311': 1, 'c303': 1, 'c312': 1, 'c319': 1}

# %%
ksic_score_list = []

for f_keywords in tqdm(filtered_keywords) :
    ksic_score = get_ksic_score(f_keywords)
    ksic_score_list.append(ksic_score)
# Out:
# 100%|███████████████████████████████| 1530052/1530052 [07:55<00:00, 3219.87it/s]

# %%
df['ksic_scores'] = ksic_score_list

# %%
ksic_score_list[:10]
# Out:
# [{'c102': 1, 'c272': 1, 'c211': 2, 'c271': 24, 'c213': 2, 'c203': 2},
#  {'c333': 6},
#  {'c264': 1, 'c311': 17, 'c152': 1, 'c333': 1, 'c339': 7, 'c301': 8},
#  {'c272': 1, 'c103': 33, 'c271': 2, 'c273': 1, 'c251': 1, 'c101': 1},
#  {'c311': 26, 'c192': 3, 'c201': 1, 'c273': 1, 'c285': 5, 'c301': 4},
#  {'c101': 6,
#   'c102': 1,
#   'c103': 12,
#   'c104': 1,
#   'c105': 1,
#   'c106': 1,
#   'c107': 2,
#   'c112': 1,
#   'c172': 1,
#   'c273': 1,
#   'c264': 1},
#  {'c271': 19,
#   'c213': 11,
#   'c106': 1,
#   'c340': 1,
#   'c264': 1,
#   'c101': 1,
#   'c102': 1,
#   'c103': 1,
#   'c139': 12,
#   'c203': 1},
#  {'c311': 11, 'c301': 3},
#  {'c181': 22},
#  {'c103': 20, 'c101': 1}]

# %%
def find_max_value_keys(input_dict):
    # dict가 비어있는 경우 빈 리스트 반환
    if not input_dict:
        return []

    # 가장 큰 value 찾기
    max_value = max(input_dict.values())
    
    # max_value와 일치하는 모든 key를 리스트로 모으기
    max_keys = [key for key, value in input_dict.items() if value == max_value]

    return max_keys

# %%
max_key_list = []

for ksic_score in tqdm(ksic_score_list) :
    max_keys = find_max_value_keys(ksic_score)
    max_key_list.append(max_keys)
# Out:
# 100%|███████████████████████████████| 1530052/1530052 [02:59<00:00, 8526.08it/s]

# %%
df['max_ksic'] = max_key_list

# %%
max_key_list[:100]
# Out:
# [['c271'],
#  ['c333'],
#  ['c311'],
#  ['c103'],
#  ['c311'],
#  ['c103'],
#  ['c271'],
#  ['c311'],
#  ['c181'],
#  ['c103'],
#  ['c301'],
#  ['c203'],
#  ['c301'],
#  ['c271'],
#  ['c192'],
#  ['c151'],
#  ['c151'],
#  ['c262'],
#  ['c212'],
#  ['c311'],
#  ['c101'],
#  ['c192'],
#  ['c271'],
#  ['c271'],
#  ['c141'],
#  ['c262'],
#  ['c192'],
#  ['c271'],
#  ['c103'],
#  ['c319'],
#  ['c111'],
#  ['c262'],
#  ['c172'],
#  ['c271'],
#  ['c271'],
#  ['c271'],
#  ['c192'],
#  ['c103'],
#  ['c103'],
#  ['c333'],
#  ['c264'],
#  ['c264'],
#  ['c271'],
#  ['c103'],
#  ['c271'],
#  ['c271'],
#  ['c271'],
#  ['c262'],
#  ['c264'],
#  ['c103'],
#  ['c271'],
#  ['c311'],
#  ['c203'],
#  ['c271'],
#  ['c103'],
#  ['c271'],
#  ['c271'],
#  ['c271'],
#  ['c333'],
#  ['c271'],
#  ['c181'],
#  ['c141'],
#  ['c271'],
#  ['c103'],
#  ['c103'],
#  ['c231', 'c319'],
#  ['c271'],
#  ['c271'],
#  ['c271'],
#  ['c271'],
#  ['c271'],
#  ['c311'],
#  ['c311'],
#  ['c103'],
#  ['c201'],
#  ['c222'],
#  ['c212'],
#  ['c311'],
#  ['c271'],
#  ['c303'],
#  ['c103'],
#  ['c182'],
#  ['c141'],
#  ['c271'],
#  ['c103'],
#  ['c271'],
#  ['c262'],
#  ['c271', 'c139'],
#  ['c271'],
#  ['c262'],
#  ['c262'],
#  ['c103'],
#  ['c271'],
#  ['c271'],
#  ['c212'],
#  ['c333'],
#  ['c271'],
#  ['c181'],
#  ['c271'],
#  ['c301']]

# %%
len(max_key_list[87])
# Out:
# 2

# %%
df['max_ksic'][:100]
# Out:
# 0     [c271]
# 1     [c333]
# 2     [c311]
# 3     [c103]
# 4     [c311]
#        ...
# 95    [c333]
# 96    [c271]
# 97    [c181]
# 98    [c271]
# 99    [c301]
# Name: max_ksic, Length: 100, dtype: object

# %%
df.columns
# Out:
# Index(['id', 'topic', 'text', 'ksic', 'max_scores', 'keywords',
#        'keywords_orig', 'ksic_scores', 'max_ksic'],
#       dtype='object')

# %%
for index, row in df[:1000].iterrows() :
    if len(row['max_ksic']) > 1 :
        print(index, row['max_ksic'], row['ksic_scores'][row['max_ksic'][0]])
# Out:
# 65 ['c231', 'c319'] 5
# 87 ['c271', 'c139'] 23
# 118 ['c303', 'c304'] 10
# 126 ['c303', 'c304'] 18
# 150 ['c151', 'c172'] 19
# 153 ['c192', 'c201'] 17
# 175 ['c233', 'c320'] 14
# 235 ['c106', 'c340'] 9
# 249 ['c271', 'c139'] 23
# 251 ['c213', 'c271'] 25
# 337 ['c301', 'c303', 'c304'] 29
# 354 ['c151', 'c172'] 18
# 448 ['c102', 'c203'] 5
# 465 ['c102', 'c319'] 12
# 474 ['c259', 'c340'] 16
# 504 ['c211', 'c212'] 10
# 509 ['c151', 'c172'] 9
# 537 ['c233', 'c320'] 10
# 553 ['c162', 'c320'] 14
# 607 ['c313', 'c319'] 3
# 648 ['c101', 'c103'] 10
# 654 ['c271', 'c213'] 16
# 665 ['c212', 'c163'] 2
# 667 ['c201', 'c239'] 10
# 717 ['c106', 'c340'] 8
# 720 ['c262', 'c261'] 16
# 729 ['c233', 'c320'] 12
# 732 ['c201', 'c239'] 11
# 745 ['c102', 'c271'] 10
# 772 ['c233', 'c320'] 17
# 816 ['c233', 'c320'] 12
# 848 ['c192', 'c201'] 16
# 850 ['c303', 'c304'] 33
# 870 ['c201', 'c239'] 18
# 900 ['c313', 'c319'] 11
# 929 ['c201', 'c239'] 7
# 936 ['c233', 'c320'] 16
# 970 ['c106', 'c340'] 8
# 990 ['c201', 'c239'] 11

# %%
df.loc[448].text
# Out:
# '김부겸 총리 11명 식사 방역수칙 위반 반성한다 중앙안전대책본부장을 맡고 있는 김부겸 국무총리가 최근 수도권 방역지침을 어기고 11명이 모인 식사 자리에 참석한 것으로 드러났다 11일 KBS 보도에 따르면 김 총리는 지난 6일 서울 삼청동 총리공관에서 대학 동기 등 10명과 함께 사진을 찍었다 KBS는 식사 중간에 참석자 중 한 명이 촬영한 사진을 3장 공개했다 3장에 담긴 인물은 총 10명이고 촬영한 사람까지 더하면 총 11명이다 현행 사회적 거리두기 규정상 수도권에선 10인까지만 사적 모임이 가능한 데 방역수칙을 어긴 것이다 김 총리 측은 이날 원래 김 총리를 포함해 총 10명이 모일 예정이었는데 이 중 한 명의 배우자가 추가로 참석해 11명이 됐다고 설명했다 방역수칙을 위반하지 않으려면 10명만 식사를 해야 했지만 김 총리가 밥은 먹고 가야지 어떻게 하겠느냐며 식사를 함께했다고 한다 이에 총리실 관계자는 김 총리가 방역책임자로서 적절치 못한 행동을 해 반성한다는 입장을 밝혔다고 전했다'

# %%
df.loc[448].keywords
# Out:
# {'김': 5, '방역': 5, '자리': 1, '사진': 2}

# %%
df.columns
# Out:
# Index(['id', 'topic', 'text', 'ksic', 'max_scores', 'keywords',
#        'keywords_orig', 'ksic_scores', 'max_ksic'],
#       dtype='object')

# %%
df.to_csv('/home/osung/data/korean/modu/json/news_PEST_ksic_score_240903.tsv', sep='\t')

# %%
df.loc[10]['max_ksic']
# Out:
# ['c301']

# %%
df.loc[10]['ksic_scores']
# Out:
# {'c271': 1, 'c171': 1, 'c301': 13, 'c311': 1, 'c303': 1, 'c312': 1, 'c319': 1}

# %%
df['ksic_count'] = df['max_ksic'].apply(lambda x:len(x))

# %%
df[:100]['ksic_count']
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#      ..
# 95    1
# 96    1
# 97    1
# 98    1
# 99    1
# Name: ksic_count, Length: 100, dtype: int64

# %%
df['ksic_count'].value_counts().sort_index()
# Out:
# 0       23666
# 1     1201074
# 2      194314
# 3       59252
# 4       28482
# 5       11241
# 6        5362
# 7        2837
# 8        1342
# 9        1462
# 10        478
# 11        252
# 12        122
# 13         65
# 14         44
# 15         12
# 16         19
# 17         11
# 18          2
# 19          5
# 20          6
# 21          2
# 22          1
# 23          1
# Name: ksic_count, dtype: int64

# %%
df['ksic_count'].max()
# Out:
# 23

# %%
df0 = df[df['ksic_count'] == 0]

# %%
len(df0)
# Out:
# 23666

# %%
df0.iloc[0].text
# Out:
# '새 방송통신위원장에 최성준 판사 내정 이경재 위원장 사실상 경질 박근혜 대통령은 14일 신임 방송통신위원회 위원장에 최성준 서울고등법원 부장판사를 내정했다 오는 25일 임기가 만료되는 이경재 위원장은 이계철 전 위원장의 잔여 임기만 채우고 1년 만에 물러나게 됐다 청와대 민경욱 대변인은 법원의 주요 보직을 두루 거치며 리더십과 재판역량 등을 인정받았고 한국정보법학회 회장을 역임하는 등 관련 전문성과 경험을 갖추고 있다고 인선 배경을 설명했다 서울 출신인 최 내정자는 경기고서울대 법학과를 졸업하고 1986년 판사에 임용됐으며 특허법원 수석부장판사 춘천지방법원장 등을 역임했다 방송통신 분야와 직접적 연관성은 없다 최 내정자는 방통위도 법을 집행하는 기관이라며 법원이 국민 눈높이에 맞춰 재판하듯이 방송통신 이용자들을 잘 헤아려 정책에 반영하겠다고 말했다 대표적 친박 인사인 이경재 위원장의 연임 실패는 경질로 해석된다 국회에서 처리된 방통위 소관 법안이 거의 없다는 점이 우선 지목된다 민경욱 대변인이 KBS에 사표를 제출하지 않고 청와대에 직행한 것을 두고 윤리도덕적 측면에서 문제가 있다고 답변해 박 대통령의 심기를 건드린 것 아니냐는 말도 나온다'

# %%
df2 = df[df['ksic_count'] > 0]

# %%
len(df2)
# Out:
# 1506386

# %%
df2['ksic_count'].value_counts().sort_index()
# Out:
# 1     1201074
# 2      194314
# 3       59252
# 4       28482
# 5       11241
# 6        5362
# 7        2837
# 8        1342
# 9        1462
# 10        478
# 11        252
# 12        122
# 13         65
# 14         44
# 15         12
# 16         19
# 17         11
# 18          2
# 19          5
# 20          6
# 21          2
# 22          1
# 23          1
# Name: ksic_count, dtype: int64

# %%
df2.to_csv('/home/osung/data/korean/modu/json/news_PEST_ksic_score_remove_non.tsv', sep='\t')

# %%
df2['ksic_scores']
# Out:
# 0          {'c102': 1, 'c272': 1, 'c211': 2, 'c271': 24, ...
# 1                                                {'c333': 6}
# 2          {'c264': 1, 'c311': 17, 'c152': 1, 'c333': 1, ...
# 3          {'c272': 1, 'c103': 33, 'c271': 2, 'c273': 1, ...
# 4          {'c311': 26, 'c192': 3, 'c201': 1, 'c273': 1, ...
#                                  ...
# 1530047                    {'c192': 1, 'c179': 2, 'c264': 1}
# 1530048         {'c271': 1, 'c285': 1, 'c301': 1, 'c311': 1}
# 1530049                               {'c132': 1, 'c171': 1}
# 1530050    {'c204': 2, 'c262': 1, 'c282': 1, 'c289': 1, '...
# 1530051    {'c262': 2, 'c201': 2, 'c202': 3, 'c204': 2, '...
# Name: ksic_scores, Length: 1506386, dtype: object

# %%
df2['max_ksic_score'] = df2['max_ksic'].apply(lambda x:df2['ksic_scores'][(x[0])])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'c271'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2102719/825110785.py in <module>
# ----> 1 df2['max_ksic_score'] = df2['max_ksic'].apply(lambda x:df2['ksic_scores'][(x[0])])
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#    1141                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142                 # "Callable[[Any], Any]"
# -> 1143                 mapped = lib.map_infer(
#    1144                     values,
#    1145                     f,  # type: ignore[arg-type]
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /tmp/ipykernel_2102719/825110785.py in <lambda>(x)
# ----> 1 df2['max_ksic_score'] = df2['max_ksic'].apply(lambda x:df2['ksic_scores'][(x[0])])
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'c271'

# %%
max_ksic_scores = []

for index, row in tqdm(df2.iterrows(), total=len(df2)) :
        max_ksic_score = row['ksic_scores'][row['max_ksic'][0]]
        max_ksic_scores.append(max_ksic_score)
# Out:
# 100%|██████████████████████████████| 1506386/1506386 [00:41<00:00, 36234.86it/s]

# %%
df2['max_ksic_scores'] = max_ksic_scores
# Out:
# /tmp/ipykernel_2102719/839618001.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['max_ksic_scores'] = max_ksic_scores

# %%
df2['max_ksic_scores'].value_counts().sort_index()
# Out:
# 1      122391
# 2      153496
# 3      130342
# 4      114292
# 5      102355
#         ...
# 138         2
# 143         1
# 148         1
# 164         2
# 166         1
# Name: max_ksic_scores, Length: 133, dtype: int64

# %%
df3 = df2[df2['max_ksic_scores'] > 4]

# %%
len(df3)
# Out:
# 985865

# %%
len(df2)
# Out:
# 1506386

# %%
df_1 = df2[df2['max_ksic_scores'] == 1]

# %%
df_1.columns
# Out:
# Index(['id', 'topic', 'text', 'ksic', 'max_scores', 'keywords',
#        'keywords_orig', 'ksic_scores', 'max_ksic', 'ksic_count',
#        'max_ksic_scores'],
#       dtype='object')

# %%
df_1.ksic_count.value_counts().sort_index()
# Out:
# 1     36333
# 2     32097
# 3     22525
# 4     13686
# 5      8202
# 6      4515
# 7      2330
# 8      1216
# 9       648
# 10      367
# 11      210
# 12      105
# 13       63
# 14       40
# 15       11
# 16       18
# 17       10
# 18        2
# 19        5
# 20        5
# 21        2
# 22        1
# Name: ksic_count, dtype: int64

# %%
df_1.iloc[1].text
# Out:
# '윤석열 아내 관련 논란 공정상식에 맞지 않아죄송 윤석열 국민의힘 대선 후보가 배우자 김건희씨의 허위 이력 의혹과 관련해 제 아내와 관련된 논란으로 국민 여러분께 심려를 끼쳐드려 죄송하다고 사과했다 윤 후보는 17일 오후 여의도 당사에서 국민후원금 모금 캠페인 행사를 한 뒤 예고 없이 기자실을 찾아 양복 안주머니에서 준비된 A4 용지를 꺼내들곤 이같이 말했다 윤 후보는 또 이유 여하를 불문하고 경력 기재가 정확하지 않고 논란을 야기하게 된 것 자체만으로 제가 강조해 온 공정과 상식에 맞지 않는 것임을 분명히 말씀드린다고 밝혔다 이어 국민 여러분께서 저에게 기대하셨던 바를 결코 잊지 않겠다며 과거 제가 가졌던 일관된 원칙과 잣대를 저와 제 가족 제 주변에 대해서도 똑같이 적용돼야만 한다고 강조했다 윤 후보는 아내와 관련된 국민의 비판을 겸허히 달게 받겠다며 그리고 더 낮은 자세로 국민께 다가가겠다 죄송하다라며 거듭 고개를 숙였다'

# %%
df3.ksic_count.value_counts().sort_index()
# Out:
# 1     880092
# 2      85274
# 3      13865
# 4       5418
# 5        354
# 6         39
# 7        176
# 8         16
# 9        594
# 10        24
# 11        11
# 12         2
# Name: ksic_count, dtype: int64

# %%
global_ksic_count = {key: 0 for key in KSIC_keyword.keys()}

# %%
for index, row in tqdm(df3.iterrows(), total=len(df3)):
    for ksic in row['max_ksic']:
        global_ksic_count[ksic] += 1
# Out:
# 100%|████████████████████████████████| 985865/985865 [00:24<00:00, 40489.83it/s]

# %%
global_ksic_count
# Out:
# {'c101': 17822,
#  'c102': 37096,
#  'c103': 77533,
#  'c104': 1617,
#  'c105': 3319,
#  'c106': 6948,
#  'c107': 16823,
#  'c108': 1094,
#  'c111': 5395,
#  'c112': 5568,
#  'c120': 875,
#  'c131': 280,
#  'c132': 1689,
#  'c133': 659,
#  'c134': 2872,
#  'c139': 3588,
#  'c141': 2609,
#  'c142': 14,
#  'c143': 328,
#  'c144': 469,
#  'c151': 1590,
#  'c152': 4008,
#  'c161': 3669,
#  'c162': 1753,
#  'c163': 1170,
#  'c171': 4285,
#  'c172': 7680,
#  'c179': 2279,
#  'c181': 8879,
#  'c182': 4718,
#  'c191': 2404,
#  'c192': 27067,
#  'c201': 17125,
#  'c202': 4199,
#  'c203': 11679,
#  'c204': 5944,
#  'c211': 5637,
#  'c212': 10921,
#  'c213': 924,
#  'c221': 3689,
#  'c222': 4219,
#  'c231': 2541,
#  'c232': 490,
#  'c233': 31461,
#  'c239': 4596,
#  'c241': 19159,
#  'c242': 2623,
#  'c243': 153,
#  'c251': 2575,
#  'c252': 35346,
#  'c259': 3764,
#  'c261': 24746,
#  'c262': 71972,
#  'c263': 3756,
#  'c264': 102255,
#  'c265': 9737,
#  'c266': 978,
#  'c271': 158917,
#  'c272': 24601,
#  'c273': 12137,
#  'c274': 527,
#  'c281': 461,
#  'c282': 9792,
#  'c283': 2514,
#  'c284': 1520,
#  'c285': 19369,
#  'c289': 1765,
#  'c291': 2758,
#  'c292': 1220,
#  'c301': 52804,
#  'c302': 580,
#  'c303': 21282,
#  'c304': 7139,
#  'c311': 40045,
#  'c312': 6121,
#  'c313': 18506,
#  'c319': 13835,
#  'c320': 32967,
#  'c331': 1336,
#  'c332': 876,
#  'c333': 12312,
#  'c334': 27543,
#  'c339': 7536,
#  'c340': 7950}

# %%
df_c142 = df3[df3['max_ksic'].apply(lambda x: 'c142' in x)]

# %%
df_c142
# Out:
#                            id topic  \
# 794858   NPRW2100000002.50776     S
# 796689   NWRW2100000005.15953     S
# 818559   NPRW2100000002.43978     S
# 820412   NWRW2100000004.14286     S
# 830698   NWRW2100000005.16448     S
# 833775   NWRW2100000002.32433     S
# 862384   NWRW2100000004.14990     S
# 876640   NWRW2100000002.30370     S
# 964334   NWRW2100000002.34516     S
# 1008619    NLRW1900000047.884     S
# 1106660    NLRW1900000104.446     S
# 1127200  NWRW1900000036.10978     S
# 1184316  NPRW2100000002.49600     T
# 1290687  NWRW1900000032.28408     T
#
#                                                       text  ksic  max_scores  \
# 794858   코로나 때문에 살처분된 수천 마리 밍크 땅을 뚫고 솟아올라 공포 덴마크에서 신종 코...  c142    0.206258
# 796689   변종 코로나 때문에 밍크 2000만 마리 살처분 운명 종간 신종 코로나바이러스 감염...  c142    0.203095
# 818559   가죽 벗기더니 이번엔 코로나밍크 100만마리 눈물의 살처분 덴마크에서 밍크 100만...  c142    0.175707
# 820412   덴마크 밍크 1700만 마리 살처분모피축산코로나의 비극 인간의 옷이 되기 위해 좁은...  c142    0.173910
# 830698   덴마크 정부가 밍크 1700만마리 살처분 일단 멈춘 이유 실수를 저질렀다 유감스러운...  c142    0.164779
# 833775   좀비 밍크 공포 휩싸인 덴마크 사체 다시 꺼낼 것왜 덴마크가 코로나19 바이러스 확...  c271    0.162348
# 862384   덴마크 변종 코로나 발견된 밍크 살처분 명령에 총리 퇴진론 덴마크 농업식품부 장관이...  c142    0.143487
# 876640   덴마크 코로나 걸린 밍크 살처분 철회했지만대신 모피 벗겨 도살 덴마크 정부가 밍크 ...  c142    0.136155
# 964334   죽어도 편히 못죽네덴마크 매장한 밍크 400만 마리 다시 꺼내 소각 모피 때문에 죽...  c271    0.103939
# 1008619  백화점서 파는 것 가짜 모피 속여 판 일당 검거 지난달 5일 오전 10시께 창원시 ...  c142    0.092580
# 1106660  자유란 무엇인가  사만다 경위는 미스 세시나를 잘 알고 있었다 미스 세시나는 시위할...  c142    0.073391
# 1127200  한국전 참전 노인 손수 쓴 부고문아내 헐린이 이제 밍크코트 살 수 있을 것 한국전쟁...  c142    0.070097
# 1184316  밍크의 돌연변이 코로나 사람서도 발견백신 무력화 우려 덴마크 밍크 농장에서 코로나바...  c211    0.157219
# 1290687  1867년 미국 소련령 알래스카 구입 당 474달러 총 720만달러에 알래스카를 발...  c142    0.079657
#
#                                                   keywords  \
# 794858   {'밍크': 12, '바이러스': 3, '코로나': 3, '가스': 4, '소독':...
# 796689   {'농장': 4, '밍크': 20, '바이러스': 2, '코로나': 5, '감염':...
# 818559   {'농장': 10, '밍크': 18, '코로나': 9, '식품': 1, '감염': ...
# 820412   {'축산': 1, '농장': 14, '밍크': 23, '바이러스': 3, '코로나'...
# 830698   {'영상': 1, '농장': 9, '밍크': 24, '바이러스': 1, '코로나':...
# 833775   {'농장': 1, '밍크': 11, '바이러스': 4, '코로나': 5, '감염':...
# 862384   {'농장': 1, '밍크': 22, '바이러스': 6, '코로나': 8, '농가':...
# 876640   {'농장': 8, '밍크': 21, '바이러스': 9, '코로나': 8, '농가':...
# 964334   {'폐기물': 1, '밍크': 12, '바이러스': 4, '코로나': 5, '농가'...
# 1008619      {'코트': 1, '의류': 1, '의사': 1, '모피': 5, '차량': 1}
# 1106660  {'밍크': 1, '모피': 10, '사진': 6, '잉크': 2, '마리': 1,...
# 1127200  {'밍크': 5, '전쟁': 1, '코트': 3, '자리': 1, '듀폰': 2, ...
# 1184316  {'농장': 1, '밍크': 12, '바이러스': 11, '코로나': 1, '백신'...
# 1290687  {'여객선': 1, '전쟁': 1, '석유': 1, '운동': 2, '동물': 1,...
#
#                                              keywords_orig  \
# 794858   {'밍크': 12, '사체': 8, '살': 4, '처분': 4, '덴마크': 4,...
# 796689   {'밍크': 20, '마리': 7, '살': 7, '처분': 7, '변종': 5, ...
# 818559   {'밍크': 18, '덴마크': 11, '농장': 10, '코로나': 9, '감염'...
# 820412   {'밍크': 23, '덴마크': 14, '농장': 14, '마리': 8, '감염':...
# 830698   {'밍크': 24, '살': 16, '처분': 16, '덴마크': 11, '농장':...
# 833775   {'밍크': 11, '덴마크': 7, '사체': 6, '살': 6, '처분': 6,...
# 862384   {'밍크': 22, '덴마크': 11, '살': 11, '처분': 11, '사육':...
# 876640   {'밍크': 21, '살': 14, '처분': 14, '덴마크': 10, '바이러스...
# 964334   {'밍크': 12, '사체': 6, '덴마크': 5, '마리': 5, '다시': 5...
# 1008619  {'씨': 9, '이': 9, '모피': 5, '백화점': 4, '유명': 4, '...
# 1106660  {'모피': 10, '사만': 8, '경위': 8, '볼런': 8, '티어': 8,...
# 1127200  {'것': 7, '그': 6, '밍크': 5, '자신': 5, '부': 5, '고문...
# 1184316  {'밍크': 12, '바이러스': 11, '돌연변이': 9, '발견': 7, '덴마...
# 1290687  {'알래스카': 13, '러시아': 7, '모피': 5, '발견': 4, '베링':...
#
#                                                ksic_scores      max_ksic  \
# 794858   {'c142': 12, 'c211': 3, 'c271': 7, 'c192': 4, ...        [c142]
# 796689   {'c103': 4, 'c142': 23, 'c211': 2, 'c271': 10,...        [c142]
# 818559   {'c103': 12, 'c142': 20, 'c271': 16, 'c101': 7...        [c142]
# 820412   {'c101': 12, 'c103': 15, 'c142': 30, 'c211': 3...        [c142]
# 830698   {'c265': 1, 'c272': 1, 'c273': 1, 'c103': 16, ...        [c142]
# 833775   {'c103': 1, 'c142': 12, 'c211': 4, 'c271': 11,...        [c142]
# 862384   {'c103': 6, 'c142': 24, 'c211': 6, 'c271': 19,...        [c142]
# 876640   {'c103': 10, 'c142': 26, 'c211': 9, 'c271': 20...        [c142]
# 964334   {'c222': 1, 'c142': 14, 'c211': 4, 'c271': 11,...        [c142]
# 1008619  {'c141': 1, 'c134': 1, 'c143': 1, 'c271': 1, '...  [c142, c151]
# 1106660  {'c142': 11, 'c151': 10, 'c273': 6, 'c204': 2,...        [c142]
# 1127200  {'c142': 5, 'c252': 1, 'c313': 1, 'c319': 1, '...        [c142]
# 1184316  {'c103': 1, 'c142': 12, 'c211': 11, 'c271': 12...  [c142, c271]
# 1290687  {'c311': 1, 'c252': 1, 'c313': 1, 'c319': 1, '...  [c142, c151]
#
#          ksic_count  max_ksic_scores
# 794858            1               12
# 796689            1               23
# 818559            1               20
# 820412            1               30
# 830698            1               27
# 833775            1               12
# 862384            1               24
# 876640            1               26
# 964334            1               14
# 1008619           2                5
# 1106660           1               11
# 1127200           1                5
# 1184316           2               12
# 1290687           2                5

# %%
df_c243 = df3[df3['max_ksic'].apply(lambda x: 'c243' in x)]

# %%
len(df_c243)
# Out:
# 153

# %%
df_c243.iloc[20].text
# Out:
# '한일단조 세아베스틸과 특수강 협업 사업경쟁력 강화 한일단조가 세아베스틸과의 협업체제를 통해 사업경쟁력을 강화한다 한일단조는 1일 세아베스틸과 동반관계 구축을 위한 장기 협약식을 맺고 양사간 상생체제를 구축했다고 밝혔다 회사 관계자는 양사의 협약 배경은 최근 급변하는 글로벌 사업환경속에서 상호협력을 통해 시장확대를 모색하고 상호이익을 추구해 상생기반을 다진다는데 목표를 두고 있다고 설명했다 이에 따라 한일단조는 상용차 정밀 단조부품과 고품질의 방산품을 생산하는 데 최우선적으로 세아베스틸의 특수강을 사용해 품질향상 및 신규고객 창출을 견인할 계획이다 또 세아베스틸은 한일단조의 글로벌경쟁력 제고와 시장리더십 강화를 위해 원재료 공급을 최대한 지원한다는게 골자다 아울러 한일단조와 세아베스틸은 상호간의 신뢰와 협력을 바탕으로 국내외 신규 고객발굴 및 접점 마케팅 강화 해외시장개척 및 수출 저변 확대를 통한 수출 확대 정기 기술 교류회 등을 펼쳐 협업시너지를 극대화해 나갈 방침이다 한일단조는 세아베스틸과의 협업을 통해 그동안 우수한 기술과 제품력에도 불구하고 중국이나 인도 업체에게 불리했던 가격경쟁력을 만회하고 시장점유율을 견인할 수 있는 계기가 마련될 것으로 기대하고 있다 권병호 한일단조 대표는 부품소재업체 입장에서 안정적인 원재료 공급선 확보는 안정적인 사업을 영위하는 전제조건인데 세아베스틸의 적극적인 지원을 통해 고품질 기반 가격경쟁력을 갖출 수 있게 돼 큰 힘이 된다며 각 분야 1위 기업이 맞손을 잡은 만큼 이번 공동 협업으로 시장을 선점해 지속성장을 일구는 기업으로 자리매김할 것이라고 말했다 한편 한일단조는 49년간 단조기술을 통한 상용차용 단조부품 사업과 미사일 및 박격포탄 탄두탄체 방위사업을 영위하며 한국형 단조기술 표준기업으로 글로벌 성장을 가속화하고 있다'
